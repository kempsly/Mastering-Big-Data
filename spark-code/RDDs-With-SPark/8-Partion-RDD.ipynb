# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("Partition")
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# 25/01/26 20:40:18 WARN Utils: Your hostname, Kempslys-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.1.57 instead (on interface en0)
# 25/01/26 20:40:18 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/01/26 20:40:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
rdd = sc.textFile('playground.txt')

# %%
rdd.collect()
# Out:
# ['Hello! How are you?',
#  '',
#  "I'm doing well, thank you! How about you?",
#  '',
#  "I'm good too, thanks for asking.",
#  '',
#  'What have you been up to?',
#  '',
#  'Not much, just relaxing. How about you?',
#  '',
#  'Same here, just catching up on some work.',
#  '',
#  "That's good to hear. Do you have any plans for the weekend?",
#  '',
#  'I’m thinking of going hiking, how about you?',
#  '',
#  'I might just stay in and watch some movies.',
#  '',
#  'Sounds fun! Enjoy your weekend!',
#  '',
#  'Thanks, you too!']

# %%
rdd.getNumPartitions()
# Out:
# 2

# %%
rdd = rdd.repartition(5)

# %%
rdd.getNumPartitions()
# Out:
# 5

# %%
rdd2 = rdd.flatMap(lambda x: x.split(' '))
rdd3 = rdd2.map(lambda x: (x,1))

# %%
rdd3.saveAsTextFile('output/5partitionOutput')

# %%
rdd = sc.textFile('filter_text.txt')
rdd = rdd.repartition(5)
rdd2 = rdd.flatMap(lambda x: x.split(' '))
rdd3 = rdd2.map(lambda x: (x,1))
rdd3 = rdd3.coalesce(3)


rdd3.saveAsTextFile('output/3partitionOutput')

# %%
rdd = sc.textFile('output/5partitionOutput')
rdd.collect()
# Out:
# ["('Hello!', 1)",
#  "('How', 1)",
#  "('are', 1)",
#  "('you?', 1)",
#  "('', 1)",
#  '("I\'m", 1)',
#  "('doing', 1)",
#  "('well,', 1)",
#  "('thank', 1)",
#  "('you!', 1)",
#  "('How', 1)",
#  "('about', 1)",
#  "('you?', 1)",
#  "('', 1)",
#  '("I\'m", 1)',
#  "('good', 1)",
#  "('too,', 1)",
#  "('thanks', 1)",
#  "('for', 1)",
#  "('asking.', 1)",
#  "('', 1)",
#  "('What', 1)",
#  "('have', 1)",
#  "('you', 1)",
#  "('been', 1)",
#  "('up', 1)",
#  "('to?', 1)",
#  "('', 1)",
#  "('Not', 1)",
#  "('much,', 1)",
#  "('just', 1)",
#  "('relaxing.', 1)",
#  "('How', 1)",
#  "('about', 1)",
#  "('you?', 1)",
#  "('', 1)",
#  "('', 1)",
#  '("That\'s", 1)',
#  "('good', 1)",
#  "('to', 1)",
#  "('hear.', 1)",
#  "('Do', 1)",
#  "('you', 1)",
#  "('have', 1)",
#  "('any', 1)",
#  "('plans', 1)",
#  "('for', 1)",
#  "('the', 1)",
#  "('weekend?', 1)",
#  "('', 1)",
#  "('I’m', 1)",
#  "('thinking', 1)",
#  "('of', 1)",
#  "('going', 1)",
#  "('hiking,', 1)",
#  "('how', 1)",
# ...
