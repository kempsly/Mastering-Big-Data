# %%
"""
  The code here has been inspired by

  PySpark Cookbook:
  Over 60 recipes for implementing big data processing and analytics using
  Apache Spark and Python
"""

# %% [markdown]
# # Using Spark Dataframe

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 3.5.4

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("ColabPySpark") \
    .master("local[*]") \
    .getOrCreate()

print("Spark is running:", spark.version)
# Out:
# Spark is running: 3.5.4

# %%
# # Get Spark context
sc = spark.sparkContext

print(f"Spark UI: {sc.uiWebUrl}")  # Check Spark UI link
print(f"Spark Version: {sc.version}")
# Out:
# Spark UI: http://9d17be5665ee:4040
# Spark Version: 3.5.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Create flights RDD
flightsRDD = sc.textFile('/content/drive/My Drive/Pyspark/data/departure_delays.csv')\
.map(lambda line: line.split(",")).zipWithIndex()\
.filter(lambda row_idx: row_idx[1] > 0)\
.map(lambda row_idx: row_idx[0])

# %%
flightsRDD.take(3)
# Out:
# [['01011245', '6', '602', 'ABE', 'ATL'],
#  ['01020600', '-8', '369', 'ABE', 'DTW'],
#  ['01021245', '-2', '602', 'ABE', 'ATL']]

# %%
# Create flightsDF DataFrame
flightsDF = spark.read.options(header='true', inferSchema='true')\
    .csv('/content/drive/My Drive/Pyspark/data/departure_delays.csv')

flightsDF
# Out:
# DataFrame[date: int, delay: int, distance: int, origin: string, destination: string]

# %%
flightsDF.collect()
# Out:
# [Row(date=1011245, delay=6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1020600, delay=-8, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1021245, delay=-2, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1020605, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1031245, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1030605, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1041243, delay=10, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1040605, delay=28, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1051245, delay=88, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1050605, delay=9, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1061215, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1061725, delay=69, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1061230, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1060625, delay=-3, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1070600, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1071725, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1071230, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1070625, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1071219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1080600, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1081230, delay=33, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1080625, delay=1, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1080607, delay=5, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1081219, delay=54, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1091215, delay=43, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1090600, delay=151, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1091725, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1091230, delay=-4, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1090625, delay=8, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1091219, delay=83, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1101215, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1100600, delay=-5, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1101725, delay=7, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1101230, delay=-8, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1100625, delay=52, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1101219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1111215, delay=127, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1110600, delay=-9, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1110625, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1121215, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1121725, delay=-1, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1131215, delay=14, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1130600, delay=-7, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1131725, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1131230, delay=-13, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1130625, delay=29, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1131219, delay=-8, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1140600, delay=-9, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1141725, delay=-9, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1141230, delay=-8, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1140625, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1141219, delay=-10, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1150600, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1151725, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1151230, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1150625, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1150607, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1151219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1161215, delay=-10, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1160600, delay=-1, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1161725, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1161230, delay=-7, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1160625, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1161219, delay=68, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1171215, delay=-8, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1170600, delay=-5, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1171725, delay=5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1171230, delay=-10, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1170625, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1171219, delay=-10, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1181215, delay=-12, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1180600, delay=-13, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1180625, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1191215, delay=-16, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1191725, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1201215, delay=-8, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1201725, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1201230, delay=-11, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1200625, delay=-7, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1201219, delay=-6, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1210600, delay=89, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1211725, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1211230, delay=44, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1210625, delay=-6, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1211219, delay=9, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1220600, delay=80, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1221230, delay=-5, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1220625, delay=333, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1220607, delay=219, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1221219, delay=15, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1231215, delay=-12, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1230600, delay=-3, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1231725, delay=180, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1231230, delay=-5, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1230625, delay=-8, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1231219, delay=-13, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1241215, delay=-11, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1240600, delay=-3, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1241725, delay=2, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1241230, delay=-5, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1240625, delay=-3, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1241219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1251215, delay=2, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1250600, delay=-4, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1250625, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1261215, delay=1, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1261725, delay=7, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1271215, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1270600, delay=-9, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1271725, delay=-8, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1271230, delay=-7, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1270625, delay=-1, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1271219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1280600, delay=-6, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1281725, delay=-3, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1281230, delay=-8, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1280625, delay=-4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1281219, delay=0, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1290600, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1291230, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1290625, delay=4, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1290607, delay=92, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1291219, delay=-10, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1301215, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1300600, delay=-1, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1301725, delay=10, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1301230, delay=0, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1300625, delay=0, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1301219, delay=-11, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1311215, delay=1, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1310600, delay=-4, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1311725, delay=25, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1311230, delay=-4, distance=369, origin='ABE', destination='DTW'),
#  Row(date=1310625, delay=-5, distance=602, origin='ABE', destination='ATL'),
#  Row(date=1311219, delay=24, distance=569, origin='ABE', destination='ORD'),
#  Row(date=1011400, delay=26, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1011525, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1021400, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1021525, delay=47, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1031400, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1031525, delay=40, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1041400, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1041525, delay=3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1051400, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1051525, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1061400, delay=2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1061525, delay=22, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1071400, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1071525, delay=-15, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1081525, delay=21, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1091525, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1101525, delay=4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1111525, delay=-23, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1121525, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1131525, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1141525, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1151525, delay=-17, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1161525, delay=2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1171525, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1181525, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1191525, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1201525, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1211525, delay=-17, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1221525, delay=40, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1231525, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1241525, delay=21, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1251525, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1261525, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1271525, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1281525, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1291525, delay=146, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1301525, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1311525, delay=6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1010925, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1011730, delay=72, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1010700, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1011155, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1010810, delay=62, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1020550, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1020925, delay=7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1021730, delay=27, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1020700, delay=150, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1021155, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1020810, delay=1, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1030550, delay=51, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1030925, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1031730, delay=-18, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1030700, delay=2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1031155, delay=48, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1030810, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1040925, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1041730, delay=135, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1040700, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1041155, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1040810, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1050550, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1050925, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1051730, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1050700, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1051155, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1050810, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1060550, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1060925, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1061730, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1060700, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1061155, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1060810, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1070550, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1070925, delay=62, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1071730, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1070700, delay=4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1071155, delay=10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1070810, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1080550, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1080925, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1081730, delay=7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1080700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1081155, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1080810, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1081400, delay=10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1090550, delay=395, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1090925, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1091730, delay=38, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1090700, delay=6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1091155, delay=21, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1090810, delay=16, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1091400, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1100550, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1100925, delay=34, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1101730, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1100700, delay=129, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1101155, delay=-1, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1100810, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1101400, delay=30, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1110905, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1111730, delay=-14, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1110700, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1111155, delay=16, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1110810, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1111400, delay=39, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1120550, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1120925, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1121730, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1120700, delay=35, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1121155, delay=158, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1120810, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1121400, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1130550, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1130925, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1131730, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1130700, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1131155, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1130810, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1131400, delay=-1, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1140550, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1140925, delay=4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1141730, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1140700, delay=49, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1141155, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1140810, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1141400, delay=-17, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1150550, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1150925, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1151730, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1150700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1151155, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1150810, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1151400, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1160550, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1160925, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1161730, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1160700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1161155, delay=56, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1160810, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1161400, delay=8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1170550, delay=-1, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1170925, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1171730, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1170700, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1171155, delay=18, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1170810, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1171400, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1180905, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1181730, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1180700, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1181155, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1180810, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1181400, delay=6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1190550, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1190925, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1191730, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1190700, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1191155, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1190810, delay=-22, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1191400, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1200550, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1200925, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1201730, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1200700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1201155, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1200810, delay=19, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1201400, delay=3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1210550, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1210925, delay=29, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1211730, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1210700, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1211155, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1210810, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1211400, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1220550, delay=-12, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1220925, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1221730, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1220700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1221155, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1220810, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1221400, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1230550, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1230925, delay=15, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1231730, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1230700, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1231155, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1230810, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1231400, delay=37, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1240550, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1240925, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1241730, delay=61, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1240700, delay=-14, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1241155, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1240810, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1241400, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1250905, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1251730, delay=-14, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1250700, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1251155, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1250810, delay=-14, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1251400, delay=-26, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1260550, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1260925, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1261730, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1260700, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1261155, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1260810, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1261400, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1270550, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1270925, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1271730, delay=-3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1270700, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1271155, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1270810, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1271400, delay=-9, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1280550, delay=0, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1280925, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1281730, delay=-10, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1280700, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1281155, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1280810, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1281400, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1290550, delay=-5, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1290925, delay=57, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1291730, delay=8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1290700, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1291155, delay=3, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1290810, delay=-8, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1291400, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1300550, delay=-4, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1300925, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1301730, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1300700, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1301155, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1300810, delay=-11, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1301400, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1310550, delay=-2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1310925, delay=27, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1311730, delay=-6, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1310700, delay=-7, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1311155, delay=2, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1310810, delay=29, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1311400, delay=-13, distance=137, origin='ABI', destination='DFW'),
#  Row(date=1011405, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1011520, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1010605, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1010835, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1010730, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1011030, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1011135, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1021405, delay=8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1021520, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1020605, delay=118, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1020835, delay=59, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1020730, delay=87, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1021030, delay=85, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1021135, delay=115, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1021655, delay=87, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1031405, delay=38, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1031520, delay=36, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1030605, delay=2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1030835, delay=33, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1030730, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1031030, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1031135, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1031655, delay=85, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1041405, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1041520, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1040605, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1040835, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1040730, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1041030, delay=10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1041135, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1051405, delay=47, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1051520, delay=59, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1050605, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1050835, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1050730, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1051030, delay=30, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1051135, delay=9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1051655, delay=9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1061405, delay=25, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1061520, delay=36, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1060605, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1060835, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1060730, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1061030, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1061135, delay=71, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1061655, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1071405, delay=78, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1071520, delay=4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1070605, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1070835, delay=173, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1070730, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1071030, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1071135, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1081405, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1081520, delay=17, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1080605, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1080835, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1080730, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1081030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1081135, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1091405, delay=18, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1091520, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1090605, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1090835, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1090730, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1091030, delay=9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1091135, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1101405, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1101520, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1100605, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1100835, delay=-15, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1100730, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1101030, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1101135, delay=-14, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1111405, delay=43, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1111520, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1110605, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1110835, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1110730, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1111030, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1111135, delay=3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1121405, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1121520, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1120835, delay=-11, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1120730, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1121030, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1121135, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1131405, delay=2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1131520, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1130605, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1130835, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1130730, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1131030, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1131135, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1141405, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1141520, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1140605, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1140835, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1140730, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1141030, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1141135, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1151405, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1151520, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1150605, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1150835, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1150730, delay=4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1151030, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1151135, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1161405, delay=43, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1161520, delay=58, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1160605, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1160835, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1160730, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1161030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1161135, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1171405, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1171520, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1170605, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1170835, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1170730, delay=8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1171030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1171135, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1181405, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1181520, delay=38, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1180605, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1180835, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1180730, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1181030, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1181135, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1191405, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1191520, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1190835, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1190730, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1191030, delay=-15, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1191135, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1201405, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1201520, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1200605, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1200835, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1200730, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1201030, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1201135, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1211405, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1211520, delay=2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1210605, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1210835, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1210730, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1211030, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1211135, delay=-11, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1221405, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1221520, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1220605, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1220835, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1220730, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1221030, delay=87, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1221135, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1231405, delay=76, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1231520, delay=33, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1230605, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1230835, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1230730, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1231030, delay=62, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1231135, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1241405, delay=79, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1241520, delay=6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1240605, delay=68, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1240835, delay=3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1240730, delay=97, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1241030, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1241135, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1251405, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1251520, delay=11, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1250605, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1250835, delay=-13, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1250730, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1251030, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1251135, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1261405, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1261520, delay=11, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1260835, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1260730, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1261030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1261135, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1271405, delay=-11, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1271520, delay=-2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1270605, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1270835, delay=-13, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1270730, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1271030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1271135, delay=2, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1281405, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1281520, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1280605, delay=-12, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1280835, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1280730, delay=-10, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1281030, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1281135, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1291405, delay=8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1291520, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1290605, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1290835, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1290730, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1291030, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1291135, delay=19, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1301405, delay=-4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1301520, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1300605, delay=-7, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1300835, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1300730, delay=-3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1301030, delay=0, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1301135, delay=-1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1311405, delay=3, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1311520, delay=4, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1310605, delay=-6, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1310835, delay=-9, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1310730, delay=-5, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1311030, delay=1, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1311135, delay=-8, distance=494, origin='ABQ', destination='DFW'),
#  Row(date=1012355, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1022355, delay=158, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1032355, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1042355, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1052355, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1062355, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1072359, delay=14, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1082358, delay=-4, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1092358, delay=20, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1102358, delay=-2, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1112358, delay=116, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1122358, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1132358, delay=-10, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1142359, delay=-17, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1152358, delay=135, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1162358, delay=-13, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1172358, delay=-10, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1182358, delay=-17, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1192358, delay=-18, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1202358, delay=-9, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1212359, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1222358, delay=0, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1232358, delay=44, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1242358, delay=-6, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1252358, delay=-12, distance=1586, origin='ABQ', destination='JFK'),
#  Row(date=1262358, delay=-22, distance=1586, origin='ABQ', destination='JFK'),
# ...
#  Row(date=1290903, delay=146, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1291101, delay=127, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1290736, delay=9, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1301713, delay=-3, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1300903, delay=-8, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1311713, delay=1, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1310903, delay=12, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1011450, delay=7, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1021450, delay=32, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1020800, delay=-8, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1031450, delay=2, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1030800, delay=-3, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1040800, delay=94, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1050800, delay=-4, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1060800, delay=140, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1011950, delay=128, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1010545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1021950, delay=95, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1020545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1031950, delay=25, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1030545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1040545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1051950, delay=53, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1061950, delay=53, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1060545, delay=22, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1071950, delay=122, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1070545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1081950, delay=13, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1080545, delay=33, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1091950, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1090545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1101950, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1100545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1110545, delay=7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1121950, delay=-9, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1131950, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1130545, delay=14, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1141950, delay=-6, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1140545, delay=-5, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1151950, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1150545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1161950, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1160545, delay=-1, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1171950, delay=8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1170545, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1180545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1191950, delay=33, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1201950, delay=56, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1200545, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1211950, delay=10, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1210545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1221950, delay=58, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1220545, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1231950, delay=12, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1230545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1241950, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1240545, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1250545, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1261950, delay=-9, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1271950, delay=112, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1270545, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1281950, delay=22, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1280545, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1291950, delay=62, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1290545, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1301950, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1300545, delay=97, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1311950, delay=-10, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1310545, delay=6, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1011225, delay=10, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1012137, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1010620, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1011225, delay=-4, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1010830, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1011835, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1010715, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1011204, delay=26, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1011626, delay=39, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1010600, delay=-7, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1011047, delay=25, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1011344, delay=21, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1021225, delay=4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1022137, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1020620, delay=1, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1021225, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1020830, delay=-3, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1021835, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1020600, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1021204, delay=11, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1021825, delay=23, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1020600, delay=0, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1021933, delay=4, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1021047, delay=-5, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1021626, delay=4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1031225, delay=42, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1032137, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1030620, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1031225, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1030830, delay=-4, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1031835, delay=3, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1030600, delay=-1, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1031204, delay=84, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1031825, delay=-8, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1030600, delay=-10, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1031933, delay=-8, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1031047, delay=-4, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1031626, delay=2, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1041225, delay=3, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1042137, delay=0, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1040620, delay=-9, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1041225, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1040830, delay=-2, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1041835, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1040600, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1041204, delay=40, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1041825, delay=-3, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1041404, delay=52, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1041933, delay=25, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1040600, delay=-5, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1041047, delay=45, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1041626, delay=41, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1051225, delay=3, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1050545, delay=83, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1052137, delay=4, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1050620, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1051225, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1050830, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1051835, delay=-3, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1050605, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1051204, delay=-1, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1051825, delay=16, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1051040, delay=-7, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1050615, delay=-1, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1051721, delay=70, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1051411, delay=33, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1051658, delay=53, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1051933, delay=19, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1050530, delay=-4, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1050615, delay=0, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1051051, delay=35, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1061225, delay=3, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1060620, delay=-2, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1061225, delay=-4, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1060830, delay=24, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1061835, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1060600, delay=40, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1061720, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1060600, delay=0, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1061933, delay=-1, distance=303, origin='ABQ', destination='DEN'),
#  Row(date=1061040, delay=-3, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1061626, delay=-7, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1071225, delay=5, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1071225, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1070830, delay=-6, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1070620, delay=-1, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1070600, delay=3, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1071230, delay=-3, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1071815, delay=-10, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1071239, delay=0, distance=971, origin='ABQ', destination='ORD'),
#  Row(date=1070815, delay=4, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1071635, delay=-15, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1081255, delay=24, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1081225, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1080830, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1080620, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1081835, delay=-10, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1080600, delay=-3, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1081230, delay=-4, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1081815, delay=-8, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1081239, delay=3, distance=971, origin='ABQ', destination='ORD'),
#  Row(date=1080815, delay=36, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1081635, delay=59, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1091255, delay=11, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1090620, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1091225, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1090830, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1091835, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1090600, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1091230, delay=-3, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1091720, delay=-4, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1091239, delay=0, distance=971, origin='ABQ', destination='ORD'),
#  Row(date=1090815, delay=151, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1091635, delay=0, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1101255, delay=-6, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1100620, delay=-1, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1101225, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1100830, delay=-5, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1101835, delay=-10, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1100600, delay=-2, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1101230, delay=-8, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1101720, delay=-9, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1101239, delay=92, distance=971, origin='ABQ', destination='ORD'),
#  Row(date=1100815, delay=-6, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1101635, delay=36, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1111255, delay=-1, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1111225, delay=-8, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1110830, delay=-4, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1110620, delay=-7, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1111835, delay=-9, distance=285, origin='ABQ', destination='PHX'),
#  Row(date=1110800, delay=-4, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1111230, delay=-4, distance=428, origin='ABQ', destination='SLC'),
#  Row(date=1111101, delay=8, distance=646, origin='ABQ', destination='IAH'),
#  Row(date=1111239, delay=-8, distance=971, origin='ABQ', destination='ORD'),
#  Row(date=1110815, delay=-4, distance=779, origin='ABQ', destination='SFO'),
#  Row(date=1111635, delay=-5, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1121255, delay=-2, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1120545, delay=-8, distance=589, origin='ABQ', destination='LAX'),
#  Row(date=1120620, delay=-9, distance=285, origin='ABQ', destination='PHX'),
#  ...]

# %%
flightsDF.createOrReplaceTempView("flightsDF")

# %% [markdown]
# Create DF from RDD:

# %%
sample_data = sc.parallelize([
(1, 'MacBook Pro', 2015, '15"', '16GB', '512GB SSD'
, 13.75, 9.48, 0.61, 4.02)
, (2, 'MacBook', 2016, '12"', '8GB', '256GB SSD'
, 11.04, 7.74, 0.52, 2.03)
, (3, 'MacBook Air', 2016, '13.3"', '8GB', '128GB SSD'
, 12.8, 8.94, 0.68, 2.96)
, (4, 'iMac', 2017, '27"', '64GB', '1TB SSD'
, 25.6, 8.0, 20.3, 20.8)
])

# %%
sample_data.take(1)
# Out:
# [(1, 'MacBook Pro', 2015, '15"', '16GB', '512GB SSD', 13.75, 9.48, 0.61, 4.02)]

# %%
sample_df_from_RDD = spark.createDataFrame(
sample_data
, [
'Id', 'Model', 'Year', 'ScreenSize', 'RAM', 'HDD', 'W', 'D', 'H', 'Weight'
]
)

# %%
sample_df_from_RDD.take(2)
# Out:
# [Row(Id=1, Model='MacBook Pro', Year=2015, ScreenSize='15"', RAM='16GB', HDD='512GB SSD', W=13.75, D=9.48, H=0.61, Weight=4.02),
#  Row(Id=2, Model='MacBook', Year=2016, ScreenSize='12"', RAM='8GB', HDD='256GB SSD', W=11.04, D=7.74, H=0.52, Weight=2.03)]

# %%
sample_df_from_RDD.show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  1|MacBook Pro|2015|       15"|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|       12"| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|     13.3"| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|       27"|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %%
sample_df_from_RDD.printSchema()
# Out:
# root
#  |-- Id: long (nullable = true)
#  |-- Model: string (nullable = true)
#  |-- Year: long (nullable = true)
#  |-- ScreenSize: string (nullable = true)
#  |-- RAM: string (nullable = true)
#  |-- HDD: string (nullable = true)
#  |-- W: double (nullable = true)
#  |-- D: double (nullable = true)
#  |-- H: double (nullable = true)
#  |-- Weight: double (nullable = true)

# %% [markdown]
# Spark Dataframe from json file:

# %%
sample_data_json_df = (
                        spark.read.json('/content/drive/My Drive/Pyspark/data/sample.json'))

# %%
sample_data_json_df.show()
# Out:
# +----+----+---------+-----------+----+-----------+-----+-------+-----+---+
# |   D|   H|      HDD|      Model| RAM| ScreenSize|    W| Weight| Year| Id|
# +----+----+---------+-----------+----+-----------+-----+-------+-----+---+
# |9.48|0.61|512GB SSD|MacBook Pro|16GB|        15"|13.75|   4.02| 2015|  1|
# |7.74|0.52|256GB SSD|    MacBook| 8GB|        12"|11.04|   2.03| 2016|  2|
# |8.94|0.68|128GB SSD|MacBook Air| 8GB|      13.3"| 12.8|   2.96| 2016|  3|
# | 8.0|20.3|  1TB SSD|       iMac|64GB|        27"| 25.6|   20.8| 2017|  4|
# +----+----+---------+-----------+----+-----------+-----+-------+-----+---+

# %%
sample_data_json_df.printSchema()
# Out:
# root
#  |--  D: double (nullable = true)
#  |--  H: double (nullable = true)
#  |--  HDD: string (nullable = true)
#  |--  Model: string (nullable = true)
#  |--  RAM: string (nullable = true)
#  |--  ScreenSize: string (nullable = true)
#  |--  W: double (nullable = true)
#  |--  Weight: double (nullable = true)
#  |--  Year: long (nullable = true)
#  |-- Id: long (nullable = true)

# %%
sample_df_from_RDD.rdd.take(1)
# Out:
# [Row(Id=1, Model='MacBook Pro', Year=2015, ScreenSize='15"', RAM='16GB', HDD='512GB SSD', W=13.75, D=9.48, H=0.61, Weight=4.02)]

# %%
import pyspark.sql as sql
import pyspark.sql.functions as f

# Print schema separately (for debugging)
sample_df_from_RDD.printSchema()

# Transform the sample data
sample_data_transformed = (
    sample_df_from_RDD.rdd
    .map(lambda row: sql.Row(
        **row.asDict(),
        HDD_size=row.HDD.split(' ')[0]
    ))
    .map(lambda row: sql.Row(
        **row.asDict(),
        HDD_type=row.HDD.split(' ')[1]
    ))
    .map(lambda row: sql.Row(
        **row.asDict(),
        Volume=row.H * row.D * row.W
    ))
    .toDF()
    .select(
        *sample_df_from_RDD.columns,  # Unpacking existing columns
        'HDD_size',
        'HDD_type',
        f.round(f.col('Volume')).alias('Volume_cuIn')
    )
)

# Show transformed data
sample_data_transformed.show()
# Out:
# root
#  |-- Id: long (nullable = true)
#  |-- Model: string (nullable = true)
#  |-- Year: long (nullable = true)
#  |-- ScreenSize: string (nullable = true)
#  |-- RAM: string (nullable = true)
#  |-- HDD: string (nullable = true)
#  |-- W: double (nullable = true)
#  |-- D: double (nullable = true)
#  |-- H: double (nullable = true)
#  |-- Weight: double (nullable = true)
#
# +---+-----------+----+----------+----+---------+-----+----+----+------+--------+--------+-----------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|HDD_size|HDD_type|Volume_cuIn|
# +---+-----------+----+----------+----+---------+-----+----+----+------+--------+--------+-----------+
# |  1|MacBook Pro|2015|       15"|16GB|512GB SSD|13.75|9.48|0.61|  4.02|   512GB|     SSD|       80.0|
# |  2|    MacBook|2016|       12"| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|   256GB|     SSD|       44.0|
# |  3|MacBook Air|2016|     13.3"| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|   128GB|     SSD|       78.0|
# |  4|       iMac|2017|       27"|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|     1TB|     SSD|     4157.0|
# +---+-----------+----+----------+----+---------+-----+----+----+------+--------+--------+-----------+

# %% [markdown]
# ### **Explanation of the Code:**
# This PySpark script processes a DataFrame `sample_df_from_RDD`, extracting and transforming specific columns before converting it back to a DataFrame.
#
# ---
#
# ## **1. Import Required Libraries**
# ```python
# import pyspark.sql as sql
# import pyspark.sql.functions as f
# ```
# - `pyspark.sql` is imported to handle structured data using the Spark SQL module.
# - `pyspark.sql.functions` (aliased as `f`) provides functions for column operations like `round()`.
#
# ---
#
# ## **2. Print Schema for Debugging**
# ```python
# sample_df_from_RDD.printSchema()
# ```
# - This **prints the schema** (column names and data types) of `sample_df_from_RDD` before applying transformations.
# - It helps verify that the DataFrame is structured correctly.
#
# ---
#
# ## **3. Transform Data Using RDD Operations**
# The dataset is **converted into an RDD** (Resilient Distributed Dataset) and modified before being converted back to a DataFrame.
#
# ### **a) Convert DataFrame to RDD**
# ```python
# sample_df_from_RDD.rdd
# ```
# - Converts `sample_df_from_RDD` (a Spark DataFrame) into an RDD of `Row` objects for row-wise transformations.
#
# ---
#
# ### **b) Extract `HDD_size`**
# ```python
# .map(lambda row: sql.Row(
#     **row.asDict(),
#     HDD_size=row.HDD.split(' ')[0]  # Extracts the first part of the HDD column
# ))
# ```
# - Each row is converted to a dictionary using `.asDict()`, then back to a `Row` object.
# - The `HDD` column (e.g., `"500GB SSD"`) is split into words (`split(' ')`), and the **first word** (`500GB`) is stored as `HDD_size`.
#
# ---
#
# ### **c) Extract `HDD_type`**
# ```python
# .map(lambda row: sql.Row(
#     **row.asDict(),
#     HDD_type=row.HDD.split(' ')[1]  # Extracts the second part of the HDD column
# ))
# ```
# - Extracts the **second word** (`SSD`) from the `HDD` column and stores it as `HDD_type`.
#
# ---
#
# ### **d) Compute `Volume`**
# ```python
# .map(lambda row: sql.Row(
#     **row.asDict(),
#     Volume=row.H * row.D * row.W  # Calculate the volume using height, depth, and width
# ))
# ```
# - Computes the **volume** of an object using `H × D × W` and stores it as `Volume`.
#
# ---
#
# ## **4. Convert RDD Back to DataFrame**
# ```python
# .toDF()
# ```
# - Converts the transformed RDD **back to a Spark DataFrame**.
#
# ---
#
# ## **5. Select and Format Columns**
# ```python
# .select(
#     *sample_df_from_RDD.columns,  # Keep all original columns
#     'HDD_size',
#     'HDD_type',
#     f.round(f.col('Volume')).alias('Volume_cuIn')  # Round the Volume and rename column
# )
# ```
# - Keeps **all original columns** from `sample_df_from_RDD`.
# - Adds `HDD_size`, `HDD_type`, and **rounded** `Volume` (renamed to `Volume_cuIn`).
#
# ---
#
# ## **6. Display the Transformed Data**
# ```python
# sample_data_transformed.show()
# ```
# - Displays the transformed DataFrame.
#
# ---

# %% [markdown]
# ## Performance optimizations Techniques

# %%
import pyspark.sql.functions as f
import pandas as pd
from scipy import stats

# %%
big_df = spark.range(0, 1000000).withColumn('val', f.rand())
big_df.cache()

big_df.show(3)
# Out:
# +---+-------------------+
# | id|                val|
# +---+-------------------+
# |  0| 0.9186205554998382|
# |  1|0.19159021324850545|
# |  2|0.42624747849388045|
# +---+-------------------+
# only showing top 3 rows

# %% [markdown]
# This PySpark script creates a large DataFrame, caches it in memory for performance optimization, and then displays a few rows.
#
# ---
#
# ### **1. Create a Large DataFrame**
# ```python
# big_df = spark.range(0, 1000000).withColumn('val', f.rand())
# ```
# - `spark.range(0, 1000000)`:
#   - Creates a **DataFrame** with a **single column (`id`)** containing values from `0` to `999999` (one million rows).
# - `.withColumn('val', f.rand())`:
#   - Adds a new column named **`val`**, where each row contains a **random number** between `0` and `1`.
#
#
# ### **2. Cache the DataFrame in Memory**
# ```python
# big_df.cache()
# ```
# - **Stores the DataFrame in memory (or disk if needed)** for faster repeated access.
# - This prevents recomputation when `big_df` is used multiple times in subsequent operations.
#
# 💡 **Why use `cache()`?**
# - If `big_df` is used multiple times, Spark **won't re-evaluate** it.
# - Instead, it **fetches the precomputed result** from memory, improving performance.
#
# ---
#
# ### **3. Show the First 3 Rows**
# ```python
# big_df.show(3)
#
# ```
# - Displays the **first 3 rows** of the DataFrame.

# %%
@f.pandas_udf('double', f.PandasUDFType.SCALAR)
def pandas_pdf(v):

  return pd.Series(stats.norm.pdf(v))

big_df.withColumn('probability', pandas_pdf(big_df.val)).show(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/sql/pandas/functions.py:407: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   warnings.warn(
# +---+-------------------+-------------------+
# | id|                val|        probability|
# +---+-------------------+-------------------+
# |  0| 0.9186205554998382|0.26161785839371604|
# |  1|0.19159021324850545| 0.3916871133600802|
# |  2|0.42624747849388045| 0.3642983917289778|
# |  3|0.18188943222960408|  0.392397306304047|
# |  4| 0.8601473897522728|0.27558331033172945|
# +---+-------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# This code applies a **Pandas UDF** (User-Defined Function) to compute the **probability density function (PDF)** of a normal distribution for values in the **"val"** column of a Spark DataFrame.
#
# ---
#
# #### **1️⃣ Define the Pandas UDF**
# ```python
# @f.pandas_udf('double', f.PandasUDFType.SCALAR)
# def pandas_pdf(v):
#     return pd.Series(stats.norm.pdf(v))
# ```
# - **`@f.pandas_udf('double', f.PandasUDFType.SCALAR)`**
#   - Defines a **Pandas UDF** that returns a column of `double` values.
#   - `SCALAR`: This means the function **operates on each row (element-wise transformation)**.
# - **Function `pandas_pdf(v)`**
#   - Takes a **Pandas Series `v`** (column values in batches).
#   - Computes the **normal PDF** using `stats.norm.pdf(v)`.
#   - Returns the computed values as a **Pandas Series**.
#
# ---
#
# #### **2️⃣ Apply the UDF to the "val" Column**
# ```python
# big_df.withColumn('probability', pandas_pdf(big_df.val)).show(5)
# ```
# - `big_df.withColumn('probability', pandas_pdf(big_df.val))`:
#   - Creates a **new column "probability"** by applying `pandas_pdf` to the `"val"` column.
# - `.show(5)`:
#   - Displays the first **5 rows** of the updated DataFrame.
#
# ---

# %% [markdown]
# The @f.pandas_udf decorator
# preceding the method's declaration as this is key to registering a vectorized
# UDF in PySpark and has only became available in Spark 2.3.

# %%
#Performance Comparison

# %%
# Pandas UDF Approach (Vectorized)
@f.pandas_udf('double', f.PandasUDFType.SCALAR)
def pandas_pdf(v):
    return pd.Series(stats.norm.pdf(v))

def test_pandas_pdf():
    return (big_df
        .withColumn('probability', pandas_pdf(big_df.val))  # Apply vectorized PDF
        .agg(f.count(f.col('probability')))  # Count non-null values
        .show()
    )

# %timeit -n 1 test_pandas_pdf()
# Out:
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# 2.35 s ± 1.2 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Efficient because it processes entire batches of data at once.

# %%
# Regular UDF Approach (Row-by-Row)
@f.udf('double')  # Standard PySpark UDF
def pdf(v):
    return float(stats.norm.pdf(v))  # Compute PDF per row

def test_pdf():
    return (big_df
        .withColumn('probability', pdf(big_df.val))  # Apply row-wise PDF
        .agg(f.count(f.col('probability')))  # Count non-null values
        .show()
    )

# %timeit -n 1 test_pdf()
# Out:
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# +------------------+
# |count(probability)|
# +------------------+
# |           1000000|
# +------------------+
#
# 1min 53s ± 1.85 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Slower because it processes each row individually, causing frequent Python-JVM conversions.

# %% [markdown]
# ## Infering the schema With reflection

# %%
sample_rdd = sc.textFile('/content/drive/My Drive/Pyspark/data/sample.csv')
sample_rdd.take(5)
# Out:
# ['Id, Model, Year, ScreenSize, RAM, HDD, W, D, H, Weight',
#  '1,MacBook Pro,2015,"15\\"",16GB,512GB SSD,13.75,9.48,0.61,4.02',
#  '2,MacBook,2016,"12\\"",8GB,256GB SSD,11.04,7.74,0.52,2.03',
#  '3,MacBook Air,2016,"13.3\\"",8GB,128GB SSD,12.8,8.94,0.68,2.96',
#  '4,iMac,2017,"27\\"",64GB,1TB SSD,25.6,8.0,20.3,20.8']

# %%
# sample_data_json_df = (
#                         spark.read.json('/content/drive/My Drive/Pyspark/data/sample.json'))

# %%
import pyspark.sql as sql

header = sample_rdd.first()

sample_data_rdd_row = (
    sample_rdd
    .filter(lambda row: row != header)
    .map(lambda row: row.split(','))
    .map(lambda row:
        sql.Row(
            Id=int(row[0])
            , Model=row[1]
            , Year=int(row[2])
            , ScreenSize=row[3]
            , RAM=row[4]
            , HDD=row[5]
            , W=float(row[6])
            , D=float(row[7])
            , H=float(row[8])
            , Weight=float(row[9])
        )
    )
)

# %%
spark.createDataFrame(sample_data_rdd_row).show(5)
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# ## Defining the schema dynamically in code.

# %%
import pyspark.sql.types as typ

sch = typ.StructType([
      typ.StructField('Id', typ.LongType(), False)
    , typ.StructField('Model', typ.StringType(), True)
    , typ.StructField('Year', typ.IntegerType(), True)
    , typ.StructField('ScreenSize', typ.StringType(), True)
    , typ.StructField('RAM', typ.StringType(), True)
    , typ.StructField('HDD', typ.StringType(), True)
    , typ.StructField('W', typ.DoubleType(), True)
    , typ.StructField('D', typ.DoubleType(), True)
    , typ.StructField('H', typ.DoubleType(), True)
    , typ.StructField('Weight', typ.DoubleType(), True)
])

# %% [markdown]
# This code defines a schema for a PySpark DataFrame using `StructType` and `StructField` from `pyspark.sql.types`.
#
# - `StructType([])`: Represents the overall schema as a collection of fields.
# - `StructField(name, dataType, nullable)`: Defines each column with its name, data type, and whether it can contain `NULL` values.
#
# ### Schema Details:
# | Column Name  | Data Type       | Nullable | Description  |
# |-------------|----------------|----------|-------------|
# | `Id`        | `LongType`      | `False`  | Unique identifier for each row (mandatory). |
# | `Model`     | `StringType`    | `True`   | Name of the model. |
# | `Year`      | `IntegerType`   | `True`   | Manufacturing year. |
# | `ScreenSize`| `StringType`    | `True`   | Screen size of the device. |
# | `RAM`       | `StringType`    | `True`   | RAM size of the device. |
# | `HDD`       | `StringType`    | `True`   | Hard drive description. |
# | `W`         | `DoubleType`    | `True`   | Width of the device. |
# | `D`         | `DoubleType`    | `True`   | Depth of the device. |
# | `H`         | `DoubleType`    | `True`   | Height of the device. |
# | `Weight`    | `DoubleType`    | `True`   | Weight of the device. |

# %%
sample_rdd = sc.textFile('/content/drive/My Drive/Pyspark/data/sample.csv')

header = sample_rdd.first()

sample_rdd = (
    sample_rdd
    .filter(lambda row: row != header)
    .map(lambda row: row.split(','))
    .map(lambda row: (
                int(row[0])
                , row[1]
                , int(row[2])
                , row[3]
                , row[4]
                , row[5]
                , float(row[6])
                , float(row[7])
                , float(row[8])
                , float(row[9])
        )
    )
)

# %%
sample_data_schema = spark.createDataFrame(sample_rdd, schema=sch)
sample_data_schema.show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# ## Temporary Table

# %%
# Create a temporary view
sample_data_schema.createTempView('sample_data_view')

# %%
# We will start writing sql code using this view

# %%
spark.sql('''
    SELECT Model
        , Year
        , RAM
        , HDD
    FROM sample_data_view
''').show()
# Out:
# +-----------+----+----+---------+
# |      Model|Year| RAM|      HDD|
# +-----------+----+----+---------+
# |MacBook Pro|2015|16GB|512GB SSD|
# |    MacBook|2016| 8GB|256GB SSD|
# |MacBook Air|2016| 8GB|128GB SSD|
# |       iMac|2017|64GB|  1TB SSD|
# +-----------+----+----+---------+

# %%
sample_data_schema.createOrReplaceTempView('sample_data_view')

# %%
spark.sql('''
    SELECT *
    FROM sample_data_view
''').show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %%
spark.sql('''
    SELECT Model
      , Year
      , RAM
      , HDD
      , ScreenSize
    FROM sample_data_view
''').show()
# Out:
# +-----------+----+----+---------+----------+
# |      Model|Year| RAM|      HDD|ScreenSize|
# +-----------+----+----+---------+----------+
# |MacBook Pro|2015|16GB|512GB SSD|    "15\""|
# |    MacBook|2016| 8GB|256GB SSD|    "12\""|
# |MacBook Air|2016| 8GB|128GB SSD|  "13.3\""|
# |       iMac|2017|64GB|  1TB SSD|    "27\""|
# +-----------+----+----+---------+----------+

# %% [markdown]
# ## Let's play with the dataframe using sql commands

# %%
df = sc.parallelize([
      ('MacBook Pro', 'Laptop')
    , ('MacBook', 'Laptop')
    , ('MacBook Air', 'Laptop')
    , ('iMac', 'Desktop')
]).toDF(['Model', 'FormFactor'])

df.createOrReplaceTempView('models')

# %%
sample_data_schema.createOrReplaceTempView('sample_data_view')

# %%
spark.sql('''
    SELECT a.*
        , b.FormFactor
    FROM sample_data_view AS a
    LEFT JOIN models AS b
        ON a.Model == b.Model
    ORDER BY Weight DESC
''').show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+----------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|FormFactor|
# +---+-----------+----+----------+----+---------+-----+----+----+------+----------+
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|   Desktop|
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|    Laptop|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|    Laptop|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|    Laptop|
# +---+-----------+----+----------+----+---------+-----+----+----+------+----------+

# %% [markdown]
# Werun an **SQL query in PySpark** using `spark.sql()` to join two tables and retrieve data in a structured way.
#
#
# 1. **Querying Tables**
#    - `sample_data_view (a)`: Main table containing sample data.
#    - `models (b)`: Lookup table that includes `FormFactor` information.
#
# 2. **Join Operation (`LEFT JOIN`)**
#    - Matches rows from `sample_data_view` (`a`) with `models` (`b`) based on the `Model` column.
#    - Keeps all rows from `sample_data_view`, even if no match is found in `models` (null values will appear for `FormFactor` if there’s no match).
#
# 3. **Column Selection (`a.*, b.FormFactor`)**
#    - Selects all columns from `sample_data_view` (`a.*`).
#    - Adds `FormFactor` from `models` (`b`).
#
# 4. **Sorting (`ORDER BY Weight DESC`)**
#    - Orders results by the `Weight` column in **descending order** (heaviest first).
#
# 5. **Displaying Results (`.show()`)**
#    - Shows the first few rows of the resulting DataFrame.

# %%
spark.sql('''
    SELECT b.FormFactor
        , COUNT(*) AS ComputerCnt
    FROM sample_data_view AS a
    LEFT JOIN models AS b
        ON a.Model == b.Model
    GROUP BY FormFactor
''').show()
# Out:
# +----------+-----------+
# |FormFactor|ComputerCnt|
# +----------+-----------+
# |    Laptop|          3|
# |   Desktop|          1|
# +----------+-----------+

# %% [markdown]
# This SQL query **counts the number of computers** for each `FormFactor` by joining two datasets:
#
# - `sample_data_view` (**`a`**): Contains information about different computers.
# - `models` (**`b`**): Contains additional details, including the `FormFactor` for each model.
#
# ---
#
# 1. **LEFT JOIN (`ON a.Model == b.Model`)**
#    - Combines data from both tables based on the `Model` column.
#    - Ensures all records from `sample_data_view` (`a`) remain, even if `models` (`b`) lacks a matching `Model`.
#    - If there's no match, `FormFactor` will be `NULL` for those rows.
#
# 2. **COUNT(*) AS ComputerCnt**
#    - Counts the number of computers (rows) for each `FormFactor`.
#    - Groups results by `FormFactor`.
#
# 3. **GROUP BY FormFactor**
#    - Aggregates results so that each unique `FormFactor` gets a count of associated computers.
#
# 4. **.show()**
#    - Displays the first few rows of the resulting DataFrame.

# %% [markdown]
# ## DataFrame Transformation

# %% [markdown]
# .select() transformation:

# %%
# select Model and ScreenSize from the DataFrame
sample_data_schema.select('Model', 'ScreenSize').show()
# Out:
# +-----------+----------+
# |      Model|ScreenSize|
# +-----------+----------+
# |MacBook Pro|    "15\""|
# |    MacBook|    "12\""|
# |MacBook Air|  "13.3\""|
# |       iMac|    "27\""|
# +-----------+----------+

# %% [markdown]
# .filter() transformation

# %%
# extract only machines from 2015 onwards
sample_data_schema.filter(sample_data_schema.Year > 2015).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# .groupBy() transformation

# %%
sample_data_schema.groupBy('RAM').count().show()
# Out:
# +----+-----+
# | RAM|count|
# +----+-----+
# |16GB|    1|
# | 8GB|    2|
# |64GB|    1|
# +----+-----+

# %% [markdown]
# .orderBy() transformation

# %%
# sort by width (W)
sample_data_schema.orderBy('W').show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %%
# sort by height (H) in descending order
sample_data_schema.orderBy(f.col('H').desc()).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# .withColumn() transformation

# %%
# split the HDD into size and type
sample_data_schema.withColumn('HDDSplit', f.split(f.col('HDD'), ' ')).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|    HDDSplit|
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|[512GB, SSD]|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|[256GB, SSD]|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|[128GB, SSD]|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|  [1TB, SSD]|
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+

# %%
# do the same as withColumn
(sample_data_schema.select(f.col('*')
, f.split(f.col('HDD'), ' ').alias('HDD_Array')).show())
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|   HDD_Array|
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|[512GB, SSD]|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|[256GB, SSD]|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|[128GB, SSD]|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|  [1TB, SSD]|
# +---+-----------+----+----------+----+---------+-----+----+----+------+------------+

# %% [markdown]
# .join() transformation

# %%
models_df = sc.parallelize([
      ('MacBook Pro', 'Laptop')
    , ('MacBook Air', 'Laptop')
    , ('iMac', 'Desktop')
]).toDF(['Model', 'FormFactor'])

(
    sample_data_schema
    .join(
        models_df # Join with models_df
        , sample_data_schema.Model == models_df.Model # Match on 'Model'
        , 'left' # Perform LEFT JOIN (Keep all rows from sample_data_schema)
    ).show()
)
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|      Model|FormFactor|
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|       NULL|      NULL|
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|MacBook Pro|    Laptop|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|MacBook Air|    Laptop|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|       iMac|   Desktop|
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+

# %%
sample_data_schema.join(
        models_df
        , sample_data_schema.Model == models_df.Model
        , 'right'
    ).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|      Model|FormFactor|
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|MacBook Pro|    Laptop|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|MacBook Air|    Laptop|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|       iMac|   Desktop|
# +---+-----------+----+----------+----+---------+-----+----+----+------+-----------+----------+

# %% [markdown]
# The SEMI and ANTI joins are somewhat recent additions. The SEMI join keeps all
# the records from the left DataFrame that are matched with the records in the
# right DataFrame (as with the RIGHT join) but only keeps the columns from the
# left DataFrame; the ANTI join is the opposite of the SEMI join—it keeps only
# the records that are not found in the right DataFrame.

# %%
sample_data_schema.join(
        models_df
        , sample_data_schema.Model == models_df.Model
        , 'left_anti'
    ).show()
# Out:
# +---+-------+----+----------+---+---------+-----+----+----+------+
# | Id|  Model|Year|ScreenSize|RAM|      HDD|    W|   D|   H|Weight|
# +---+-------+----+----------+---+---------+-----+----+----+------+
# |  2|MacBook|2016|    "12\""|8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# +---+-------+----+----------+---+---------+-----+----+----+------+

# %%
sample_data_schema.join(
        models_df
        , sample_data_schema.Model == models_df.Model
        , 'left_semi'
    ).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# .unionAll() transformation

# %%
another_macBookPro = sc.parallelize([
                          (5, 'MacBook Pro', 2018, '15"', '16GB', '256GB SSD', 13.75, 9.48, 0.61, 4.02)])\
                          .toDF(sample_data_schema.columns)
sample_data_schema.unionAll(another_macBookPro).show()
# Out:
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# | Id|      Model|Year|ScreenSize| RAM|      HDD|    W|   D|   H|Weight|
# +---+-----------+----+----------+----+---------+-----+----+----+------+
# |  1|MacBook Pro|2015|    "15\""|16GB|512GB SSD|13.75|9.48|0.61|  4.02|
# |  2|    MacBook|2016|    "12\""| 8GB|256GB SSD|11.04|7.74|0.52|  2.03|
# |  3|MacBook Air|2016|  "13.3\""| 8GB|128GB SSD| 12.8|8.94|0.68|  2.96|
# |  4|       iMac|2017|    "27\""|64GB|  1TB SSD| 25.6| 8.0|20.3|  20.8|
# |  5|MacBook Pro|2018|       15"|16GB|256GB SSD|13.75|9.48|0.61|  4.02|
# +---+-----------+----+----------+----+---------+-----+----+----+------+

# %% [markdown]
# .distinct() transformation:

# %%
# select the distinct values from the RAM column
sample_data_schema.select('RAM').distinct().show()
# Out:
# +----+
# | RAM|
# +----+
# |16GB|
# | 8GB|
# |64GB|
# +----+

# %% [markdown]
# .repartition() transformation:

# %%
sample_data_schema_rep = (sample_data_schema.repartition(2, 'Year'))
sample_data_schema_rep.rdd.getNumPartitions()
# Out:
# 2

# %% [markdown]
# .fillna() transformation

# %%
missing_df = sc.parallelize([
                              (None, 36.3, 24.2)
                              , (1.6, 32.1, 27.9)
                              , (3.2, 38.7, 24.7)
                              , (2.8, None, 23.9)
                              , (3.9, 34.1, 27.9)
                              , (9.2, None, None)
                              ]).toDF(['A', 'B', 'C'])

missing_df.show()
# Out:
# +----+----+----+
# |   A|   B|   C|
# +----+----+----+
# |NULL|36.3|24.2|
# | 1.6|32.1|27.9|
# | 3.2|38.7|24.7|
# | 2.8|NULL|23.9|
# | 3.9|34.1|27.9|
# | 9.2|NULL|NULL|
# +----+----+----+

# %%
#Replace missing value with 21.4
missing_df.fillna(21.4).show()
# Out:
# +----+----+----+
# |   A|   B|   C|
# +----+----+----+
# |21.4|36.3|24.2|
# | 1.6|32.1|27.9|
# | 3.2|38.7|24.7|
# | 2.8|21.4|23.9|
# | 3.9|34.1|27.9|
# | 9.2|21.4|21.4|
# +----+----+----+

# %%
miss_dict = (missing_df.agg(f.mean('A').alias('A')
      , f.mean('B').alias('B')
      , f.mean('C').alias('C')
      )
).toPandas().to_dict('records')[0]

missing_df.fillna(miss_dict).show()
# Out:
# +----+------------------+-----+
# |   A|                 B|    C|
# +----+------------------+-----+
# |4.14|              36.3| 24.2|
# | 1.6|              32.1| 27.9|
# | 3.2|              38.7| 24.7|
# | 2.8|35.300000000000004| 23.9|
# | 3.9|              34.1| 27.9|
# | 9.2|35.300000000000004|25.72|
# +----+------------------+-----+

# %% [markdown]
# .dropna() transformation

# %%
#Remove missing value
missing_df.dropna().show()
# Out:
# +---+----+----+
# |  A|   B|   C|
# +---+----+----+
# |1.6|32.1|27.9|
# |3.2|38.7|24.7|
# |3.9|34.1|27.9|
# +---+----+----+

# %%
missing_df.dropna(thresh=2).show()
# Out:
# +----+----+----+
# |   A|   B|   C|
# +----+----+----+
# |NULL|36.3|24.2|
# | 1.6|32.1|27.9|
# | 3.2|38.7|24.7|
# | 2.8|NULL|23.9|
# | 3.9|34.1|27.9|
# +----+----+----+

# %% [markdown]
# ### **Understanding `dropna(thresh=2)` in PySpark**
#
# ```python
# missing_df.dropna(thresh=2).show()
# ```
#
# ---
#
# ### **What This Code Does**
# 1. **`dropna(thresh=2)`**
#    - Removes rows that have **less than 2 non-null (non-missing) values**.
#    - If a row has **at least 2 non-null values**, it remains in the DataFrame.
#    - If a row has **fewer than 2 non-null values**, it gets dropped.
#
# 2. **`.show()`**
#    - Displays the resulting DataFrame after applying `dropna()`.
#
# ---
#
# ### **Example Data Before Applying `dropna(thresh=2)`**
# | ID | Name  | Age  | Salary  |
# |----|-------|------|--------|
# | 1  | Alice | 25   | 50000  |
# | 2  | Bob   | None | None   |
# | 3  | None  | None | 30000  |
# | 4  | John  | 30   | None   |
#
# ---
#
# ### **After Applying `dropna(thresh=2)`**
# | ID | Name  | Age  | Salary  |
# |----|-------|------|--------|
# | 1  | Alice | 25   | 50000  |
# | 4  | John  | 30   | None   |
#
# - **Row 2** (`Bob, None, None`) was removed (only 1 non-null value: `ID`).
# - **Row 3** (`None, None, 30000`) was removed (only 1 non-null value: `Salary`).
# - **Rows 1 and 4** remained because they had **at least 2 non-null values**.
#
# ---

# %% [markdown]
# .dropDuplicates()transformation:

# %%
# The .dropDuplicates(...) transformation, as the name suggests, removes
# duplicated records.

# %%
dupes_df = sc.parallelize([
        (1.6, 32.1, 27.9)
        , (3.2, 38.7, 24.7)
        , (3.9, 34.1, 27.9)
        , (3.2, 38.7, 24.7)
        ]).toDF(['A', 'B', 'C'])
dupes_df.dropDuplicates().show()
# Out:
# +---+----+----+
# |  A|   B|   C|
# +---+----+----+
# |1.6|32.1|27.9|
# |3.2|38.7|24.7|
# |3.9|34.1|27.9|
# +---+----+----+

# %% [markdown]
# .summary() and .describe() transformations :

# %%
# The .summary() and .describe() transformations produce similar descriptive
# statistics, with the .summary() transformation additionally producing quartiles.

# %%
sample_data_schema.select('W').summary().show()
# Out:
# +-------+------------------+
# |summary|                 W|
# +-------+------------------+
# |  count|                 4|
# |   mean|15.797500000000001|
# | stddev| 6.630738395281983|
# |    min|             11.04|
# |    25%|             11.04|
# |    50%|              12.8|
# |    75%|             13.75|
# |    max|              25.6|
# +-------+------------------+

# %%
sample_data_schema.select('W').describe().show()
# Out:
# +-------+------------------+
# |summary|                 W|
# +-------+------------------+
# |  count|                 4|
# |   mean|15.797500000000001|
# | stddev| 6.630738395281983|
# |    min|             11.04|
# |    max|              25.6|
# +-------+------------------+

# %%
sample_data_schema.summary().show()
# Out:
# +-------+------------------+-------+-----------------+----------+----+---------+------------------+------------------+-----------------+-----------------+
# |summary|                Id|  Model|             Year|ScreenSize| RAM|      HDD|                 W|                 D|                H|           Weight|
# +-------+------------------+-------+-----------------+----------+----+---------+------------------+------------------+-----------------+-----------------+
# |  count|                 4|      4|                4|         4|   4|        4|                 4|                 4|                4|                4|
# |   mean|               2.5|   NULL|           2016.0|      NULL|NULL|     NULL|15.797500000000001|              8.54|           5.5275|7.452500000000001|
# | stddev|1.2909944487358056|   NULL|0.816496580927726|      NULL|NULL|     NULL| 6.630738395281983|0.8114185110040317|9.848551077865888|8.935395439859764|
# |    min|                 1|MacBook|             2015|    "12\""|16GB|128GB SSD|             11.04|              7.74|             0.52|             2.03|
# |    25%|                 1|   NULL|             2015|      NULL|NULL|     NULL|             11.04|              7.74|             0.52|             2.03|
# |    50%|                 2|   NULL|             2016|      NULL|NULL|     NULL|              12.8|               8.0|             0.61|             2.96|
# |    75%|                 3|   NULL|             2016|      NULL|NULL|     NULL|             13.75|              8.94|             0.68|             4.02|
# |    max|                 4|   iMac|             2017|    "27\""| 8GB|512GB SSD|              25.6|              9.48|             20.3|             20.8|
# +-------+------------------+-------+-----------------+----------+----+---------+------------------+------------------+-----------------+-----------------+

# %% [markdown]
# .freqItems() transformation:

# %% [markdown]
# The .freqItems(...) transformation returns a list of frequent items from a
# column. You can also specify a minSupport parameter that will throw away
# items that are below a certain threshold.

# %%
sample_data_schema.freqItems(['RAM']).show()
# Out:
# +-----------------+
# |    RAM_freqItems|
# +-----------------+
# |[16GB, 64GB, 8GB]|
# +-----------------+

# %% [markdown]
# ## Spark DataFrame Actions

# %% [markdown]
# .show() action:

# %%
sample_data_schema.select('W').describe().show()
# Out:
# +-------+------------------+
# |summary|                 W|
# +-------+------------------+
# |  count|                 4|
# |   mean|15.797500000000001|
# | stddev| 6.630738395281983|
# |    min|             11.04|
# |    max|              25.6|
# +-------+------------------+

# %% [markdown]
# .collect() action:

# %%
sample_data_schema.groupBy('Year').count().collect()
# Out:
# [Row(Year=2015, count=1), Row(Year=2016, count=2), Row(Year=2017, count=1)]

# %% [markdown]
# .take() action:

# %%
sample_data_schema.take(2)
# Out:
# [Row(Id=1, Model='MacBook Pro', Year=2015, ScreenSize='"15\\""', RAM='16GB', HDD='512GB SSD', W=13.75, D=9.48, H=0.61, Weight=4.02),
#  Row(Id=2, Model='MacBook', Year=2016, ScreenSize='"12\\""', RAM='8GB', HDD='256GB SSD', W=11.04, D=7.74, H=0.52, Weight=2.03)]

# %% [markdown]
# .toPandas() action:

# %%
# The .toPandas() action, as the name suggests, converts the Spark DataFrame
# into a pandas DataFrame.

# %%
sample_data_schema.toPandas()
# Out:
#    Id        Model  Year ScreenSize   RAM        HDD      W     D      H  \
# 0   1  MacBook Pro  2015     "15\""  16GB  512GB SSD  13.75  9.48   0.61
# 1   2      MacBook  2016     "12\""   8GB  256GB SSD  11.04  7.74   0.52
# 2   3  MacBook Air  2016   "13.3\""   8GB  128GB SSD  12.80  8.94   0.68
# 3   4         iMac  2017     "27\""  64GB    1TB SSD  25.60  8.00  20.30
#
#    Weight
# 0    4.02
# 1    2.03
# 2    2.96
# 3   20.80
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['W'].plot(kind='hist', bins=20, title='W')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['D'].plot(kind='hist', bins=20, title='D')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Model').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('ScreenSize').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('RAM').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('HDD').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Id', y='Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Year', y='W', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='W', y='D', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='D', y='H', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['W']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Model')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Model', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('W')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['W']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('Id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('ScreenSize')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='ScreenSize', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('W')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['W']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('Id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('RAM')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='RAM', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('W')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['W']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('Id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('HDD')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='HDD', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('W')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Id'].plot(kind='line', figsize=(8, 4), title='Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Year'].plot(kind='line', figsize=(8, 4), title='Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['W'].plot(kind='line', figsize=(8, 4), title='W')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['D'].plot(kind='line', figsize=(8, 4), title='D')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['ScreenSize'].value_counts()
#     for x_label, grp in _df_20.groupby('Model')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Model')
# _ = plt.ylabel('ScreenSize')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['RAM'].value_counts()
#     for x_label, grp in _df_21.groupby('ScreenSize')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('ScreenSize')
# _ = plt.ylabel('RAM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['HDD'].value_counts()
#     for x_label, grp in _df_22.groupby('RAM')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('RAM')
# _ = plt.ylabel('HDD')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['Model'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='Id', y='Model', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['ScreenSize'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='Id', y='ScreenSize', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['RAM'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='Id', y='RAM', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['HDD'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='Id', y='HDD', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
