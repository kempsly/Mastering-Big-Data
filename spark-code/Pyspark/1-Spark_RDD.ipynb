# %%
"""
  The code here has been inspired by

  PySpark Cookbook:
  Over 60 recipes for implementing big data processing and analytics using
  Apache Spark and Python
"""

# %% [markdown]
# # Using Spark RDD

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 3.5.4

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("ColabPySpark") \
    .master("local[*]") \
    .getOrCreate()

print("Spark is running:", spark.version)
# Out:
# Spark is running: 3.5.4

# %% [markdown]
# # Spark RDD

# %%
# # Get Spark context
sc = spark.sparkContext

print(f"Spark UI: {sc.uiWebUrl}")  # Check Spark UI link
print(f"Spark Version: {sc.version}")
# Out:
# Spark UI: http://4ee654948532:4040
# Spark Version: 3.5.4

# %%
myRDD = sc.parallelize([('Mike', 19), ('June', 18), ('Rachel',16), ('Rob', 18), ('Scott', 17)])

# %%
myRDD.take(5)
# Out:
# [('Mike', 19), ('June', 18), ('Rachel', 16), ('Rob', 18), ('Scott', 17)]

# %% [markdown]
# Load and Read data from files:

# %%
aiportRDD = sc.textFile('airport-code.txt')
aiportRDD.collect()
# Out:
# ['City\tState\tCountry\tIATA',
#  'Abbotsford\tBC\tCanada\tYXX',
#  'Aberdeen\tSD\tUSA\tABR',
#  'Abilene\tTX\tUSA\tABI',
#  'Akron\tOH\tUSA\tCAK',
#  'Alamosa\tCO\tUSA\tALS',
#  'Albany\tGA\tUSA\tABY',
#  'Albany\tNY\tUSA\tALB',
#  'Albuquerque\tNM\tUSA\tABQ',
#  'Alexandria\tLA\tUSA\tAEX',
#  'Allentown\tPA\tUSA\tABE',
#  'Alliance\tNE\tUSA\tAIA',
#  'Alpena\tMI\tUSA\tAPN',
#  'Altoona\tPA\tUSA\tAOO',
#  'Amarillo\tTX\tUSA\tAMA',
#  'Anahim Lake\tBC\tCanada\tYAA',
#  'Anchorage\tAK\tUSA\tANC',
#  'Appleton\tWI\tUSA\tATW',
#  'Arviat\tNWT\tCanada\tYEK',
#  'Asheville\tNC\tUSA\tAVL',
#  'Aspen\tCO\tUSA\tASE',
#  'Athens\tGA\tUSA\tAHN',
#  'Atlanta\tGA\tUSA\tATL',
#  'Atlantic City\tNJ\tUSA\tACY',
#  'Augusta\tGA\tUSA\tAGS',
#  'Augusta\tME\tUSA\tAUG',
#  'Austin\tTX\tUSA\tAUS',
#  'Bagotville\tPQ\tCanada\tYBG',
#  'Baie-Comeau\tPQ\tCanada\tYBC',
#  'Bakersfield\tCA\tUSA\tBFL',
#  'Baltimore\tMD\tUSA\tBWI',
#  'Bangor\tME\tUSA\tBGR',
#  'Bar Harbor\tME\tUSA\tBHB',
#  'Barrow\tAK\tUSA\tBRW',
#  'Baton Rouge\tLA\tUSA\tBTR',
#  'Beaumont\tTX\tUSA\tBPT',
#  'Beckley\tWV\tUSA\tBKW',
#  'Bedford\tMA\tUSA\tBED',
#  'Bellingham\tWA\tUSA\tBLI',
#  'Bemidji\tMN\tUSA\tBJI',
#  'Bethel\tAK\tUSA\tBET',
#  'Bettles\tAK\tUSA\tBTT',
#  'Billings\tMT\tUSA\tBIL',
#  'Binghamton\tNY\tUSA\tBGM',
#  'Birmingham\tAL\tUSA\tBHM',
#  'Bismarck\tND\tUSA\tBIS',
#  'Bloomington\tIL\tUSA\tBMI',
#  'Bloomington\tIN\tUSA\tBMG',
#  'Bluefield\tWV\tUSA\tBLF',
#  'Boise\tID\tUSA\tBOI',
#  'Boston\tMA\tUSA\tBOS',
#  'Bozeman\tMT\tUSA\tBZN',
#  'Brookings\tSD\tUSA\tBKX',
#  'Brownsville\tTX\tUSA\tBRO',
#  'Brunswick\tGA\tUSA\tBQK',
#  'Buffalo\tNY\tUSA\tBUF',
#  'Burbank\tCA\tUSA\tBUR',
#  'Burlington\tIA\tUSA\tBRL',
#  'Burlington\tMA\tUSA\tBBF',
#  'Burlington\tVT\tUSA\tBTV',
#  'Butte\tMT\tUSA\tBTM',
#  'Calgary\tAB\tCanada\tYYC',
#  'Campbell River\tBC\tCanada\tYBL',
#  '"Cap-aux-Meules, Magdalens Islands"\tPQ\tCanada\tYGR',
#  'Cape Girardeau\tMO\tUSA\tCGI',
#  'Carlsbad\tCA\tUSA\tCLD',
#  'Carlsbad\tNM\tUSA\tCNM',
#  'Casper\tWY\tUSA\tCPR',
#  'Castlegar\tBC\tCanada\tYCG',
#  'Cedar Rapids\tIA\tUSA\tCID',
#  'Champaign\tIL\tUSA\tCMI',
#  'Charleston\tSC\tUSA\tCHS',
#  'Charleston\tWV\tUSA\tCRW',
#  'Charlotte\tNC\tUSA\tCLT',
#  'Charlottesville\tVA\tUSA\tCHO',
#  'Charlottetown\tPEI\tCanada\tYYG',
#  'Chattanooga\tTN\tUSA\tCHA',
#  'Cheyenne\tWY\tUSA\tCYS',
#  'Chibougamau\tPQ\tCanada\tYMT',
#  'Chicago\tIL\tUSA\tMDW',
#  'Chicago\tIL\tUSA\tORD',
#  'Chicago\tIL\tUSA\tCHI',
#  'Chico\tCA\tUSA\tCIC',
#  'Churchill\tMB\tCanada\tYYQ',
#  'Cincinnati\tOH\tUSA\tCVG',
#  'Clarksburg\tWV\tUSA\tCKB',
#  'Cleveland\tOH\tUSA\tCLE',
#  'Clovis\tNM\tUSA\tCVN',
#  'Cody\tWY\tUSA\tCOD',
#  'College Station\tTX\tUSA\tCLL',
#  'Colorado Springs\tCO\tUSA\tCOS',
#  'Columbia\tMO\tUSA\tCOU',
#  'Columbia\tSC\tUSA\tCAE',
#  'Columbus\tGA\tUSA\tCSG',
#  'Columbus\tIN\tUSA\tCLU',
#  'Columbus\tMS\tUSA\tGTR',
#  'Columbus\tNE\tUSA\tOLU',
#  'Columbus\tOH\tUSA\tCMH',
#  'Cordova\tAK\tUSA\tCDV',
#  'Corpus Christi\tTX\tUSA\tCRP',
#  'Cranbrook\tBC\tCanada\tYXC',
#  'Dallas\tTX\tUSA\tDFW',
#  'Dallas\tTX\tUSA\tDAL',
#  'Dayton\tOH\tUSA\tDAY',
#  'Daytona Beach\tFL\tUSA\tDAB',
#  'Decatur\tIL\tUSA\tDEC',
#  'Deer Lake\tNF\tCanada\tYDF',
#  'Denver\tCO\tUSA\tDEN',
#  'Des Moines\tIA\tUSA\tDSM',
#  'Detroit\tMI\tUSA\tDTW',
#  'Detroit\tMI\tUSA\tDTT',
#  'Devils Lake\tND\tUSA\tDVL',
#  'Dickinson\tND\tUSA\tDIK',
#  'Dillingham\tAK\tUSA\tDLG',
#  'Dodge City\tKS\tUSA\tDDC',
#  'Dothan\tAL\tUSA\tDHN',
#  'Dryden\tON\tCanada\tYHD',
#  'Du Bois\tPA\tUSA\tDUJ',
#  'Dubuque\tIA\tUSA\tDBQ',
#  'Duluth\tMN\tUSA\tDLH',
#  'Durango\tCO\tUSA\tDRO',
#  '"Dutch Harbor, Un Island"\tAK\tUSA\tDUT',
#  'Eau Claire\tWI\tUSA\tEAU',
#  'Edmonton\tAB\tCanada\tYEG',
#  'Eek\tAK\tUSA\tEEK',
#  'El Centro\tCA\tUSA\tIPL',
#  'El Dorado\tAR\tUSA\tELD',
#  'El Paso\tTX\tUSA\tELP',
#  'Elko\tNV\tUSA\tEKO',
#  'Elmira\tNY\tUSA\tELM',
#  'Enid\tOK\tUSA\tWDG',
#  'Erie\tPA\tUSA\tERI',
#  'Escanaba\tMI\tUSA\tESC',
#  'Eugene\tOR\tUSA\tEUG',
#  'Eureka\tCA\tUSA\tACV',
#  'Evansville\tIN\tUSA\tEVV',
#  'Fairbanks\tAK\tUSA\tFAI',
#  'Fargo\tND\tUSA\tFAR',
#  'Farmington\tNM\tUSA\tFMN',
#  'Fayetteville\tAR\tUSA\tXNA',
#  'Fayetteville\tNC\tUSA\tFAY',
#  'Flagstaff\tAZ\tUSA\tFLG',
#  'Flin Flon\tMB\tCanada\tYFO',
#  'Flint\tMI\tUSA\tFNT',
#  'Florence\tSC\tUSA\tFLO',
#  'Fort Dodge\tIA\tUSA\tFOD',
#  'Fort Lauderdale\tFL\tUSA\tFLL',
#  'Fort Leonard Wood\tMO\tUSA\tTBN',
#  'Fort McMurray\tAB\tCanada\tYMM',
#  'Fort Myers\tFL\tUSA\tRSW',
#  'Fort Nelson\tBC\tCanada\tYYE',
#  'Fort Saint John\tBC\tCanada\tYXJ',
#  'Fort Smith\tAR\tUSA\tFSM',
#  'Fort Smith\tNWT\tCanada\tYSM',
#  'Fort Walton Beach\tFL\tUSA\tVPS',
#  'Fort Wayne\tIN\tUSA\tFWA',
#  'Fort Yukon\tAK\tUSA\tFYU',
#  'Fredericton\tNB\tCanada\tYFC',
#  'Fresno\tCA\tUSA\tFAT',
#  'Gainesville\tFL\tUSA\tGNV',
#  'Gander\tNF\tCanada\tYQX',
#  'Garden City\tKS\tUSA\tGCK',
#  'Gaspe\tPQ\tCanada\tYGP',
#  'Gillette\tWY\tUSA\tGCC',
#  'Glendive\tMT\tUSA\tGDV',
#  'Grand Forks\tND\tUSA\tGFK',
#  'Grand Island\tNE\tUSA\tGRI',
#  'Grand Junction\tCO\tUSA\tGJT',
#  'Grand Rapids\tMI\tUSA\tGRR',
#  'Grande Prairie\tAB\tCanada\tYQU',
#  'Great Bend\tKS\tUSA\tGBD',
#  'Great Falls\tMT\tUSA\tGTF',
#  'Green Bay\tWI\tUSA\tGRB',
#  'Greenbrier\tWV\tUSA\tLWB',
#  'Greensboro\tNC\tUSA\tGSO',
#  'Greenville\tMS\tUSA\tGLH',
#  'Greenville\tNC\tUSA\tPGV',
#  'Greenville\tSC\tUSA\tGSP',
#  'Gulfport\tMS\tUSA\tGPT',
#  'Gunnison\tCO\tUSA\tGUC',
#  'Hagerstown\tMD\tUSA\tHGR',
#  'Halifax\tNS\tCanada\tYHZ',
#  'Hamilton\tON\tCanada\tYHM',
#  '"Hana, Maui"\tHI\tUSA\tHNM',
#  'Hancock\tMI\tUSA\tCMX',
#  'Harlingen\tTX\tUSA\tHRL',
#  'Harrisburg\tPA\tUSA\tMDT',
#  'Harrison\tAR\tUSA\tHRO',
#  'Hartford\tCT\tUSA\tBDL',
#  'Havre\tMT\tUSA\tHVR',
#  'Hays\tKS\tUSA\tHYS',
#  'Helena\tMT\tUSA\tHLN',
#  'Hibbing\tMN\tUSA\tHIB',
#  'Hilo\tHI\tUSA\tBig',
#  'Hilton Head Island\tSC\tUSA\tHHH',
#  'Hobbs\tNM\tUSA\tHOB',
#  'Homer\tAK\tUSA\tHOM',
#  '"Honolulu, Oahu"\tHI\tUSA\tHNL',
#  '"Hoolehua, Molokai"\tHI\tUSA\tMKK',
#  'Hot Springs\tAR\tUSA\tHOT',
#  'Houston\tTX\tUSA\tIAH',
#  'Houston\tTX\tUSA\tHOU',
#  'Houston\tTX\tUSA\tEFD',
#  'Huntington\tWV\tUSA\tHTS',
#  'Huntsville\tAL\tUSA\tHSV',
#  'Huron\tSD\tUSA\tHON',
#  'Hyannis\tMA\tUSA\tHYA',
#  'Idaho Falls\tID\tUSA\tIDA',
#  'Indianapolis\tIN\tUSA\tIND',
#  'International Falls\tMN\tUSA\tINL',
#  'Inyokern\tCA\tUSA\tIYK',
#  'Iqaluit\tNunavut\tCanada\tYFB',
#  'Iron Mountain\tMI\tUSA\tIMT',
#  'Ironwood\tMI\tUSA\tIWD',
#  'Islip\tNY\tUSA\tISP',
#  'Ithaca\tNY\tUSA\tITH',
#  'Jackson Hole\tWY\tUSA\tJAC',
#  'Jackson\tMS\tUSA\tJAN',
#  'Jackson\tTN\tUSA\tMKL',
#  'Jacksonville\tFL\tUSA\tJAX',
#  'Jacksonville\tNC\tUSA\tOAJ',
#  'Jamestown\tND\tUSA\tJMS',
#  'Jamestown\tNY\tUSA\tJHW',
#  'Johnstown\tPA\tUSA\tJST',
#  'Jonesboro\tAR\tUSA\tJBR',
#  'Joplin\tMO\tUSA\tJLN',
#  'Juneau\tAK\tUSA\tJNU',
#  '"Kahului, Maui"\tHI\tUSA\tOGG',
#  'Kailua-Kona\tHawaii\tUSA\tBig',
#  'Kalamazoo\tMI\tUSA\tAZO',
#  '"Kalaupapa, Molokai"\tHI\tUSA\tLUP',
#  'Kalispell\tMT\tUSA\tFCA',
#  'Kamloops\tBC\tCanada\tYKA',
#  'Kamuela\tHawaii\tUSA\tBig',
#  'Kansas City\tMO\tUSA\tMCI',
#  '"Kapalua, Maui"\tHI\tUSA\tJHM',
#  'Kearney\tNE\tUSA\tEAR',
#  'Kelowna\tBC\tCanada\tYLW',
#  'Kenai\tAK\tUSA\tENA',
#  'Kenora\tON\tCanada\tYQK',
#  'Ketchikan\tAK\tUSA\tKTN',
#  'Key West\tFL\tUSA\tEYW',
#  'Killeen\tTX\tUSA\tGRK',
#  'King Salmon\tAK\tUSA\tAKN',
#  'Kingman\tAZ\tUSA\tIGM',
#  'Kingston\tON\tCanada\tYGK',
#  'Kirksville\tMO\tUSA\tIRK',
#  'Klamath Falls\tOR\tUSA\tLMT',
#  'Knoxville\tTN\tUSA\tTYS',
#  'Kodiak\tAK\tUSA\tADQ',
#  'La Crosse\tWI\tUSA\tLSE',
#  'Lafayette\tLA\tUSA\tLFT',
#  'Lake Charles\tLA\tUSA\tLCH',
#  'Lake Havasu City\tAZ\tUSA\tHII',
#  '"Lanai City, Lanai"\tHI\tUSA\tLNY',
#  'Lancaster\tPA\tUSA\tLNS',
#  'Lansing\tMI\tUSA\tLAN',
#  'Laramie\tWY\tUSA\tLAR',
#  'Laredo\tTX\tUSA\tLRD',
#  'Las Cruces\tNM\tUSA\tLRU',
#  'Las Vegas\tNV\tUSA\tLAS',
#  'Latrobe\tPA\tUSA\tLBE',
#  'Laurel\tMS\tUSA\tPIB',
#  'Lawton\tOK\tUSA\tLAW',
#  'Lebanon\tNH\tUSA\tLEB',
#  'Lethbridge\tAB\tCanada\tYQL',
#  'Lewiston\tID\tUSA\tLWS',
#  'Lewiston\tME\tUSA\tLEW',
#  'Lewistown\tMT\tUSA\tLWT',
#  'Lexington\tKY\tUSA\tLEX',
#  'Liberal\tKS\tUSA\tLBL',
#  '"Lihue, Kauai"\tHI\tUSA\tLIH',
#  'Lincoln\tNE\tUSA\tLNK',
#  'Little Rock\tAR\tUSA\tLIT',
#  'London\tON\tCanada\tYXU',
#  'Long Beach\tCA\tUSA\tLGB',
#  'Longview\tTX\tUSA\tGGG',
#  'Los Angeles\tCA\tUSA\tQLA',
#  'Los Angeles\tCA\tUSA\tLAX',
#  'Louisville\tKY\tUSA\tSDF',
#  'Lubbock\tTX\tUSA\tLBB',
#  'Lynchburg\tVA\tUSA\tLYH',
#  'Macon\tGA\tUSA\tMCN',
#  'Madison\tWI\tUSA\tMSN',
#  'Manchester\tNH\tUSA\tMHT',
#  'Manhattan\tKS\tUSA\tMHK',
#  'Manistee\tMI\tUSA\tMBL',
#  'Marion\tIL\tUSA\tMWA',
#  'Marquette\tMI\tUSA\tMQT',
#  "Martha's Vineyard\tMA\tUSA\tMVY",
#  'Mason City\tIA\tUSA\tMCW',
#  'Massena\tNY\tUSA\tMSS',
#  'McAllen\tTX\tUSA\tMFE',
#  'McCook\tNE\tUSA\tMCK',
#  'Medford\tOR\tUSA\tMFR',
#  'Medicine Hat\tAB\tCanada\tYXH',
#  'Melbourne\tFL\tUSA\tMLB',
#  'Memphis\tTN\tUSA\tMEM',
#  'Meridian\tMS\tUSA\tMEI',
#  'Miami\tFL\tUSA\tMIA',
#  'Midland\tTX\tUSA\tMAF',
#  'Miles City\tMT\tUSA\tMLS',
#  'Milwaukee\tWI\tUSA\tMKE',
#  'Minneapolis\tMN\tUSA\tMSP',
#  'Minot\tND\tUSA\tMOT',
#  'Missoula\tMT\tUSA\tMSO',
#  'Mobile\tAL\tUSA\tMOB',
#  'Modesto\tCA\tUSA\tMOD',
#  'Moline\tIL\tUSA\tMLI',
#  'Moncton\tNB\tCanada\tYQM',
#  'Monroe\tLA\tUSA\tMLU',
#  'Mont-Joli\tPQ\tCanada\tYYY',
#  'Monterey\tCA\tUSA\tMRY',
#  'Montgomery\tAL\tUSA\tMGM',
#  'Montreal\tPQ\tCanada\tYUL',
#  'Montreal\tPQ\tCanada\tYMQ',
#  'Montrose\tCO\tUSA\tMTJ',
#  'Morgantown\tWV\tUSA\tMGW',
#  'Moses Lake\tWA\tUSA\tMWH',
#  'Muscle Shoals\tAL\tUSA\tMSL',
#  'Muskegon\tMI\tUSA\tMKG',
#  'Myrtle Beach\tSC\tUSA\tMYR',
#  'Nanaimo\tBC\tCanada\tYCD',
#  'Nantucket\tMA\tUSA\tACK',
#  'Naples\tFL\tUSA\tAPF',
#  'Nashville\tTN\tUSA\tBNA',
#  'New Bern\tNC\tUSA\tEWN',
#  'New Haven\tCT\tUSA\tHVN',
#  'New Orleans\tLA\tUSA\tMSY',
#  'New York\tNY\tUSA\tJFK',
#  'New York\tNY\tUSA\tNYC',
#  'New York\tNY\tUSA\tLGA',
#  'Newark\tNJ\tUSA\tEWR',
#  'Newburgh\tNY\tUSA\tSWF',
#  'Newport News\tVA\tUSA\tPHF',
#  'Nome\tAK\tUSA\tOME',
#  'Norfolk\tVA\tUSA\tORF',
#  'North Bay\tON\tCanada\tYYB',
#  'North Bend\tOR\tUSA\tOTH',
#  'North Platte\tNE\tUSA\tLBF',
#  'Oakland\tCA\tUSA\tOAK',
#  'Ogdensburg\tNY\tUSA\tOGS',
#  'Oklahoma City\tOK\tUSA\tOKC',
#  'Omaha\tNE\tUSA\tOMA',
#  'Ontario\tCA\tUSA\tONT',
#  'Orange County\tCA\tUSA\tSNA',
#  'Orlando\tFL\tUSA\tMCO',
#  'Oshkosh\tWI\tUSA\tOSH',
#  'Ottawa\tON\tCanada\tYOW',
#  'Owensboro\tKY\tUSA\tOWB',
#  'Oxnard\tCA\tUSA\tOXR',
#  'Paducah\tKY\tUSA\tPAH',
#  'Page\tAZ\tUSA\tPGA',
#  'Palm Springs\tCA\tUSA\tPSP',
#  'Panama City\tFL\tUSA\tPFN',
#  'Parkersburg\tWV\tUSA\tPKB',
#  'Pasco\tWA\tUSA\tPSC',
#  'Pellston\tMI\tUSA\tPLN',
#  'Pendleton\tOR\tUSA\tPDT',
#  'Pensacola\tFL\tUSA\tPNS',
#  'Penticton\tBC\tCanada\tYYF',
#  'Peoria\tIL\tUSA\tPIA',
#  'Philadelphia\tPA\tUSA\tPHL',
#  'Phoenix\tAZ\tUSA\tPHX',
#  'Pierre\tSD\tUSA\tPIR',
#  'Pinehurst\tNC\tUSA\tSOP',
#  'Pittsburgh\tPA\tUSA\tPIT',
#  'Pocatello\tID\tUSA\tPIH',
#  'Ponca City\tOK\tUSA\tPNC',
#  'Port Hardy\tBC\tCanada\tYZT',
#  'Portland\tME\tUSA\tPWM',
#  'Portland\tOR\tUSA\tPDX',
#  'Portsmouth\tNH\tUSA\tPSM',
#  'Powell River\tBC\tCanada\tYPW',
#  'Prescott\tAZ\tUSA\tPRC',
#  'Presque Isle\tME\tUSA\tPQI',
#  'Prince George\tBC\tCanada\tYXS',
#  'Prince Rupert\tBC\tCanada\tYPR',
#  'Providence\tRI\tUSA\tPVD',
#  'Provincetown\tMA\tUSA\tPVC',
#  'Pueblo\tCO\tUSA\tPUB',
#  'Pullman\tWA\tUSA\tPUW',
#  'Quebec\tPQ\tCanada\tYQB',
#  'Quesnel\tBC\tCanada\tYQZ',
#  'Quincy\tIL\tUSA\tUIN',
#  'Raleigh\tNC\tUSA\tRDU',
#  'Rankin Inlet\tNWT\tCanada\tYRT',
#  'Rapid City\tSD\tUSA\tRAP',
#  'Red Lake\tON\tCanada\tYRL',
#  'Redding\tCA\tUSA\tRDD',
#  'Redmond\tOR\tUSA\tRDM',
#  'Regina\tSK\tCanada\tYQR',
#  'Reno\tNV\tUSA\tRNO',
#  'Rhinelander\tWI\tUSA\tRHI',
#  'Richmond\tVA\tUSA\tRIC',
#  'Riverton\tWY\tUSA\tRIW',
#  'Roanoke\tVA\tUSA\tROA',
#  'Roberval\tPQ\tCanada\tYRJ',
#  'Rochester\tMN\tUSA\tRST',
#  'Rochester\tNY\tUSA\tROC',
#  'Rock Springs\tWY\tUSA\tRKS',
#  'Rockford\tIL\tUSA\tRFD',
#  'Rockland\tME\tUSA\tRKD',
#  'Roswell\tNM\tUSA\tROW',
#  'Rouyn-Noranda\tPQ\tCanada\tYUY',
#  'Rutland\tVT\tUSA\tRUT',
#  'Sacramento\tCA\tUSA\tSMF',
#  'Saginaw\tMI\tUSA\tMBS',
#  'Saint John\tNB\tCanada\tYSJ',
#  'Salina\tKS\tUSA\tSLN',
#  'Salisbury\tMD\tUSA\tSBY',
#  'Salt Lake City\tUT\tUSA\tSLC',
#  'San Angelo\tTX\tUSA\tSJT',
#  'San Antonio\tTX\tUSA\tSAT',
#  'San Diego\tCA\tUSA\tSAN',
#  'San Francisco\tCA\tUSA\tQSF',
#  'San Francisco\tCA\tUSA\tSFO',
#  'San Jose\tCA\tUSA\tSJC',
#  'San Luis Obispo\tCA\tUSA\tSBP',
#  'Sand Point\tAK\tUSA\tSDP',
#  '"Sandspit, Queen Charlotte Islands"\tBC\tCanada\tYZP',
#  'Santa Barbara\tCA\tUSA\tSBA',
#  'Santa Fe\tNM\tUSA\tSAF',
#  'Santa Maria\tCA\tUSA\tSMX',
#  'Santa Rosa\tCA\tUSA\tSTS',
#  'Saranac Lake\tNY\tUSA\tSLK',
#  'Sarasota\tFL\tUSA\tSRQ',
#  'Sarnia\tON\tCanada\tYZR',
#  'Saskatoon\tSK\tCanada\tYXE',
#  'Sault Ste. Marie\tMI\tUSA\tCIU',
#  'Sault Ste. Marie\tON\tCanada\tYAM',
#  'Savannah\tGA\tUSA\tSAV',
#  'Scottsbluff\tNE\tUSA\tBFF',
#  'Seattle\tWA\tUSA\tSEA',
#  'Sept-Iles\tPQ\tCanada\tYZV',
#  'Shenandoah Valley Airport\tVA\tUSA\tSHD',
#  'Sheridan\tWY\tUSA\tSHR',
#  'Shreveport\tLA\tUSA\tSHV',
#  'Sidney\tMT\tUSA\tSDY',
#  'Silver City\tNM\tUSA\tSVC',
#  'Sioux City\tIA\tUSA\tSUX',
#  'Sioux Falls\tSD\tUSA\tFSD',
#  'Sioux Lookout\tON\tCanada\tYXL',
#  'Sitka\tAK\tUSA\tSIT',
#  'Skagway\tAK\tUSA\tSGY',
#  'Smithers\tBC\tCanada\tYYD',
#  'South Bend\tIN\tUSA\tSBN',
#  'Spokane\tWA\tUSA\tGEG',
#  'Springfield\tIL\tUSA\tSPI',
#  'Springfield\tMA\tUSA\tCEF',
#  'Springfield\tMO\tUSA\tSGF',
#  'Springfield\tVT\tUSA\tVSF',
#  'St. Cloud\tMN\tUSA\tSTC',
#  'St. George\tUT\tUSA\tSGU',
#  "St. John's\tNF\tCanada\tYYT",
#  'St. Louis\tMO\tUSA\tSTL',
#  'St. Petersburg\tFL\tUSA\tPIE',
#  'State College\tPA\tUSA\tSCE',
#  'Steamboat Springs\tCO\tUSA\tSBS',
#  'Sudbury\tON\tCanada\tYSB',
#  'Sun Valley\tID\tUSA\tSUN',
#  '"Sydney, Cape Breton Island"\tNS\tCanada\tYQY',
#  'Syracuse\tNY\tUSA\tSYR',
#  'Tallahassee\tFL\tUSA\tTLH',
#  'Tampa\tFL\tUSA\tTPA',
#  'Telluride\tCO\tUSA\tTEX',
#  'Terrace\tBC\tCanada\tYXT',
#  'Texarkana\tAR\tUSA\tTXK',
#  'Thief River Falls\tMN\tUSA\tTVF',
#  'Thompson\tMB\tCanada\tYTH',
#  'Thunder Bay\tON\tCanada\tYQT',
#  'Timmins\tON\tCanada\tYTS',
#  'Toksook Bay\tAK\tUSA\tOOK',
#  'Toledo\tOH\tUSA\tTOL',
#  'Eureka\tKS\tUSA\tTOP',
#  'Toronto\tON\tCanada\tYYZ',
#  'Toronto\tON\tCanada\tYTZ',
#  'Toronto\tON\tCanada\tYTO',
#  'Traverse City\tMI\tUSA\tTVC',
#  'Trenton\tNJ\tUSA\tTTN',
#  'Tri-City Airport\tTN\tUSA\tTRI',
#  'Tucson\tAZ\tUSA\tTUS',
#  'Tulsa\tOK\tUSA\tTUL',
#  'Tupelo\tMS\tUSA\tTUP',
#  'Twin Falls\tID\tUSA\tTWF',
#  'Tyler\tTX\tUSA\tTYR',
#  'Unalakleet\tAK\tUSA\tUNK',
#  'Vail\tCO\tUSA\tEGE',
#  "Val-d'Or\tPQ\tCanada\tYVO",
#  'Valdez\tAK\tUSA\tVDZ',
#  'Valdosta\tGA\tUSA\tVLD',
#  'Vancouver\tBC\tCanada\tYVR',
#  'Victoria\tBC\tCanada\tYYJ',
#  'Victoria\tTX\tUSA\tVCT',
#  'Visalia\tCA\tUSA\tVIS',
#  '"Wabush, Labrador"\tNF\tCanada\tYWK',
#  'Waco\tTX\tUSA\tACT',
#  'Walla Walla\tWA\tUSA\tALW',
#  'Washington DC\t\tUSA\tIAD',
#  'Washington DC\t\tUSA\tDCA',
#  'Washington DC\t\tUSA\tWAS',
#  'Waterloo\tIA\tUSA\tALO',
#  'Watertown\tNY\tUSA\tART',
#  'Watertown\tSD\tUSA\tATY',
#  'Wausau\tWI\tUSA\tCWA',
#  'Wenatchee\tWA\tUSA\tEAT',
#  'West Palm Beach\tFL\tUSA\tPBI',
#  'West Yellowstone\tMT\tUSA\tWYS',
#  'White Plains\tNY\tUSA\tHPN',
#  'Whitehorse\tYT\tCanada\tYXY',
#  'Wichita Falls\tTX\tUSA\tSPS',
#  'Wichita\tKS\tUSA\tICT',
#  'Wilkes-Barre\tPA\tUSA\tAVP',
#  'Williams Lake\tBC\tCanada\tYWL',
#  'Williamsport\tPA\tUSA\tIPT',
#  'Williston\tND\tUSA\tISN',
#  'Wilmington\tDE\tUSA\tILG',
#  'Wilmington\tNC\tUSA\tILM',
#  'Windsor\tON\tCanada\tYQG',
#  'Winnipeg\tMB\tCanada\tYWG',
#  'Wolf Point\tMT\tUSA\tOLF',
#  'Worland\tWY\tUSA\tWRL',
#  'Wrangell\tAK\tUSA\tWRG',
#  'Yakima\tWA\tUSA\tYKM',
#  'Yakutat\tAK\tUSA\tYAK',
#  'Yellowknife\tNWT\tCanada\tYZF',
#  'Yuma\tAZ\tUSA\tYUM']

# %%
aiportRDD.take(5)
# Out:
# ['City\tState\tCountry\tIATA',
#  'Abbotsford\tBC\tCanada\tYXX',
#  'Aberdeen\tSD\tUSA\tABR',
#  'Abilene\tTX\tUSA\tABI',
#  'Akron\tOH\tUSA\tCAK']

# %%
aiportRDD.count()
# Out:
# 527

# %%
aiportRDD = sc.textFile('airport-code.txt', minPartitions=4, use_unicode=True).map(lambda line: line.split("\t"))
aiportRDD.collect()
# Out:
# [['City', 'State', 'Country', 'IATA'],
#  ['Abbotsford', 'BC', 'Canada', 'YXX'],
#  ['Aberdeen', 'SD', 'USA', 'ABR'],
#  ['Abilene', 'TX', 'USA', 'ABI'],
#  ['Akron', 'OH', 'USA', 'CAK'],
#  ['Alamosa', 'CO', 'USA', 'ALS'],
#  ['Albany', 'GA', 'USA', 'ABY'],
#  ['Albany', 'NY', 'USA', 'ALB'],
#  ['Albuquerque', 'NM', 'USA', 'ABQ'],
#  ['Alexandria', 'LA', 'USA', 'AEX'],
#  ['Allentown', 'PA', 'USA', 'ABE'],
#  ['Alliance', 'NE', 'USA', 'AIA'],
#  ['Alpena', 'MI', 'USA', 'APN'],
#  ['Altoona', 'PA', 'USA', 'AOO'],
#  ['Amarillo', 'TX', 'USA', 'AMA'],
#  ['Anahim Lake', 'BC', 'Canada', 'YAA'],
#  ['Anchorage', 'AK', 'USA', 'ANC'],
#  ['Appleton', 'WI', 'USA', 'ATW'],
#  ['Arviat', 'NWT', 'Canada', 'YEK'],
#  ['Asheville', 'NC', 'USA', 'AVL'],
#  ['Aspen', 'CO', 'USA', 'ASE'],
#  ['Athens', 'GA', 'USA', 'AHN'],
#  ['Atlanta', 'GA', 'USA', 'ATL'],
#  ['Atlantic City', 'NJ', 'USA', 'ACY'],
#  ['Augusta', 'GA', 'USA', 'AGS'],
#  ['Augusta', 'ME', 'USA', 'AUG'],
#  ['Austin', 'TX', 'USA', 'AUS'],
#  ['Bagotville', 'PQ', 'Canada', 'YBG'],
#  ['Baie-Comeau', 'PQ', 'Canada', 'YBC'],
#  ['Bakersfield', 'CA', 'USA', 'BFL'],
#  ['Baltimore', 'MD', 'USA', 'BWI'],
#  ['Bangor', 'ME', 'USA', 'BGR'],
#  ['Bar Harbor', 'ME', 'USA', 'BHB'],
#  ['Barrow', 'AK', 'USA', 'BRW'],
#  ['Baton Rouge', 'LA', 'USA', 'BTR'],
#  ['Beaumont', 'TX', 'USA', 'BPT'],
#  ['Beckley', 'WV', 'USA', 'BKW'],
#  ['Bedford', 'MA', 'USA', 'BED'],
#  ['Bellingham', 'WA', 'USA', 'BLI'],
#  ['Bemidji', 'MN', 'USA', 'BJI'],
#  ['Bethel', 'AK', 'USA', 'BET'],
#  ['Bettles', 'AK', 'USA', 'BTT'],
#  ['Billings', 'MT', 'USA', 'BIL'],
#  ['Binghamton', 'NY', 'USA', 'BGM'],
#  ['Birmingham', 'AL', 'USA', 'BHM'],
#  ['Bismarck', 'ND', 'USA', 'BIS'],
#  ['Bloomington', 'IL', 'USA', 'BMI'],
#  ['Bloomington', 'IN', 'USA', 'BMG'],
#  ['Bluefield', 'WV', 'USA', 'BLF'],
#  ['Boise', 'ID', 'USA', 'BOI'],
#  ['Boston', 'MA', 'USA', 'BOS'],
#  ['Bozeman', 'MT', 'USA', 'BZN'],
#  ['Brookings', 'SD', 'USA', 'BKX'],
#  ['Brownsville', 'TX', 'USA', 'BRO'],
#  ['Brunswick', 'GA', 'USA', 'BQK'],
#  ['Buffalo', 'NY', 'USA', 'BUF'],
#  ['Burbank', 'CA', 'USA', 'BUR'],
#  ['Burlington', 'IA', 'USA', 'BRL'],
#  ['Burlington', 'MA', 'USA', 'BBF'],
#  ['Burlington', 'VT', 'USA', 'BTV'],
#  ['Butte', 'MT', 'USA', 'BTM'],
#  ['Calgary', 'AB', 'Canada', 'YYC'],
#  ['Campbell River', 'BC', 'Canada', 'YBL'],
#  ['"Cap-aux-Meules, Magdalens Islands"', 'PQ', 'Canada', 'YGR'],
#  ['Cape Girardeau', 'MO', 'USA', 'CGI'],
#  ['Carlsbad', 'CA', 'USA', 'CLD'],
#  ['Carlsbad', 'NM', 'USA', 'CNM'],
#  ['Casper', 'WY', 'USA', 'CPR'],
#  ['Castlegar', 'BC', 'Canada', 'YCG'],
#  ['Cedar Rapids', 'IA', 'USA', 'CID'],
#  ['Champaign', 'IL', 'USA', 'CMI'],
#  ['Charleston', 'SC', 'USA', 'CHS'],
#  ['Charleston', 'WV', 'USA', 'CRW'],
#  ['Charlotte', 'NC', 'USA', 'CLT'],
#  ['Charlottesville', 'VA', 'USA', 'CHO'],
#  ['Charlottetown', 'PEI', 'Canada', 'YYG'],
#  ['Chattanooga', 'TN', 'USA', 'CHA'],
#  ['Cheyenne', 'WY', 'USA', 'CYS'],
#  ['Chibougamau', 'PQ', 'Canada', 'YMT'],
#  ['Chicago', 'IL', 'USA', 'MDW'],
#  ['Chicago', 'IL', 'USA', 'ORD'],
#  ['Chicago', 'IL', 'USA', 'CHI'],
#  ['Chico', 'CA', 'USA', 'CIC'],
#  ['Churchill', 'MB', 'Canada', 'YYQ'],
#  ['Cincinnati', 'OH', 'USA', 'CVG'],
#  ['Clarksburg', 'WV', 'USA', 'CKB'],
#  ['Cleveland', 'OH', 'USA', 'CLE'],
#  ['Clovis', 'NM', 'USA', 'CVN'],
#  ['Cody', 'WY', 'USA', 'COD'],
#  ['College Station', 'TX', 'USA', 'CLL'],
#  ['Colorado Springs', 'CO', 'USA', 'COS'],
#  ['Columbia', 'MO', 'USA', 'COU'],
#  ['Columbia', 'SC', 'USA', 'CAE'],
#  ['Columbus', 'GA', 'USA', 'CSG'],
#  ['Columbus', 'IN', 'USA', 'CLU'],
#  ['Columbus', 'MS', 'USA', 'GTR'],
#  ['Columbus', 'NE', 'USA', 'OLU'],
#  ['Columbus', 'OH', 'USA', 'CMH'],
#  ['Cordova', 'AK', 'USA', 'CDV'],
#  ['Corpus Christi', 'TX', 'USA', 'CRP'],
#  ['Cranbrook', 'BC', 'Canada', 'YXC'],
#  ['Dallas', 'TX', 'USA', 'DFW'],
#  ['Dallas', 'TX', 'USA', 'DAL'],
#  ['Dayton', 'OH', 'USA', 'DAY'],
#  ['Daytona Beach', 'FL', 'USA', 'DAB'],
#  ['Decatur', 'IL', 'USA', 'DEC'],
#  ['Deer Lake', 'NF', 'Canada', 'YDF'],
#  ['Denver', 'CO', 'USA', 'DEN'],
#  ['Des Moines', 'IA', 'USA', 'DSM'],
#  ['Detroit', 'MI', 'USA', 'DTW'],
#  ['Detroit', 'MI', 'USA', 'DTT'],
#  ['Devils Lake', 'ND', 'USA', 'DVL'],
#  ['Dickinson', 'ND', 'USA', 'DIK'],
#  ['Dillingham', 'AK', 'USA', 'DLG'],
#  ['Dodge City', 'KS', 'USA', 'DDC'],
#  ['Dothan', 'AL', 'USA', 'DHN'],
#  ['Dryden', 'ON', 'Canada', 'YHD'],
#  ['Du Bois', 'PA', 'USA', 'DUJ'],
#  ['Dubuque', 'IA', 'USA', 'DBQ'],
#  ['Duluth', 'MN', 'USA', 'DLH'],
#  ['Durango', 'CO', 'USA', 'DRO'],
#  ['"Dutch Harbor, Un Island"', 'AK', 'USA', 'DUT'],
#  ['Eau Claire', 'WI', 'USA', 'EAU'],
#  ['Edmonton', 'AB', 'Canada', 'YEG'],
#  ['Eek', 'AK', 'USA', 'EEK'],
#  ['El Centro', 'CA', 'USA', 'IPL'],
#  ['El Dorado', 'AR', 'USA', 'ELD'],
#  ['El Paso', 'TX', 'USA', 'ELP'],
#  ['Elko', 'NV', 'USA', 'EKO'],
#  ['Elmira', 'NY', 'USA', 'ELM'],
#  ['Enid', 'OK', 'USA', 'WDG'],
#  ['Erie', 'PA', 'USA', 'ERI'],
#  ['Escanaba', 'MI', 'USA', 'ESC'],
#  ['Eugene', 'OR', 'USA', 'EUG'],
#  ['Eureka', 'CA', 'USA', 'ACV'],
#  ['Evansville', 'IN', 'USA', 'EVV'],
#  ['Fairbanks', 'AK', 'USA', 'FAI'],
#  ['Fargo', 'ND', 'USA', 'FAR'],
#  ['Farmington', 'NM', 'USA', 'FMN'],
#  ['Fayetteville', 'AR', 'USA', 'XNA'],
#  ['Fayetteville', 'NC', 'USA', 'FAY'],
#  ['Flagstaff', 'AZ', 'USA', 'FLG'],
#  ['Flin Flon', 'MB', 'Canada', 'YFO'],
#  ['Flint', 'MI', 'USA', 'FNT'],
#  ['Florence', 'SC', 'USA', 'FLO'],
#  ['Fort Dodge', 'IA', 'USA', 'FOD'],
#  ['Fort Lauderdale', 'FL', 'USA', 'FLL'],
#  ['Fort Leonard Wood', 'MO', 'USA', 'TBN'],
#  ['Fort McMurray', 'AB', 'Canada', 'YMM'],
#  ['Fort Myers', 'FL', 'USA', 'RSW'],
#  ['Fort Nelson', 'BC', 'Canada', 'YYE'],
#  ['Fort Saint John', 'BC', 'Canada', 'YXJ'],
#  ['Fort Smith', 'AR', 'USA', 'FSM'],
#  ['Fort Smith', 'NWT', 'Canada', 'YSM'],
#  ['Fort Walton Beach', 'FL', 'USA', 'VPS'],
#  ['Fort Wayne', 'IN', 'USA', 'FWA'],
#  ['Fort Yukon', 'AK', 'USA', 'FYU'],
#  ['Fredericton', 'NB', 'Canada', 'YFC'],
#  ['Fresno', 'CA', 'USA', 'FAT'],
#  ['Gainesville', 'FL', 'USA', 'GNV'],
#  ['Gander', 'NF', 'Canada', 'YQX'],
#  ['Garden City', 'KS', 'USA', 'GCK'],
#  ['Gaspe', 'PQ', 'Canada', 'YGP'],
#  ['Gillette', 'WY', 'USA', 'GCC'],
#  ['Glendive', 'MT', 'USA', 'GDV'],
#  ['Grand Forks', 'ND', 'USA', 'GFK'],
#  ['Grand Island', 'NE', 'USA', 'GRI'],
#  ['Grand Junction', 'CO', 'USA', 'GJT'],
#  ['Grand Rapids', 'MI', 'USA', 'GRR'],
#  ['Grande Prairie', 'AB', 'Canada', 'YQU'],
#  ['Great Bend', 'KS', 'USA', 'GBD'],
#  ['Great Falls', 'MT', 'USA', 'GTF'],
#  ['Green Bay', 'WI', 'USA', 'GRB'],
#  ['Greenbrier', 'WV', 'USA', 'LWB'],
#  ['Greensboro', 'NC', 'USA', 'GSO'],
#  ['Greenville', 'MS', 'USA', 'GLH'],
#  ['Greenville', 'NC', 'USA', 'PGV'],
#  ['Greenville', 'SC', 'USA', 'GSP'],
#  ['Gulfport', 'MS', 'USA', 'GPT'],
#  ['Gunnison', 'CO', 'USA', 'GUC'],
#  ['Hagerstown', 'MD', 'USA', 'HGR'],
#  ['Halifax', 'NS', 'Canada', 'YHZ'],
#  ['Hamilton', 'ON', 'Canada', 'YHM'],
#  ['"Hana, Maui"', 'HI', 'USA', 'HNM'],
#  ['Hancock', 'MI', 'USA', 'CMX'],
#  ['Harlingen', 'TX', 'USA', 'HRL'],
#  ['Harrisburg', 'PA', 'USA', 'MDT'],
#  ['Harrison', 'AR', 'USA', 'HRO'],
#  ['Hartford', 'CT', 'USA', 'BDL'],
#  ['Havre', 'MT', 'USA', 'HVR'],
#  ['Hays', 'KS', 'USA', 'HYS'],
#  ['Helena', 'MT', 'USA', 'HLN'],
#  ['Hibbing', 'MN', 'USA', 'HIB'],
#  ['Hilo', 'HI', 'USA', 'Big'],
#  ['Hilton Head Island', 'SC', 'USA', 'HHH'],
#  ['Hobbs', 'NM', 'USA', 'HOB'],
#  ['Homer', 'AK', 'USA', 'HOM'],
#  ['"Honolulu, Oahu"', 'HI', 'USA', 'HNL'],
#  ['"Hoolehua, Molokai"', 'HI', 'USA', 'MKK'],
#  ['Hot Springs', 'AR', 'USA', 'HOT'],
#  ['Houston', 'TX', 'USA', 'IAH'],
#  ['Houston', 'TX', 'USA', 'HOU'],
#  ['Houston', 'TX', 'USA', 'EFD'],
#  ['Huntington', 'WV', 'USA', 'HTS'],
#  ['Huntsville', 'AL', 'USA', 'HSV'],
#  ['Huron', 'SD', 'USA', 'HON'],
#  ['Hyannis', 'MA', 'USA', 'HYA'],
#  ['Idaho Falls', 'ID', 'USA', 'IDA'],
#  ['Indianapolis', 'IN', 'USA', 'IND'],
#  ['International Falls', 'MN', 'USA', 'INL'],
#  ['Inyokern', 'CA', 'USA', 'IYK'],
#  ['Iqaluit', 'Nunavut', 'Canada', 'YFB'],
#  ['Iron Mountain', 'MI', 'USA', 'IMT'],
#  ['Ironwood', 'MI', 'USA', 'IWD'],
#  ['Islip', 'NY', 'USA', 'ISP'],
#  ['Ithaca', 'NY', 'USA', 'ITH'],
#  ['Jackson Hole', 'WY', 'USA', 'JAC'],
#  ['Jackson', 'MS', 'USA', 'JAN'],
#  ['Jackson', 'TN', 'USA', 'MKL'],
#  ['Jacksonville', 'FL', 'USA', 'JAX'],
#  ['Jacksonville', 'NC', 'USA', 'OAJ'],
#  ['Jamestown', 'ND', 'USA', 'JMS'],
#  ['Jamestown', 'NY', 'USA', 'JHW'],
#  ['Johnstown', 'PA', 'USA', 'JST'],
#  ['Jonesboro', 'AR', 'USA', 'JBR'],
#  ['Joplin', 'MO', 'USA', 'JLN'],
#  ['Juneau', 'AK', 'USA', 'JNU'],
#  ['"Kahului, Maui"', 'HI', 'USA', 'OGG'],
#  ['Kailua-Kona', 'Hawaii', 'USA', 'Big'],
#  ['Kalamazoo', 'MI', 'USA', 'AZO'],
#  ['"Kalaupapa, Molokai"', 'HI', 'USA', 'LUP'],
#  ['Kalispell', 'MT', 'USA', 'FCA'],
#  ['Kamloops', 'BC', 'Canada', 'YKA'],
#  ['Kamuela', 'Hawaii', 'USA', 'Big'],
#  ['Kansas City', 'MO', 'USA', 'MCI'],
#  ['"Kapalua, Maui"', 'HI', 'USA', 'JHM'],
#  ['Kearney', 'NE', 'USA', 'EAR'],
#  ['Kelowna', 'BC', 'Canada', 'YLW'],
#  ['Kenai', 'AK', 'USA', 'ENA'],
#  ['Kenora', 'ON', 'Canada', 'YQK'],
#  ['Ketchikan', 'AK', 'USA', 'KTN'],
#  ['Key West', 'FL', 'USA', 'EYW'],
#  ['Killeen', 'TX', 'USA', 'GRK'],
#  ['King Salmon', 'AK', 'USA', 'AKN'],
#  ['Kingman', 'AZ', 'USA', 'IGM'],
#  ['Kingston', 'ON', 'Canada', 'YGK'],
#  ['Kirksville', 'MO', 'USA', 'IRK'],
#  ['Klamath Falls', 'OR', 'USA', 'LMT'],
#  ['Knoxville', 'TN', 'USA', 'TYS'],
#  ['Kodiak', 'AK', 'USA', 'ADQ'],
#  ['La Crosse', 'WI', 'USA', 'LSE'],
#  ['Lafayette', 'LA', 'USA', 'LFT'],
#  ['Lake Charles', 'LA', 'USA', 'LCH'],
#  ['Lake Havasu City', 'AZ', 'USA', 'HII'],
#  ['"Lanai City, Lanai"', 'HI', 'USA', 'LNY'],
#  ['Lancaster', 'PA', 'USA', 'LNS'],
#  ['Lansing', 'MI', 'USA', 'LAN'],
#  ['Laramie', 'WY', 'USA', 'LAR'],
#  ['Laredo', 'TX', 'USA', 'LRD'],
#  ['Las Cruces', 'NM', 'USA', 'LRU'],
#  ['Las Vegas', 'NV', 'USA', 'LAS'],
#  ['Latrobe', 'PA', 'USA', 'LBE'],
#  ['Laurel', 'MS', 'USA', 'PIB'],
#  ['Lawton', 'OK', 'USA', 'LAW'],
#  ['Lebanon', 'NH', 'USA', 'LEB'],
#  ['Lethbridge', 'AB', 'Canada', 'YQL'],
#  ['Lewiston', 'ID', 'USA', 'LWS'],
#  ['Lewiston', 'ME', 'USA', 'LEW'],
#  ['Lewistown', 'MT', 'USA', 'LWT'],
#  ['Lexington', 'KY', 'USA', 'LEX'],
#  ['Liberal', 'KS', 'USA', 'LBL'],
#  ['"Lihue, Kauai"', 'HI', 'USA', 'LIH'],
#  ['Lincoln', 'NE', 'USA', 'LNK'],
#  ['Little Rock', 'AR', 'USA', 'LIT'],
#  ['London', 'ON', 'Canada', 'YXU'],
#  ['Long Beach', 'CA', 'USA', 'LGB'],
#  ['Longview', 'TX', 'USA', 'GGG'],
#  ['Los Angeles', 'CA', 'USA', 'QLA'],
#  ['Los Angeles', 'CA', 'USA', 'LAX'],
#  ['Louisville', 'KY', 'USA', 'SDF'],
#  ['Lubbock', 'TX', 'USA', 'LBB'],
#  ['Lynchburg', 'VA', 'USA', 'LYH'],
#  ['Macon', 'GA', 'USA', 'MCN'],
#  ['Madison', 'WI', 'USA', 'MSN'],
#  ['Manchester', 'NH', 'USA', 'MHT'],
#  ['Manhattan', 'KS', 'USA', 'MHK'],
#  ['Manistee', 'MI', 'USA', 'MBL'],
#  ['Marion', 'IL', 'USA', 'MWA'],
#  ['Marquette', 'MI', 'USA', 'MQT'],
#  ["Martha's Vineyard", 'MA', 'USA', 'MVY'],
#  ['Mason City', 'IA', 'USA', 'MCW'],
#  ['Massena', 'NY', 'USA', 'MSS'],
#  ['McAllen', 'TX', 'USA', 'MFE'],
#  ['McCook', 'NE', 'USA', 'MCK'],
#  ['Medford', 'OR', 'USA', 'MFR'],
#  ['Medicine Hat', 'AB', 'Canada', 'YXH'],
#  ['Melbourne', 'FL', 'USA', 'MLB'],
#  ['Memphis', 'TN', 'USA', 'MEM'],
#  ['Meridian', 'MS', 'USA', 'MEI'],
#  ['Miami', 'FL', 'USA', 'MIA'],
#  ['Midland', 'TX', 'USA', 'MAF'],
#  ['Miles City', 'MT', 'USA', 'MLS'],
#  ['Milwaukee', 'WI', 'USA', 'MKE'],
#  ['Minneapolis', 'MN', 'USA', 'MSP'],
#  ['Minot', 'ND', 'USA', 'MOT'],
#  ['Missoula', 'MT', 'USA', 'MSO'],
#  ['Mobile', 'AL', 'USA', 'MOB'],
#  ['Modesto', 'CA', 'USA', 'MOD'],
#  ['Moline', 'IL', 'USA', 'MLI'],
#  ['Moncton', 'NB', 'Canada', 'YQM'],
#  ['Monroe', 'LA', 'USA', 'MLU'],
#  ['Mont-Joli', 'PQ', 'Canada', 'YYY'],
#  ['Monterey', 'CA', 'USA', 'MRY'],
#  ['Montgomery', 'AL', 'USA', 'MGM'],
#  ['Montreal', 'PQ', 'Canada', 'YUL'],
#  ['Montreal', 'PQ', 'Canada', 'YMQ'],
#  ['Montrose', 'CO', 'USA', 'MTJ'],
#  ['Morgantown', 'WV', 'USA', 'MGW'],
#  ['Moses Lake', 'WA', 'USA', 'MWH'],
#  ['Muscle Shoals', 'AL', 'USA', 'MSL'],
#  ['Muskegon', 'MI', 'USA', 'MKG'],
#  ['Myrtle Beach', 'SC', 'USA', 'MYR'],
#  ['Nanaimo', 'BC', 'Canada', 'YCD'],
#  ['Nantucket', 'MA', 'USA', 'ACK'],
#  ['Naples', 'FL', 'USA', 'APF'],
#  ['Nashville', 'TN', 'USA', 'BNA'],
#  ['New Bern', 'NC', 'USA', 'EWN'],
#  ['New Haven', 'CT', 'USA', 'HVN'],
#  ['New Orleans', 'LA', 'USA', 'MSY'],
#  ['New York', 'NY', 'USA', 'JFK'],
#  ['New York', 'NY', 'USA', 'NYC'],
#  ['New York', 'NY', 'USA', 'LGA'],
#  ['Newark', 'NJ', 'USA', 'EWR'],
#  ['Newburgh', 'NY', 'USA', 'SWF'],
#  ['Newport News', 'VA', 'USA', 'PHF'],
#  ['Nome', 'AK', 'USA', 'OME'],
#  ['Norfolk', 'VA', 'USA', 'ORF'],
#  ['North Bay', 'ON', 'Canada', 'YYB'],
#  ['North Bend', 'OR', 'USA', 'OTH'],
#  ['North Platte', 'NE', 'USA', 'LBF'],
#  ['Oakland', 'CA', 'USA', 'OAK'],
#  ['Ogdensburg', 'NY', 'USA', 'OGS'],
#  ['Oklahoma City', 'OK', 'USA', 'OKC'],
#  ['Omaha', 'NE', 'USA', 'OMA'],
#  ['Ontario', 'CA', 'USA', 'ONT'],
#  ['Orange County', 'CA', 'USA', 'SNA'],
#  ['Orlando', 'FL', 'USA', 'MCO'],
#  ['Oshkosh', 'WI', 'USA', 'OSH'],
#  ['Ottawa', 'ON', 'Canada', 'YOW'],
#  ['Owensboro', 'KY', 'USA', 'OWB'],
#  ['Oxnard', 'CA', 'USA', 'OXR'],
#  ['Paducah', 'KY', 'USA', 'PAH'],
#  ['Page', 'AZ', 'USA', 'PGA'],
#  ['Palm Springs', 'CA', 'USA', 'PSP'],
#  ['Panama City', 'FL', 'USA', 'PFN'],
#  ['Parkersburg', 'WV', 'USA', 'PKB'],
#  ['Pasco', 'WA', 'USA', 'PSC'],
#  ['Pellston', 'MI', 'USA', 'PLN'],
#  ['Pendleton', 'OR', 'USA', 'PDT'],
#  ['Pensacola', 'FL', 'USA', 'PNS'],
#  ['Penticton', 'BC', 'Canada', 'YYF'],
#  ['Peoria', 'IL', 'USA', 'PIA'],
#  ['Philadelphia', 'PA', 'USA', 'PHL'],
#  ['Phoenix', 'AZ', 'USA', 'PHX'],
#  ['Pierre', 'SD', 'USA', 'PIR'],
#  ['Pinehurst', 'NC', 'USA', 'SOP'],
#  ['Pittsburgh', 'PA', 'USA', 'PIT'],
#  ['Pocatello', 'ID', 'USA', 'PIH'],
#  ['Ponca City', 'OK', 'USA', 'PNC'],
#  ['Port Hardy', 'BC', 'Canada', 'YZT'],
#  ['Portland', 'ME', 'USA', 'PWM'],
#  ['Portland', 'OR', 'USA', 'PDX'],
#  ['Portsmouth', 'NH', 'USA', 'PSM'],
#  ['Powell River', 'BC', 'Canada', 'YPW'],
#  ['Prescott', 'AZ', 'USA', 'PRC'],
#  ['Presque Isle', 'ME', 'USA', 'PQI'],
#  ['Prince George', 'BC', 'Canada', 'YXS'],
#  ['Prince Rupert', 'BC', 'Canada', 'YPR'],
#  ['Providence', 'RI', 'USA', 'PVD'],
#  ['Provincetown', 'MA', 'USA', 'PVC'],
#  ['Pueblo', 'CO', 'USA', 'PUB'],
#  ['Pullman', 'WA', 'USA', 'PUW'],
#  ['Quebec', 'PQ', 'Canada', 'YQB'],
#  ['Quesnel', 'BC', 'Canada', 'YQZ'],
#  ['Quincy', 'IL', 'USA', 'UIN'],
#  ['Raleigh', 'NC', 'USA', 'RDU'],
#  ['Rankin Inlet', 'NWT', 'Canada', 'YRT'],
#  ['Rapid City', 'SD', 'USA', 'RAP'],
#  ['Red Lake', 'ON', 'Canada', 'YRL'],
#  ['Redding', 'CA', 'USA', 'RDD'],
#  ['Redmond', 'OR', 'USA', 'RDM'],
#  ['Regina', 'SK', 'Canada', 'YQR'],
#  ['Reno', 'NV', 'USA', 'RNO'],
#  ['Rhinelander', 'WI', 'USA', 'RHI'],
#  ['Richmond', 'VA', 'USA', 'RIC'],
#  ['Riverton', 'WY', 'USA', 'RIW'],
#  ['Roanoke', 'VA', 'USA', 'ROA'],
#  ['Roberval', 'PQ', 'Canada', 'YRJ'],
#  ['Rochester', 'MN', 'USA', 'RST'],
#  ['Rochester', 'NY', 'USA', 'ROC'],
#  ['Rock Springs', 'WY', 'USA', 'RKS'],
#  ['Rockford', 'IL', 'USA', 'RFD'],
#  ['Rockland', 'ME', 'USA', 'RKD'],
#  ['Roswell', 'NM', 'USA', 'ROW'],
#  ['Rouyn-Noranda', 'PQ', 'Canada', 'YUY'],
#  ['Rutland', 'VT', 'USA', 'RUT'],
#  ['Sacramento', 'CA', 'USA', 'SMF'],
#  ['Saginaw', 'MI', 'USA', 'MBS'],
#  ['Saint John', 'NB', 'Canada', 'YSJ'],
#  ['Salina', 'KS', 'USA', 'SLN'],
#  ['Salisbury', 'MD', 'USA', 'SBY'],
#  ['Salt Lake City', 'UT', 'USA', 'SLC'],
#  ['San Angelo', 'TX', 'USA', 'SJT'],
#  ['San Antonio', 'TX', 'USA', 'SAT'],
#  ['San Diego', 'CA', 'USA', 'SAN'],
#  ['San Francisco', 'CA', 'USA', 'QSF'],
#  ['San Francisco', 'CA', 'USA', 'SFO'],
#  ['San Jose', 'CA', 'USA', 'SJC'],
#  ['San Luis Obispo', 'CA', 'USA', 'SBP'],
#  ['Sand Point', 'AK', 'USA', 'SDP'],
#  ['"Sandspit, Queen Charlotte Islands"', 'BC', 'Canada', 'YZP'],
#  ['Santa Barbara', 'CA', 'USA', 'SBA'],
#  ['Santa Fe', 'NM', 'USA', 'SAF'],
#  ['Santa Maria', 'CA', 'USA', 'SMX'],
#  ['Santa Rosa', 'CA', 'USA', 'STS'],
#  ['Saranac Lake', 'NY', 'USA', 'SLK'],
#  ['Sarasota', 'FL', 'USA', 'SRQ'],
#  ['Sarnia', 'ON', 'Canada', 'YZR'],
#  ['Saskatoon', 'SK', 'Canada', 'YXE'],
#  ['Sault Ste. Marie', 'MI', 'USA', 'CIU'],
#  ['Sault Ste. Marie', 'ON', 'Canada', 'YAM'],
#  ['Savannah', 'GA', 'USA', 'SAV'],
#  ['Scottsbluff', 'NE', 'USA', 'BFF'],
#  ['Seattle', 'WA', 'USA', 'SEA'],
#  ['Sept-Iles', 'PQ', 'Canada', 'YZV'],
#  ['Shenandoah Valley Airport', 'VA', 'USA', 'SHD'],
#  ['Sheridan', 'WY', 'USA', 'SHR'],
#  ['Shreveport', 'LA', 'USA', 'SHV'],
#  ['Sidney', 'MT', 'USA', 'SDY'],
#  ['Silver City', 'NM', 'USA', 'SVC'],
#  ['Sioux City', 'IA', 'USA', 'SUX'],
#  ['Sioux Falls', 'SD', 'USA', 'FSD'],
#  ['Sioux Lookout', 'ON', 'Canada', 'YXL'],
#  ['Sitka', 'AK', 'USA', 'SIT'],
#  ['Skagway', 'AK', 'USA', 'SGY'],
#  ['Smithers', 'BC', 'Canada', 'YYD'],
#  ['South Bend', 'IN', 'USA', 'SBN'],
#  ['Spokane', 'WA', 'USA', 'GEG'],
#  ['Springfield', 'IL', 'USA', 'SPI'],
#  ['Springfield', 'MA', 'USA', 'CEF'],
#  ['Springfield', 'MO', 'USA', 'SGF'],
#  ['Springfield', 'VT', 'USA', 'VSF'],
#  ['St. Cloud', 'MN', 'USA', 'STC'],
#  ['St. George', 'UT', 'USA', 'SGU'],
#  ["St. John's", 'NF', 'Canada', 'YYT'],
#  ['St. Louis', 'MO', 'USA', 'STL'],
#  ['St. Petersburg', 'FL', 'USA', 'PIE'],
#  ['State College', 'PA', 'USA', 'SCE'],
#  ['Steamboat Springs', 'CO', 'USA', 'SBS'],
#  ['Sudbury', 'ON', 'Canada', 'YSB'],
#  ['Sun Valley', 'ID', 'USA', 'SUN'],
#  ['"Sydney, Cape Breton Island"', 'NS', 'Canada', 'YQY'],
#  ['Syracuse', 'NY', 'USA', 'SYR'],
#  ['Tallahassee', 'FL', 'USA', 'TLH'],
#  ['Tampa', 'FL', 'USA', 'TPA'],
#  ['Telluride', 'CO', 'USA', 'TEX'],
#  ['Terrace', 'BC', 'Canada', 'YXT'],
#  ['Texarkana', 'AR', 'USA', 'TXK'],
#  ['Thief River Falls', 'MN', 'USA', 'TVF'],
#  ['Thompson', 'MB', 'Canada', 'YTH'],
#  ['Thunder Bay', 'ON', 'Canada', 'YQT'],
#  ['Timmins', 'ON', 'Canada', 'YTS'],
#  ['Toksook Bay', 'AK', 'USA', 'OOK'],
#  ['Toledo', 'OH', 'USA', 'TOL'],
#  ['Eureka', 'KS', 'USA', 'TOP'],
#  ['Toronto', 'ON', 'Canada', 'YYZ'],
#  ['Toronto', 'ON', 'Canada', 'YTZ'],
#  ['Toronto', 'ON', 'Canada', 'YTO'],
#  ['Traverse City', 'MI', 'USA', 'TVC'],
#  ['Trenton', 'NJ', 'USA', 'TTN'],
#  ['Tri-City Airport', 'TN', 'USA', 'TRI'],
#  ['Tucson', 'AZ', 'USA', 'TUS'],
#  ['Tulsa', 'OK', 'USA', 'TUL'],
#  ['Tupelo', 'MS', 'USA', 'TUP'],
#  ['Twin Falls', 'ID', 'USA', 'TWF'],
#  ['Tyler', 'TX', 'USA', 'TYR'],
#  ['Unalakleet', 'AK', 'USA', 'UNK'],
#  ['Vail', 'CO', 'USA', 'EGE'],
#  ["Val-d'Or", 'PQ', 'Canada', 'YVO'],
#  ['Valdez', 'AK', 'USA', 'VDZ'],
#  ['Valdosta', 'GA', 'USA', 'VLD'],
#  ['Vancouver', 'BC', 'Canada', 'YVR'],
#  ['Victoria', 'BC', 'Canada', 'YYJ'],
#  ['Victoria', 'TX', 'USA', 'VCT'],
#  ['Visalia', 'CA', 'USA', 'VIS'],
#  ['"Wabush, Labrador"', 'NF', 'Canada', 'YWK'],
#  ['Waco', 'TX', 'USA', 'ACT'],
#  ['Walla Walla', 'WA', 'USA', 'ALW'],
#  ['Washington DC', '', 'USA', 'IAD'],
#  ['Washington DC', '', 'USA', 'DCA'],
#  ['Washington DC', '', 'USA', 'WAS'],
#  ['Waterloo', 'IA', 'USA', 'ALO'],
#  ['Watertown', 'NY', 'USA', 'ART'],
#  ['Watertown', 'SD', 'USA', 'ATY'],
#  ['Wausau', 'WI', 'USA', 'CWA'],
#  ['Wenatchee', 'WA', 'USA', 'EAT'],
#  ['West Palm Beach', 'FL', 'USA', 'PBI'],
#  ['West Yellowstone', 'MT', 'USA', 'WYS'],
#  ['White Plains', 'NY', 'USA', 'HPN'],
#  ['Whitehorse', 'YT', 'Canada', 'YXY'],
#  ['Wichita Falls', 'TX', 'USA', 'SPS'],
#  ['Wichita', 'KS', 'USA', 'ICT'],
#  ['Wilkes-Barre', 'PA', 'USA', 'AVP'],
#  ['Williams Lake', 'BC', 'Canada', 'YWL'],
#  ['Williamsport', 'PA', 'USA', 'IPT'],
#  ['Williston', 'ND', 'USA', 'ISN'],
#  ['Wilmington', 'DE', 'USA', 'ILG'],
#  ['Wilmington', 'NC', 'USA', 'ILM'],
#  ['Windsor', 'ON', 'Canada', 'YQG'],
#  ['Winnipeg', 'MB', 'Canada', 'YWG'],
#  ['Wolf Point', 'MT', 'USA', 'OLF'],
#  ['Worland', 'WY', 'USA', 'WRL'],
#  ['Wrangell', 'AK', 'USA', 'WRG'],
#  ['Yakima', 'WA', 'USA', 'YKM'],
#  ['Yakutat', 'AK', 'USA', 'YAK'],
#  ['Yellowknife', 'NWT', 'Canada', 'YZF'],
#  ['Yuma', 'AZ', 'USA', 'YUM']]

# %%
aiportRDD.take(5)
# Out:
# [['City', 'State', 'Country', 'IATA'],
#  ['Abbotsford', 'BC', 'Canada', 'YXX'],
#  ['Aberdeen', 'SD', 'USA', 'ABR'],
#  ['Abilene', 'TX', 'USA', 'ABI'],
#  ['Akron', 'OH', 'USA', 'CAK']]

# %%
aiportRDD.count()
# Out:
# 527

# %%
#Number of partitin
aiportRDD.getNumPartitions()
# Out:
# 4

# %%
#Departure RDD
departureRDD = (sc.textFile('departure_delays.csv').map(lambda element: element.split(",")))
departureRDD.collect()
# Out:
# [['date', 'delay', 'distance', 'origin', 'destination'],
#  ['01011245', '6', '602', 'ABE', 'ATL'],
#  ['01020600', '-8', '369', 'ABE', 'DTW'],
#  ['01021245', '-2', '602', 'ABE', 'ATL'],
#  ['01020605', '-4', '602', 'ABE', 'ATL'],
#  ['01031245', '-4', '602', 'ABE', 'ATL'],
#  ['01030605', '0', '602', 'ABE', 'ATL'],
#  ['01041243', '10', '602', 'ABE', 'ATL'],
#  ['01040605', '28', '602', 'ABE', 'ATL'],
#  ['01051245', '88', '602', 'ABE', 'ATL'],
#  ['01050605', '9', '602', 'ABE', 'ATL'],
#  ['01061215', '-6', '602', 'ABE', 'ATL'],
#  ['01061725', '69', '602', 'ABE', 'ATL'],
#  ['01061230', '0', '369', 'ABE', 'DTW'],
#  ['01060625', '-3', '602', 'ABE', 'ATL'],
#  ['01070600', '0', '369', 'ABE', 'DTW'],
#  ['01071725', '0', '602', 'ABE', 'ATL'],
#  ['01071230', '0', '369', 'ABE', 'DTW'],
#  ['01070625', '0', '602', 'ABE', 'ATL'],
#  ['01071219', '0', '569', 'ABE', 'ORD'],
#  ['01080600', '0', '369', 'ABE', 'DTW'],
#  ['01081230', '33', '369', 'ABE', 'DTW'],
#  ['01080625', '1', '602', 'ABE', 'ATL'],
#  ['01080607', '5', '569', 'ABE', 'ORD'],
#  ['01081219', '54', '569', 'ABE', 'ORD'],
#  ['01091215', '43', '602', 'ABE', 'ATL'],
#  ['01090600', '151', '369', 'ABE', 'DTW'],
#  ['01091725', '0', '602', 'ABE', 'ATL'],
#  ['01091230', '-4', '369', 'ABE', 'DTW'],
#  ['01090625', '8', '602', 'ABE', 'ATL'],
#  ['01091219', '83', '569', 'ABE', 'ORD'],
#  ['01101215', '-5', '602', 'ABE', 'ATL'],
#  ['01100600', '-5', '369', 'ABE', 'DTW'],
#  ['01101725', '7', '602', 'ABE', 'ATL'],
#  ['01101230', '-8', '369', 'ABE', 'DTW'],
#  ['01100625', '52', '602', 'ABE', 'ATL'],
#  ['01101219', '0', '569', 'ABE', 'ORD'],
#  ['01111215', '127', '602', 'ABE', 'ATL'],
#  ['01110600', '-9', '369', 'ABE', 'DTW'],
#  ['01110625', '-4', '602', 'ABE', 'ATL'],
#  ['01121215', '-5', '602', 'ABE', 'ATL'],
#  ['01121725', '-1', '602', 'ABE', 'ATL'],
#  ['01131215', '14', '602', 'ABE', 'ATL'],
#  ['01130600', '-7', '369', 'ABE', 'DTW'],
#  ['01131725', '-6', '602', 'ABE', 'ATL'],
#  ['01131230', '-13', '369', 'ABE', 'DTW'],
#  ['01130625', '29', '602', 'ABE', 'ATL'],
#  ['01131219', '-8', '569', 'ABE', 'ORD'],
#  ['01140600', '-9', '369', 'ABE', 'DTW'],
#  ['01141725', '-9', '602', 'ABE', 'ATL'],
#  ['01141230', '-8', '369', 'ABE', 'DTW'],
#  ['01140625', '-5', '602', 'ABE', 'ATL'],
#  ['01141219', '-10', '569', 'ABE', 'ORD'],
#  ['01150600', '0', '369', 'ABE', 'DTW'],
#  ['01151725', '-6', '602', 'ABE', 'ATL'],
#  ['01151230', '0', '369', 'ABE', 'DTW'],
#  ['01150625', '0', '602', 'ABE', 'ATL'],
#  ['01150607', '0', '569', 'ABE', 'ORD'],
#  ['01151219', '0', '569', 'ABE', 'ORD'],
#  ['01161215', '-10', '602', 'ABE', 'ATL'],
#  ['01160600', '-1', '369', 'ABE', 'DTW'],
#  ['01161725', '-6', '602', 'ABE', 'ATL'],
#  ['01161230', '-7', '369', 'ABE', 'DTW'],
#  ['01160625', '-4', '602', 'ABE', 'ATL'],
#  ['01161219', '68', '569', 'ABE', 'ORD'],
#  ['01171215', '-8', '602', 'ABE', 'ATL'],
#  ['01170600', '-5', '369', 'ABE', 'DTW'],
#  ['01171725', '5', '602', 'ABE', 'ATL'],
#  ['01171230', '-10', '369', 'ABE', 'DTW'],
#  ['01170625', '-6', '602', 'ABE', 'ATL'],
#  ['01171219', '-10', '569', 'ABE', 'ORD'],
#  ['01181215', '-12', '602', 'ABE', 'ATL'],
#  ['01180600', '-13', '369', 'ABE', 'DTW'],
#  ['01180625', '0', '602', 'ABE', 'ATL'],
#  ['01191215', '-16', '602', 'ABE', 'ATL'],
#  ['01191725', '-5', '602', 'ABE', 'ATL'],
#  ['01201215', '-8', '602', 'ABE', 'ATL'],
#  ['01201725', '-5', '602', 'ABE', 'ATL'],
#  ['01201230', '-11', '369', 'ABE', 'DTW'],
#  ['01200625', '-7', '602', 'ABE', 'ATL'],
#  ['01201219', '-6', '569', 'ABE', 'ORD'],
#  ['01210600', '89', '369', 'ABE', 'DTW'],
#  ['01211725', '0', '602', 'ABE', 'ATL'],
#  ['01211230', '44', '369', 'ABE', 'DTW'],
#  ['01210625', '-6', '602', 'ABE', 'ATL'],
#  ['01211219', '9', '569', 'ABE', 'ORD'],
#  ['01220600', '80', '369', 'ABE', 'DTW'],
#  ['01221230', '-5', '369', 'ABE', 'DTW'],
#  ['01220625', '333', '602', 'ABE', 'ATL'],
#  ['01220607', '219', '569', 'ABE', 'ORD'],
#  ['01221219', '15', '569', 'ABE', 'ORD'],
#  ['01231215', '-12', '602', 'ABE', 'ATL'],
#  ['01230600', '-3', '369', 'ABE', 'DTW'],
#  ['01231725', '180', '602', 'ABE', 'ATL'],
#  ['01231230', '-5', '369', 'ABE', 'DTW'],
#  ['01230625', '-8', '602', 'ABE', 'ATL'],
#  ['01231219', '-13', '569', 'ABE', 'ORD'],
#  ['01241215', '-11', '602', 'ABE', 'ATL'],
#  ['01240600', '-3', '369', 'ABE', 'DTW'],
#  ['01241725', '2', '602', 'ABE', 'ATL'],
#  ['01241230', '-5', '369', 'ABE', 'DTW'],
#  ['01240625', '-3', '602', 'ABE', 'ATL'],
#  ['01241219', '0', '569', 'ABE', 'ORD'],
#  ['01251215', '2', '602', 'ABE', 'ATL'],
#  ['01250600', '-4', '369', 'ABE', 'DTW'],
#  ['01250625', '-4', '602', 'ABE', 'ATL'],
#  ['01261215', '1', '602', 'ABE', 'ATL'],
#  ['01261725', '7', '602', 'ABE', 'ATL'],
#  ['01271215', '-4', '602', 'ABE', 'ATL'],
#  ['01270600', '-9', '369', 'ABE', 'DTW'],
#  ['01271725', '-8', '602', 'ABE', 'ATL'],
#  ['01271230', '-7', '369', 'ABE', 'DTW'],
#  ['01270625', '-1', '602', 'ABE', 'ATL'],
#  ['01271219', '0', '569', 'ABE', 'ORD'],
#  ['01280600', '-6', '369', 'ABE', 'DTW'],
#  ['01281725', '-3', '602', 'ABE', 'ATL'],
#  ['01281230', '-8', '369', 'ABE', 'DTW'],
#  ['01280625', '-4', '602', 'ABE', 'ATL'],
#  ['01281219', '0', '569', 'ABE', 'ORD'],
#  ['01290600', '0', '369', 'ABE', 'DTW'],
#  ['01291230', '0', '369', 'ABE', 'DTW'],
#  ['01290625', '4', '602', 'ABE', 'ATL'],
#  ['01290607', '92', '569', 'ABE', 'ORD'],
#  ['01291219', '-10', '569', 'ABE', 'ORD'],
#  ['01301215', '0', '602', 'ABE', 'ATL'],
#  ['01300600', '-1', '369', 'ABE', 'DTW'],
#  ['01301725', '10', '602', 'ABE', 'ATL'],
#  ['01301230', '0', '369', 'ABE', 'DTW'],
#  ['01300625', '0', '602', 'ABE', 'ATL'],
#  ['01301219', '-11', '569', 'ABE', 'ORD'],
#  ['01311215', '1', '602', 'ABE', 'ATL'],
#  ['01310600', '-4', '369', 'ABE', 'DTW'],
#  ['01311725', '25', '602', 'ABE', 'ATL'],
#  ['01311230', '-4', '369', 'ABE', 'DTW'],
#  ['01310625', '-5', '602', 'ABE', 'ATL'],
#  ['01311219', '24', '569', 'ABE', 'ORD'],
#  ['01011400', '26', '137', 'ABI', 'DFW'],
#  ['01011525', '-11', '137', 'ABI', 'DFW'],
#  ['01021400', '-5', '137', 'ABI', 'DFW'],
#  ['01021525', '47', '137', 'ABI', 'DFW'],
#  ['01031400', '-12', '137', 'ABI', 'DFW'],
#  ['01031525', '40', '137', 'ABI', 'DFW'],
#  ['01041400', '-12', '137', 'ABI', 'DFW'],
#  ['01041525', '3', '137', 'ABI', 'DFW'],
#  ['01051400', '-5', '137', 'ABI', 'DFW'],
#  ['01051525', '-5', '137', 'ABI', 'DFW'],
#  ['01061400', '2', '137', 'ABI', 'DFW'],
#  ['01061525', '22', '137', 'ABI', 'DFW'],
#  ['01071400', '-12', '137', 'ABI', 'DFW'],
#  ['01071525', '-15', '137', 'ABI', 'DFW'],
#  ['01081525', '21', '137', 'ABI', 'DFW'],
#  ['01091525', '-8', '137', 'ABI', 'DFW'],
#  ['01101525', '4', '137', 'ABI', 'DFW'],
#  ['01111525', '-23', '137', 'ABI', 'DFW'],
#  ['01121525', '-9', '137', 'ABI', 'DFW'],
#  ['01131525', '-12', '137', 'ABI', 'DFW'],
#  ['01141525', '-5', '137', 'ABI', 'DFW'],
#  ['01151525', '-17', '137', 'ABI', 'DFW'],
#  ['01161525', '2', '137', 'ABI', 'DFW'],
#  ['01171525', '-9', '137', 'ABI', 'DFW'],
#  ['01181525', '-5', '137', 'ABI', 'DFW'],
#  ['01191525', '-3', '137', 'ABI', 'DFW'],
#  ['01201525', '-6', '137', 'ABI', 'DFW'],
#  ['01211525', '-17', '137', 'ABI', 'DFW'],
#  ['01221525', '40', '137', 'ABI', 'DFW'],
#  ['01231525', '-12', '137', 'ABI', 'DFW'],
#  ['01241525', '21', '137', 'ABI', 'DFW'],
#  ['01251525', '-6', '137', 'ABI', 'DFW'],
#  ['01261525', '-12', '137', 'ABI', 'DFW'],
#  ['01271525', '-13', '137', 'ABI', 'DFW'],
#  ['01281525', '-10', '137', 'ABI', 'DFW'],
#  ['01291525', '146', '137', 'ABI', 'DFW'],
#  ['01301525', '-13', '137', 'ABI', 'DFW'],
#  ['01311525', '6', '137', 'ABI', 'DFW'],
#  ['01010925', '-9', '137', 'ABI', 'DFW'],
#  ['01011730', '72', '137', 'ABI', 'DFW'],
#  ['01010700', '-5', '137', 'ABI', 'DFW'],
#  ['01011155', '-6', '137', 'ABI', 'DFW'],
#  ['01010810', '62', '137', 'ABI', 'DFW'],
#  ['01020550', '-7', '137', 'ABI', 'DFW'],
#  ['01020925', '7', '137', 'ABI', 'DFW'],
#  ['01021730', '27', '137', 'ABI', 'DFW'],
#  ['01020700', '150', '137', 'ABI', 'DFW'],
#  ['01021155', '0', '137', 'ABI', 'DFW'],
#  ['01020810', '1', '137', 'ABI', 'DFW'],
#  ['01030550', '51', '137', 'ABI', 'DFW'],
#  ['01030925', '-7', '137', 'ABI', 'DFW'],
#  ['01031730', '-18', '137', 'ABI', 'DFW'],
#  ['01030700', '2', '137', 'ABI', 'DFW'],
#  ['01031155', '48', '137', 'ABI', 'DFW'],
#  ['01030810', '-3', '137', 'ABI', 'DFW'],
#  ['01040925', '-7', '137', 'ABI', 'DFW'],
#  ['01041730', '135', '137', 'ABI', 'DFW'],
#  ['01040700', '-3', '137', 'ABI', 'DFW'],
#  ['01041155', '-2', '137', 'ABI', 'DFW'],
#  ['01040810', '-12', '137', 'ABI', 'DFW'],
#  ['01050550', '-8', '137', 'ABI', 'DFW'],
#  ['01050925', '-10', '137', 'ABI', 'DFW'],
#  ['01051730', '-2', '137', 'ABI', 'DFW'],
#  ['01050700', '-6', '137', 'ABI', 'DFW'],
#  ['01051155', '-2', '137', 'ABI', 'DFW'],
#  ['01050810', '-12', '137', 'ABI', 'DFW'],
#  ['01060550', '-8', '137', 'ABI', 'DFW'],
#  ['01060925', '0', '137', 'ABI', 'DFW'],
#  ['01061730', '-7', '137', 'ABI', 'DFW'],
#  ['01060700', '-3', '137', 'ABI', 'DFW'],
#  ['01061155', '-4', '137', 'ABI', 'DFW'],
#  ['01060810', '-8', '137', 'ABI', 'DFW'],
#  ['01070550', '-3', '137', 'ABI', 'DFW'],
#  ['01070925', '62', '137', 'ABI', 'DFW'],
#  ['01071730', '0', '137', 'ABI', 'DFW'],
#  ['01070700', '4', '137', 'ABI', 'DFW'],
#  ['01071155', '10', '137', 'ABI', 'DFW'],
#  ['01070810', '-10', '137', 'ABI', 'DFW'],
#  ['01080550', '-9', '137', 'ABI', 'DFW'],
#  ['01080925', '-11', '137', 'ABI', 'DFW'],
#  ['01081730', '7', '137', 'ABI', 'DFW'],
#  ['01080700', '-8', '137', 'ABI', 'DFW'],
#  ['01081155', '-11', '137', 'ABI', 'DFW'],
#  ['01080810', '-13', '137', 'ABI', 'DFW'],
#  ['01081400', '10', '137', 'ABI', 'DFW'],
#  ['01090550', '395', '137', 'ABI', 'DFW'],
#  ['01090925', '0', '137', 'ABI', 'DFW'],
#  ['01091730', '38', '137', 'ABI', 'DFW'],
#  ['01090700', '6', '137', 'ABI', 'DFW'],
#  ['01091155', '21', '137', 'ABI', 'DFW'],
#  ['01090810', '16', '137', 'ABI', 'DFW'],
#  ['01091400', '-6', '137', 'ABI', 'DFW'],
#  ['01100550', '-4', '137', 'ABI', 'DFW'],
#  ['01100925', '34', '137', 'ABI', 'DFW'],
#  ['01101730', '-2', '137', 'ABI', 'DFW'],
#  ['01100700', '129', '137', 'ABI', 'DFW'],
#  ['01101155', '-1', '137', 'ABI', 'DFW'],
#  ['01100810', '-11', '137', 'ABI', 'DFW'],
#  ['01101400', '30', '137', 'ABI', 'DFW'],
#  ['01110905', '-8', '137', 'ABI', 'DFW'],
#  ['01111730', '-14', '137', 'ABI', 'DFW'],
#  ['01110700', '-5', '137', 'ABI', 'DFW'],
#  ['01111155', '16', '137', 'ABI', 'DFW'],
#  ['01110810', '-6', '137', 'ABI', 'DFW'],
#  ['01111400', '39', '137', 'ABI', 'DFW'],
#  ['01120550', '-12', '137', 'ABI', 'DFW'],
#  ['01120925', '-5', '137', 'ABI', 'DFW'],
#  ['01121730', '-9', '137', 'ABI', 'DFW'],
#  ['01120700', '35', '137', 'ABI', 'DFW'],
#  ['01121155', '158', '137', 'ABI', 'DFW'],
#  ['01120810', '-9', '137', 'ABI', 'DFW'],
#  ['01121400', '-9', '137', 'ABI', 'DFW'],
#  ['01130550', '-5', '137', 'ABI', 'DFW'],
#  ['01130925', '-7', '137', 'ABI', 'DFW'],
#  ['01131730', '-9', '137', 'ABI', 'DFW'],
#  ['01130700', '-9', '137', 'ABI', 'DFW'],
#  ['01131155', '-10', '137', 'ABI', 'DFW'],
#  ['01130810', '-7', '137', 'ABI', 'DFW'],
#  ['01131400', '-1', '137', 'ABI', 'DFW'],
#  ['01140550', '0', '137', 'ABI', 'DFW'],
#  ['01140925', '4', '137', 'ABI', 'DFW'],
#  ['01141730', '-13', '137', 'ABI', 'DFW'],
#  ['01140700', '49', '137', 'ABI', 'DFW'],
#  ['01141155', '-10', '137', 'ABI', 'DFW'],
#  ['01140810', '-8', '137', 'ABI', 'DFW'],
#  ['01141400', '-17', '137', 'ABI', 'DFW'],
#  ['01150550', '-11', '137', 'ABI', 'DFW'],
#  ['01150925', '-6', '137', 'ABI', 'DFW'],
#  ['01151730', '-9', '137', 'ABI', 'DFW'],
#  ['01150700', '-8', '137', 'ABI', 'DFW'],
#  ['01151155', '-5', '137', 'ABI', 'DFW'],
#  ['01150810', '-12', '137', 'ABI', 'DFW'],
#  ['01151400', '-3', '137', 'ABI', 'DFW'],
#  ['01160550', '-2', '137', 'ABI', 'DFW'],
#  ['01160925', '-12', '137', 'ABI', 'DFW'],
#  ['01161730', '-3', '137', 'ABI', 'DFW'],
#  ['01160700', '-8', '137', 'ABI', 'DFW'],
#  ['01161155', '56', '137', 'ABI', 'DFW'],
#  ['01160810', '-10', '137', 'ABI', 'DFW'],
#  ['01161400', '8', '137', 'ABI', 'DFW'],
#  ['01170550', '-1', '137', 'ABI', 'DFW'],
#  ['01170925', '-6', '137', 'ABI', 'DFW'],
#  ['01171730', '-5', '137', 'ABI', 'DFW'],
#  ['01170700', '-12', '137', 'ABI', 'DFW'],
#  ['01171155', '18', '137', 'ABI', 'DFW'],
#  ['01170810', '-11', '137', 'ABI', 'DFW'],
#  ['01171400', '-7', '137', 'ABI', 'DFW'],
#  ['01180905', '-7', '137', 'ABI', 'DFW'],
#  ['01181730', '-9', '137', 'ABI', 'DFW'],
#  ['01180700', '-10', '137', 'ABI', 'DFW'],
#  ['01181155', '-11', '137', 'ABI', 'DFW'],
#  ['01180810', '-13', '137', 'ABI', 'DFW'],
#  ['01181400', '6', '137', 'ABI', 'DFW'],
#  ['01190550', '-12', '137', 'ABI', 'DFW'],
#  ['01190925', '-12', '137', 'ABI', 'DFW'],
#  ['01191730', '-12', '137', 'ABI', 'DFW'],
#  ['01190700', '-9', '137', 'ABI', 'DFW'],
#  ['01191155', '-11', '137', 'ABI', 'DFW'],
#  ['01190810', '-22', '137', 'ABI', 'DFW'],
#  ['01191400', '-12', '137', 'ABI', 'DFW'],
#  ['01200550', '-9', '137', 'ABI', 'DFW'],
#  ['01200925', '-8', '137', 'ABI', 'DFW'],
#  ['01201730', '-8', '137', 'ABI', 'DFW'],
#  ['01200700', '-8', '137', 'ABI', 'DFW'],
#  ['01201155', '-5', '137', 'ABI', 'DFW'],
#  ['01200810', '19', '137', 'ABI', 'DFW'],
#  ['01201400', '3', '137', 'ABI', 'DFW'],
#  ['01210550', '-7', '137', 'ABI', 'DFW'],
#  ['01210925', '29', '137', 'ABI', 'DFW'],
#  ['01211730', '-9', '137', 'ABI', 'DFW'],
#  ['01210700', '-2', '137', 'ABI', 'DFW'],
#  ['01211155', '0', '137', 'ABI', 'DFW'],
#  ['01210810', '-8', '137', 'ABI', 'DFW'],
#  ['01211400', '-11', '137', 'ABI', 'DFW'],
#  ['01220550', '-12', '137', 'ABI', 'DFW'],
#  ['01220925', '-8', '137', 'ABI', 'DFW'],
#  ['01221730', '-10', '137', 'ABI', 'DFW'],
#  ['01220700', '-8', '137', 'ABI', 'DFW'],
#  ['01221155', '-6', '137', 'ABI', 'DFW'],
#  ['01220810', '-8', '137', 'ABI', 'DFW'],
#  ['01221400', '-4', '137', 'ABI', 'DFW'],
#  ['01230550', '-10', '137', 'ABI', 'DFW'],
#  ['01230925', '15', '137', 'ABI', 'DFW'],
#  ['01231730', '-7', '137', 'ABI', 'DFW'],
#  ['01230700', '-8', '137', 'ABI', 'DFW'],
#  ['01231155', '-5', '137', 'ABI', 'DFW'],
#  ['01230810', '-3', '137', 'ABI', 'DFW'],
#  ['01231400', '37', '137', 'ABI', 'DFW'],
#  ['01240550', '-8', '137', 'ABI', 'DFW'],
#  ['01240925', '-7', '137', 'ABI', 'DFW'],
#  ['01241730', '61', '137', 'ABI', 'DFW'],
#  ['01240700', '-14', '137', 'ABI', 'DFW'],
#  ['01241155', '-6', '137', 'ABI', 'DFW'],
#  ['01240810', '-6', '137', 'ABI', 'DFW'],
#  ['01241400', '-7', '137', 'ABI', 'DFW'],
#  ['01250905', '-13', '137', 'ABI', 'DFW'],
#  ['01251730', '-14', '137', 'ABI', 'DFW'],
#  ['01250700', '-6', '137', 'ABI', 'DFW'],
#  ['01251155', '-5', '137', 'ABI', 'DFW'],
#  ['01250810', '-14', '137', 'ABI', 'DFW'],
#  ['01251400', '-26', '137', 'ABI', 'DFW'],
#  ['01260550', '-8', '137', 'ABI', 'DFW'],
#  ['01260925', '-8', '137', 'ABI', 'DFW'],
#  ['01261730', '-4', '137', 'ABI', 'DFW'],
#  ['01260700', '-9', '137', 'ABI', 'DFW'],
#  ['01261155', '-13', '137', 'ABI', 'DFW'],
#  ['01260810', '-9', '137', 'ABI', 'DFW'],
#  ['01261400', '-11', '137', 'ABI', 'DFW'],
#  ['01270550', '-7', '137', 'ABI', 'DFW'],
#  ['01270925', '-5', '137', 'ABI', 'DFW'],
#  ['01271730', '-3', '137', 'ABI', 'DFW'],
#  ['01270700', '-7', '137', 'ABI', 'DFW'],
#  ['01271155', '-6', '137', 'ABI', 'DFW'],
#  ['01270810', '-10', '137', 'ABI', 'DFW'],
#  ['01271400', '-9', '137', 'ABI', 'DFW'],
#  ['01280550', '0', '137', 'ABI', 'DFW'],
#  ['01280925', '-4', '137', 'ABI', 'DFW'],
#  ['01281730', '-10', '137', 'ABI', 'DFW'],
#  ['01280700', '-6', '137', 'ABI', 'DFW'],
#  ['01281155', '-4', '137', 'ABI', 'DFW'],
#  ['01280810', '-5', '137', 'ABI', 'DFW'],
#  ['01281400', '-6', '137', 'ABI', 'DFW'],
#  ['01290550', '-5', '137', 'ABI', 'DFW'],
#  ['01290925', '57', '137', 'ABI', 'DFW'],
#  ['01291730', '8', '137', 'ABI', 'DFW'],
#  ['01290700', '-6', '137', 'ABI', 'DFW'],
#  ['01291155', '3', '137', 'ABI', 'DFW'],
#  ['01290810', '-8', '137', 'ABI', 'DFW'],
#  ['01291400', '-13', '137', 'ABI', 'DFW'],
#  ['01300550', '-4', '137', 'ABI', 'DFW'],
#  ['01300925', '-6', '137', 'ABI', 'DFW'],
#  ['01301730', '-7', '137', 'ABI', 'DFW'],
#  ['01300700', '-7', '137', 'ABI', 'DFW'],
#  ['01301155', '-6', '137', 'ABI', 'DFW'],
#  ['01300810', '-11', '137', 'ABI', 'DFW'],
#  ['01301400', '-13', '137', 'ABI', 'DFW'],
#  ['01310550', '-2', '137', 'ABI', 'DFW'],
#  ['01310925', '27', '137', 'ABI', 'DFW'],
#  ['01311730', '-6', '137', 'ABI', 'DFW'],
#  ['01310700', '-7', '137', 'ABI', 'DFW'],
#  ['01311155', '2', '137', 'ABI', 'DFW'],
#  ['01310810', '29', '137', 'ABI', 'DFW'],
#  ['01311400', '-13', '137', 'ABI', 'DFW'],
#  ['01011405', '1', '494', 'ABQ', 'DFW'],
#  ['01011520', '0', '494', 'ABQ', 'DFW'],
#  ['01010605', '-5', '494', 'ABQ', 'DFW'],
#  ['01010835', '-7', '494', 'ABQ', 'DFW'],
#  ['01010730', '-1', '494', 'ABQ', 'DFW'],
#  ['01011030', '-2', '494', 'ABQ', 'DFW'],
#  ['01011135', '-2', '494', 'ABQ', 'DFW'],
#  ['01021405', '8', '494', 'ABQ', 'DFW'],
#  ['01021520', '1', '494', 'ABQ', 'DFW'],
#  ['01020605', '118', '494', 'ABQ', 'DFW'],
#  ['01020835', '59', '494', 'ABQ', 'DFW'],
#  ['01020730', '87', '494', 'ABQ', 'DFW'],
#  ['01021030', '85', '494', 'ABQ', 'DFW'],
#  ['01021135', '115', '494', 'ABQ', 'DFW'],
#  ['01021655', '87', '494', 'ABQ', 'DFW'],
#  ['01031405', '38', '494', 'ABQ', 'DFW'],
#  ['01031520', '36', '494', 'ABQ', 'DFW'],
#  ['01030605', '2', '494', 'ABQ', 'DFW'],
#  ['01030835', '33', '494', 'ABQ', 'DFW'],
#  ['01030730', '-4', '494', 'ABQ', 'DFW'],
#  ['01031030', '-1', '494', 'ABQ', 'DFW'],
#  ['01031135', '-7', '494', 'ABQ', 'DFW'],
#  ['01031655', '85', '494', 'ABQ', 'DFW'],
#  ['01041405', '0', '494', 'ABQ', 'DFW'],
#  ['01041520', '0', '494', 'ABQ', 'DFW'],
#  ['01040605', '1', '494', 'ABQ', 'DFW'],
#  ['01040835', '-7', '494', 'ABQ', 'DFW'],
#  ['01040730', '0', '494', 'ABQ', 'DFW'],
#  ['01041030', '10', '494', 'ABQ', 'DFW'],
#  ['01041135', '-4', '494', 'ABQ', 'DFW'],
#  ['01051405', '47', '494', 'ABQ', 'DFW'],
#  ['01051520', '59', '494', 'ABQ', 'DFW'],
#  ['01050605', '1', '494', 'ABQ', 'DFW'],
#  ['01050835', '-2', '494', 'ABQ', 'DFW'],
#  ['01050730', '-2', '494', 'ABQ', 'DFW'],
#  ['01051030', '30', '494', 'ABQ', 'DFW'],
#  ['01051135', '9', '494', 'ABQ', 'DFW'],
#  ['01051655', '9', '494', 'ABQ', 'DFW'],
#  ['01061405', '25', '494', 'ABQ', 'DFW'],
#  ['01061520', '36', '494', 'ABQ', 'DFW'],
#  ['01060605', '-4', '494', 'ABQ', 'DFW'],
#  ['01060835', '-2', '494', 'ABQ', 'DFW'],
#  ['01060730', '-7', '494', 'ABQ', 'DFW'],
#  ['01061030', '-3', '494', 'ABQ', 'DFW'],
#  ['01061135', '71', '494', 'ABQ', 'DFW'],
#  ['01061655', '0', '494', 'ABQ', 'DFW'],
#  ['01071405', '78', '494', 'ABQ', 'DFW'],
#  ['01071520', '4', '494', 'ABQ', 'DFW'],
#  ['01070605', '0', '494', 'ABQ', 'DFW'],
#  ['01070835', '173', '494', 'ABQ', 'DFW'],
#  ['01070730', '-4', '494', 'ABQ', 'DFW'],
#  ['01071030', '1', '494', 'ABQ', 'DFW'],
#  ['01071135', '0', '494', 'ABQ', 'DFW'],
#  ['01081405', '-6', '494', 'ABQ', 'DFW'],
#  ['01081520', '17', '494', 'ABQ', 'DFW'],
#  ['01080605', '-7', '494', 'ABQ', 'DFW'],
#  ['01080835', '-6', '494', 'ABQ', 'DFW'],
#  ['01080730', '-5', '494', 'ABQ', 'DFW'],
#  ['01081030', '-6', '494', 'ABQ', 'DFW'],
#  ['01081135', '-1', '494', 'ABQ', 'DFW'],
#  ['01091405', '18', '494', 'ABQ', 'DFW'],
#  ['01091520', '-3', '494', 'ABQ', 'DFW'],
#  ['01090605', '-8', '494', 'ABQ', 'DFW'],
#  ['01090835', '-12', '494', 'ABQ', 'DFW'],
#  ['01090730', '-8', '494', 'ABQ', 'DFW'],
#  ['01091030', '9', '494', 'ABQ', 'DFW'],
#  ['01091135', '0', '494', 'ABQ', 'DFW'],
#  ['01101405', '-6', '494', 'ABQ', 'DFW'],
#  ['01101520', '-8', '494', 'ABQ', 'DFW'],
#  ['01100605', '-10', '494', 'ABQ', 'DFW'],
#  ['01100835', '-15', '494', 'ABQ', 'DFW'],
#  ['01100730', '-6', '494', 'ABQ', 'DFW'],
#  ['01101030', '-4', '494', 'ABQ', 'DFW'],
#  ['01101135', '-14', '494', 'ABQ', 'DFW'],
#  ['01111405', '43', '494', 'ABQ', 'DFW'],
#  ['01111520', '-8', '494', 'ABQ', 'DFW'],
#  ['01110605', '-6', '494', 'ABQ', 'DFW'],
#  ['01110835', '-9', '494', 'ABQ', 'DFW'],
#  ['01110730', '-8', '494', 'ABQ', 'DFW'],
#  ['01111030', '-7', '494', 'ABQ', 'DFW'],
#  ['01111135', '3', '494', 'ABQ', 'DFW'],
#  ['01121405', '-9', '494', 'ABQ', 'DFW'],
#  ['01121520', '-7', '494', 'ABQ', 'DFW'],
#  ['01120835', '-11', '494', 'ABQ', 'DFW'],
#  ['01120730', '-4', '494', 'ABQ', 'DFW'],
#  ['01121030', '-1', '494', 'ABQ', 'DFW'],
#  ['01121135', '-9', '494', 'ABQ', 'DFW'],
#  ['01131405', '2', '494', 'ABQ', 'DFW'],
#  ['01131520', '-12', '494', 'ABQ', 'DFW'],
#  ['01130605', '-8', '494', 'ABQ', 'DFW'],
#  ['01130835', '-12', '494', 'ABQ', 'DFW'],
#  ['01130730', '-3', '494', 'ABQ', 'DFW'],
#  ['01131030', '-10', '494', 'ABQ', 'DFW'],
#  ['01131135', '-7', '494', 'ABQ', 'DFW'],
#  ['01141405', '-6', '494', 'ABQ', 'DFW'],
#  ['01141520', '-4', '494', 'ABQ', 'DFW'],
#  ['01140605', '-5', '494', 'ABQ', 'DFW'],
#  ['01140835', '-7', '494', 'ABQ', 'DFW'],
#  ['01140730', '-9', '494', 'ABQ', 'DFW'],
#  ['01141030', '-7', '494', 'ABQ', 'DFW'],
#  ['01141135', '-6', '494', 'ABQ', 'DFW'],
#  ['01151405', '-3', '494', 'ABQ', 'DFW'],
#  ['01151520', '-4', '494', 'ABQ', 'DFW'],
#  ['01150605', '-4', '494', 'ABQ', 'DFW'],
#  ['01150835', '-10', '494', 'ABQ', 'DFW'],
#  ['01150730', '4', '494', 'ABQ', 'DFW'],
#  ['01151030', '-8', '494', 'ABQ', 'DFW'],
#  ['01151135', '-8', '494', 'ABQ', 'DFW'],
#  ['01161405', '43', '494', 'ABQ', 'DFW'],
#  ['01161520', '58', '494', 'ABQ', 'DFW'],
#  ['01160605', '-3', '494', 'ABQ', 'DFW'],
#  ['01160835', '-8', '494', 'ABQ', 'DFW'],
#  ['01160730', '-6', '494', 'ABQ', 'DFW'],
#  ['01161030', '-6', '494', 'ABQ', 'DFW'],
#  ['01161135', '-4', '494', 'ABQ', 'DFW'],
#  ['01171405', '-5', '494', 'ABQ', 'DFW'],
#  ['01171520', '-1', '494', 'ABQ', 'DFW'],
#  ['01170605', '-6', '494', 'ABQ', 'DFW'],
#  ['01170835', '0', '494', 'ABQ', 'DFW'],
#  ['01170730', '8', '494', 'ABQ', 'DFW'],
#  ['01171030', '-6', '494', 'ABQ', 'DFW'],
#  ['01171135', '-1', '494', 'ABQ', 'DFW'],
#  ['01181405', '0', '494', 'ABQ', 'DFW'],
#  ['01181520', '38', '494', 'ABQ', 'DFW'],
#  ['01180605', '-12', '494', 'ABQ', 'DFW'],
#  ['01180835', '-9', '494', 'ABQ', 'DFW'],
#  ['01180730', '-4', '494', 'ABQ', 'DFW'],
#  ['01181030', '-9', '494', 'ABQ', 'DFW'],
#  ['01181135', '-4', '494', 'ABQ', 'DFW'],
#  ['01191405', '-2', '494', 'ABQ', 'DFW'],
#  ['01191520', '-4', '494', 'ABQ', 'DFW'],
#  ['01190835', '-8', '494', 'ABQ', 'DFW'],
#  ['01190730', '-9', '494', 'ABQ', 'DFW'],
#  ['01191030', '-15', '494', 'ABQ', 'DFW'],
#  ['01191135', '-8', '494', 'ABQ', 'DFW'],
#  ['01201405', '-4', '494', 'ABQ', 'DFW'],
#  ['01201520', '-10', '494', 'ABQ', 'DFW'],
#  ['01200605', '-3', '494', 'ABQ', 'DFW'],
#  ['01200835', '-6', '494', 'ABQ', 'DFW'],
#  ['01200730', '-3', '494', 'ABQ', 'DFW'],
#  ['01201030', '-10', '494', 'ABQ', 'DFW'],
#  ['01201135', '-8', '494', 'ABQ', 'DFW'],
#  ['01211405', '-8', '494', 'ABQ', 'DFW'],
#  ['01211520', '2', '494', 'ABQ', 'DFW'],
#  ['01210605', '-12', '494', 'ABQ', 'DFW'],
#  ['01210835', '-9', '494', 'ABQ', 'DFW'],
#  ['01210730', '-12', '494', 'ABQ', 'DFW'],
#  ['01211030', '-5', '494', 'ABQ', 'DFW'],
#  ['01211135', '-11', '494', 'ABQ', 'DFW'],
#  ['01221405', '-9', '494', 'ABQ', 'DFW'],
#  ['01221520', '-6', '494', 'ABQ', 'DFW'],
#  ['01220605', '-10', '494', 'ABQ', 'DFW'],
#  ['01220835', '-7', '494', 'ABQ', 'DFW'],
#  ['01220730', '-4', '494', 'ABQ', 'DFW'],
#  ['01221030', '87', '494', 'ABQ', 'DFW'],
#  ['01221135', '-4', '494', 'ABQ', 'DFW'],
#  ['01231405', '76', '494', 'ABQ', 'DFW'],
#  ['01231520', '33', '494', 'ABQ', 'DFW'],
#  ['01230605', '-5', '494', 'ABQ', 'DFW'],
#  ['01230835', '-5', '494', 'ABQ', 'DFW'],
#  ['01230730', '-6', '494', 'ABQ', 'DFW'],
#  ['01231030', '62', '494', 'ABQ', 'DFW'],
#  ['01231135', '-1', '494', 'ABQ', 'DFW'],
#  ['01241405', '79', '494', 'ABQ', 'DFW'],
#  ['01241520', '6', '494', 'ABQ', 'DFW'],
#  ['01240605', '68', '494', 'ABQ', 'DFW'],
#  ['01240835', '3', '494', 'ABQ', 'DFW'],
#  ['01240730', '97', '494', 'ABQ', 'DFW'],
#  ['01241030', '-2', '494', 'ABQ', 'DFW'],
#  ['01241135', '0', '494', 'ABQ', 'DFW'],
#  ['01251405', '-7', '494', 'ABQ', 'DFW'],
#  ['01251520', '11', '494', 'ABQ', 'DFW'],
#  ['01250605', '-10', '494', 'ABQ', 'DFW'],
#  ['01250835', '-13', '494', 'ABQ', 'DFW'],
#  ['01250730', '-2', '494', 'ABQ', 'DFW'],
#  ['01251030', '-4', '494', 'ABQ', 'DFW'],
#  ['01251135', '-9', '494', 'ABQ', 'DFW'],
#  ['01261405', '-5', '494', 'ABQ', 'DFW'],
#  ['01261520', '11', '494', 'ABQ', 'DFW'],
#  ['01260835', '-5', '494', 'ABQ', 'DFW'],
#  ['01260730', '-2', '494', 'ABQ', 'DFW'],
#  ['01261030', '-6', '494', 'ABQ', 'DFW'],
#  ['01261135', '1', '494', 'ABQ', 'DFW'],
#  ['01271405', '-11', '494', 'ABQ', 'DFW'],
#  ['01271520', '-2', '494', 'ABQ', 'DFW'],
#  ['01270605', '0', '494', 'ABQ', 'DFW'],
#  ['01270835', '-13', '494', 'ABQ', 'DFW'],
#  ['01270730', '-12', '494', 'ABQ', 'DFW'],
#  ['01271030', '-6', '494', 'ABQ', 'DFW'],
#  ['01271135', '2', '494', 'ABQ', 'DFW'],
#  ['01281405', '0', '494', 'ABQ', 'DFW'],
#  ['01281520', '-8', '494', 'ABQ', 'DFW'],
#  ['01280605', '-12', '494', 'ABQ', 'DFW'],
#  ['01280835', '-4', '494', 'ABQ', 'DFW'],
#  ['01280730', '-10', '494', 'ABQ', 'DFW'],
#  ['01281030', '-6', '494', 'ABQ', 'DFW'],
#  ['01281135', '-7', '494', 'ABQ', 'DFW'],
#  ['01291405', '8', '494', 'ABQ', 'DFW'],
#  ['01291520', '-4', '494', 'ABQ', 'DFW'],
#  ['01290605', '-6', '494', 'ABQ', 'DFW'],
#  ['01290835', '1', '494', 'ABQ', 'DFW'],
#  ['01290730', '-6', '494', 'ABQ', 'DFW'],
#  ['01291030', '-4', '494', 'ABQ', 'DFW'],
#  ['01291135', '19', '494', 'ABQ', 'DFW'],
#  ['01301405', '-4', '494', 'ABQ', 'DFW'],
#  ['01301520', '-3', '494', 'ABQ', 'DFW'],
#  ['01300605', '-7', '494', 'ABQ', 'DFW'],
#  ['01300835', '-3', '494', 'ABQ', 'DFW'],
#  ['01300730', '-3', '494', 'ABQ', 'DFW'],
#  ['01301030', '0', '494', 'ABQ', 'DFW'],
#  ['01301135', '-1', '494', 'ABQ', 'DFW'],
#  ['01311405', '3', '494', 'ABQ', 'DFW'],
#  ['01311520', '4', '494', 'ABQ', 'DFW'],
#  ['01310605', '-6', '494', 'ABQ', 'DFW'],
#  ['01310835', '-9', '494', 'ABQ', 'DFW'],
#  ['01310730', '-5', '494', 'ABQ', 'DFW'],
#  ['01311030', '1', '494', 'ABQ', 'DFW'],
#  ['01311135', '-8', '494', 'ABQ', 'DFW'],
#  ['01012355', '0', '1586', 'ABQ', 'JFK'],
#  ['01022355', '158', '1586', 'ABQ', 'JFK'],
#  ['01032355', '0', '1586', 'ABQ', 'JFK'],
#  ['01042355', '0', '1586', 'ABQ', 'JFK'],
#  ['01052355', '0', '1586', 'ABQ', 'JFK'],
#  ['01062355', '0', '1586', 'ABQ', 'JFK'],
#  ['01072359', '14', '1586', 'ABQ', 'JFK'],
#  ['01082358', '-4', '1586', 'ABQ', 'JFK'],
#  ['01092358', '20', '1586', 'ABQ', 'JFK'],
#  ['01102358', '-2', '1586', 'ABQ', 'JFK'],
#  ['01112358', '116', '1586', 'ABQ', 'JFK'],
#  ['01122358', '0', '1586', 'ABQ', 'JFK'],
#  ['01132358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01142359', '-17', '1586', 'ABQ', 'JFK'],
#  ['01152358', '135', '1586', 'ABQ', 'JFK'],
#  ['01162358', '-13', '1586', 'ABQ', 'JFK'],
#  ['01172358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01182358', '-17', '1586', 'ABQ', 'JFK'],
#  ['01192358', '-18', '1586', 'ABQ', 'JFK'],
#  ['01202358', '-9', '1586', 'ABQ', 'JFK'],
#  ['01212359', '0', '1586', 'ABQ', 'JFK'],
#  ['01222358', '0', '1586', 'ABQ', 'JFK'],
#  ['01232358', '44', '1586', 'ABQ', 'JFK'],
#  ['01242358', '-6', '1586', 'ABQ', 'JFK'],
#  ['01252358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01262358', '-22', '1586', 'ABQ', 'JFK'],
#  ['01272358', '9', '1586', 'ABQ', 'JFK'],
#  ['01282359', '-20', '1586', 'ABQ', 'JFK'],
#  ['01292358', '17', '1586', 'ABQ', 'JFK'],
#  ['01302358', '7', '1586', 'ABQ', 'JFK'],
#  ['01312358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01011316', '-8', '1103', 'ABQ', 'ATL'],
#  ['01010730', '-4', '1103', 'ABQ', 'ATL'],
#  ['01011440', '-4', '852', 'ABQ', 'MSP'],
#  ['01010700', '-4', '852', 'ABQ', 'MSP'],
#  ['01020730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01020615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01021326', '6', '1103', 'ABQ', 'ATL'],
#  ['01021440', '-4', '852', 'ABQ', 'MSP'],
#  ['01020700', '-4', '852', 'ABQ', 'MSP'],
#  ['01030730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01030615', '0', '1103', 'ABQ', 'ATL'],
#  ['01031326', '6', '1103', 'ABQ', 'ATL'],
#  ['01031440', '6', '852', 'ABQ', 'MSP'],
#  ['01030700', '58', '852', 'ABQ', 'MSP'],
#  ['01040730', '-1', '1103', 'ABQ', 'ATL'],
#  ['01040615', '0', '1103', 'ABQ', 'ATL'],
#  ['01041326', '31', '1103', 'ABQ', 'ATL'],
#  ['01041440', '-3', '852', 'ABQ', 'MSP'],
#  ['01040700', '1', '852', 'ABQ', 'MSP'],
#  ['01051326', '26', '1103', 'ABQ', 'ATL'],
#  ['01050730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01050615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01051440', '40', '852', 'ABQ', 'MSP'],
#  ['01050700', '0', '852', 'ABQ', 'MSP'],
#  ['01060600', '-1', '852', 'ABQ', 'MSP'],
#  ['01061230', '-3', '428', 'ABQ', 'SLC'],
#  ['01061328', '36', '1103', 'ABQ', 'ATL'],
#  ['01060730', '44', '1103', 'ABQ', 'ATL'],
#  ['01060615', '22', '1103', 'ABQ', 'ATL'],
#  ['01071328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01070615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01081328', '16', '1103', 'ABQ', 'ATL'],
#  ['01080615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01091328', '73', '1103', 'ABQ', 'ATL'],
#  ['01090615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01101328', '17', '1103', 'ABQ', 'ATL'],
#  ['01100615', '0', '1103', 'ABQ', 'ATL'],
#  ['01111328', '15', '1103', 'ABQ', 'ATL'],
#  ['01110615', '-1', '1103', 'ABQ', 'ATL'],
#  ['01121328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01120615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01131328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01130615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01141328', '0', '1103', 'ABQ', 'ATL'],
#  ['01140615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01151328', '385', '1103', 'ABQ', 'ATL'],
#  ['01150615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01161328', '11', '1103', 'ABQ', 'ATL'],
#  ['01160615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01171328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01170615', '489', '1103', 'ABQ', 'ATL'],
#  ['01181328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01180615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01191328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01190615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01201328', '9', '1103', 'ABQ', 'ATL'],
#  ['01200615', '0', '1103', 'ABQ', 'ATL'],
#  ['01211328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01210615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01221328', '-5', '1103', 'ABQ', 'ATL'],
#  ['01220615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01231328', '30', '1103', 'ABQ', 'ATL'],
#  ['01230615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01241328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01240615', '1', '1103', 'ABQ', 'ATL'],
#  ['01251328', '-6', '1103', 'ABQ', 'ATL'],
#  ['01250615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01261328', '-1', '1103', 'ABQ', 'ATL'],
#  ['01260615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01271328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01270615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01281328', '0', '1103', 'ABQ', 'ATL'],
#  ['01280615', '0', '1103', 'ABQ', 'ATL'],
#  ['01291328', '141', '1103', 'ABQ', 'ATL'],
#  ['01290615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01301328', '296', '1103', 'ABQ', 'ATL'],
#  ['01300615', '0', '1103', 'ABQ', 'ATL'],
#  ['01311328', '0', '1103', 'ABQ', 'ATL'],
#  ['01310615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01011712', '57', '646', 'ABQ', 'IAH'],
#  ['01011420', '-6', '646', 'ABQ', 'IAH'],
#  ['01011042', '-10', '646', 'ABQ', 'IAH'],
#  ['01010805', '23', '646', 'ABQ', 'IAH'],
#  ['01011933', '0', '303', 'ABQ', 'DEN'],
#  ['01021726', '-6', '646', 'ABQ', 'IAH'],
#  ['01021411', '-6', '646', 'ABQ', 'IAH'],
#  ['01021050', '37', '646', 'ABQ', 'IAH'],
#  ['01020610', '0', '646', 'ABQ', 'IAH'],
#  ['01020536', '0', '303', 'ABQ', 'DEN'],
#  ['01031712', '8', '646', 'ABQ', 'IAH'],
#  ['01031411', '0', '646', 'ABQ', 'IAH'],
#  ['01031050', '0', '646', 'ABQ', 'IAH'],
#  ['01030610', '-1', '646', 'ABQ', 'IAH'],
#  ['01030536', '-7', '303', 'ABQ', 'DEN'],
#  ['01041712', '138', '646', 'ABQ', 'IAH'],
#  ['01041050', '-6', '646', 'ABQ', 'IAH'],
#  ['01040805', '-7', '646', 'ABQ', 'IAH'],
#  ['01040530', '15', '303', 'ABQ', 'DEN'],
#  ['01050805', '-7', '646', 'ABQ', 'IAH'],
#  ['01061712', '26', '646', 'ABQ', 'IAH'],
#  ['01061411', '0', '646', 'ABQ', 'IAH'],
#  ['01061050', '194', '646', 'ABQ', 'IAH'],
#  ['01060610', '-5', '646', 'ABQ', 'IAH'],
#  ['01060536', '0', '303', 'ABQ', 'DEN'],
#  ['01071053', '10', '646', 'ABQ', 'IAH'],
#  ['01071713', '8', '646', 'ABQ', 'IAH'],
#  ['01070903', '0', '646', 'ABQ', 'IAH'],
#  ['01081713', '9', '646', 'ABQ', 'IAH'],
#  ['01080903', '-7', '646', 'ABQ', 'IAH'],
#  ['01081101', '80', '646', 'ABQ', 'IAH'],
#  ['01080736', '-2', '303', 'ABQ', 'DEN'],
#  ['01091713', '51', '646', 'ABQ', 'IAH'],
#  ['01090903', '-7', '646', 'ABQ', 'IAH'],
#  ['01101713', '-6', '646', 'ABQ', 'IAH'],
#  ['01100903', '-7', '646', 'ABQ', 'IAH'],
#  ['01110903', '-12', '646', 'ABQ', 'IAH'],
#  ['01120903', '-7', '646', 'ABQ', 'IAH'],
#  ['01121713', '-4', '646', 'ABQ', 'IAH'],
#  ['01120720', '-1', '303', 'ABQ', 'DEN'],
#  ['01121722', '-12', '303', 'ABQ', 'DEN'],
#  ['01121007', '-10', '303', 'ABQ', 'DEN'],
#  ['01131713', '-4', '646', 'ABQ', 'IAH'],
#  ['01130903', '-6', '646', 'ABQ', 'IAH'],
#  ['01141101', '-9', '646', 'ABQ', 'IAH'],
#  ['01141713', '-10', '646', 'ABQ', 'IAH'],
#  ['01140903', '-10', '646', 'ABQ', 'IAH'],
#  ['01151713', '58', '646', 'ABQ', 'IAH'],
#  ['01150903', '-8', '646', 'ABQ', 'IAH'],
#  ['01151101', '-14', '646', 'ABQ', 'IAH'],
#  ['01150736', '-8', '303', 'ABQ', 'DEN'],
#  ['01161713', '7', '646', 'ABQ', 'IAH'],
#  ['01160903', '-5', '646', 'ABQ', 'IAH'],
#  ['01171713', '-8', '646', 'ABQ', 'IAH'],
#  ['01170903', '23', '646', 'ABQ', 'IAH'],
#  ['01180903', '-10', '646', 'ABQ', 'IAH'],
#  ['01190903', '-7', '646', 'ABQ', 'IAH'],
#  ['01191713', '-2', '646', 'ABQ', 'IAH'],
#  ['01190720', '-5', '303', 'ABQ', 'DEN'],
#  ['01191722', '-14', '303', 'ABQ', 'DEN'],
#  ['01191007', '-9', '303', 'ABQ', 'DEN'],
#  ['01201713', '-2', '646', 'ABQ', 'IAH'],
#  ['01200903', '-3', '646', 'ABQ', 'IAH'],
#  ['01211101', '7', '646', 'ABQ', 'IAH'],
#  ['01211713', '-6', '646', 'ABQ', 'IAH'],
#  ['01210903', '-11', '646', 'ABQ', 'IAH'],
#  ['01221713', '12', '646', 'ABQ', 'IAH'],
#  ['01220903', '-5', '646', 'ABQ', 'IAH'],
#  ['01221101', '-6', '646', 'ABQ', 'IAH'],
#  ['01220736', '-7', '303', 'ABQ', 'DEN'],
#  ['01231713', '0', '646', 'ABQ', 'IAH'],
#  ['01230903', '-6', '646', 'ABQ', 'IAH'],
#  ['01241713', '-8', '646', 'ABQ', 'IAH'],
#  ['01240903', '0', '646', 'ABQ', 'IAH'],
#  ['01250903', '-4', '646', 'ABQ', 'IAH'],
#  ['01260903', '7', '646', 'ABQ', 'IAH'],
#  ['01261713', '1', '646', 'ABQ', 'IAH'],
#  ['01260720', '1', '303', 'ABQ', 'DEN'],
#  ['01261722', '-11', '303', 'ABQ', 'DEN'],
#  ['01261007', '-13', '303', 'ABQ', 'DEN'],
#  ['01271713', '-7', '646', 'ABQ', 'IAH'],
#  ['01270903', '-7', '646', 'ABQ', 'IAH'],
#  ['01281101', '0', '646', 'ABQ', 'IAH'],
#  ['01281713', '0', '646', 'ABQ', 'IAH'],
#  ['01280903', '0', '646', 'ABQ', 'IAH'],
#  ['01291713', '102', '646', 'ABQ', 'IAH'],
#  ['01290903', '146', '646', 'ABQ', 'IAH'],
#  ['01291101', '127', '646', 'ABQ', 'IAH'],
#  ['01290736', '9', '303', 'ABQ', 'DEN'],
#  ['01301713', '-3', '646', 'ABQ', 'IAH'],
#  ['01300903', '-8', '646', 'ABQ', 'IAH'],
#  ['01311713', '1', '646', 'ABQ', 'IAH'],
#  ['01310903', '12', '646', 'ABQ', 'IAH'],
#  ['01011450', '7', '303', 'ABQ', 'DEN'],
#  ['01021450', '32', '303', 'ABQ', 'DEN'],
#  ['01020800', '-8', '303', 'ABQ', 'DEN'],
#  ['01031450', '2', '303', 'ABQ', 'DEN'],
#  ['01030800', '-3', '303', 'ABQ', 'DEN'],
#  ['01040800', '94', '303', 'ABQ', 'DEN'],
#  ['01050800', '-4', '303', 'ABQ', 'DEN'],
#  ['01060800', '140', '303', 'ABQ', 'DEN'],
#  ['01011950', '128', '589', 'ABQ', 'LAX'],
#  ['01010545', '0', '589', 'ABQ', 'LAX'],
#  ['01021950', '95', '589', 'ABQ', 'LAX'],
#  ['01020545', '0', '589', 'ABQ', 'LAX'],
#  ['01031950', '25', '589', 'ABQ', 'LAX'],
#  ['01030545', '0', '589', 'ABQ', 'LAX'],
#  ['01040545', '-4', '589', 'ABQ', 'LAX'],
#  ['01051950', '53', '589', 'ABQ', 'LAX'],
#  ['01061950', '53', '589', 'ABQ', 'LAX'],
#  ['01060545', '22', '589', 'ABQ', 'LAX'],
#  ['01071950', '122', '589', 'ABQ', 'LAX'],
#  ['01070545', '-4', '589', 'ABQ', 'LAX'],
#  ['01081950', '13', '589', 'ABQ', 'LAX'],
#  ['01080545', '33', '589', 'ABQ', 'LAX'],
#  ['01091950', '-8', '589', 'ABQ', 'LAX'],
#  ['01090545', '-4', '589', 'ABQ', 'LAX'],
#  ['01101950', '0', '589', 'ABQ', 'LAX'],
#  ['01100545', '-4', '589', 'ABQ', 'LAX'],
#  ['01110545', '7', '589', 'ABQ', 'LAX'],
#  ['01121950', '-9', '589', 'ABQ', 'LAX'],
#  ['01131950', '0', '589', 'ABQ', 'LAX'],
#  ['01130545', '14', '589', 'ABQ', 'LAX'],
#  ['01141950', '-6', '589', 'ABQ', 'LAX'],
#  ['01140545', '-5', '589', 'ABQ', 'LAX'],
#  ['01151950', '0', '589', 'ABQ', 'LAX'],
#  ['01150545', '0', '589', 'ABQ', 'LAX'],
#  ['01161950', '-7', '589', 'ABQ', 'LAX'],
#  ['01160545', '-1', '589', 'ABQ', 'LAX'],
#  ['01171950', '8', '589', 'ABQ', 'LAX'],
#  ['01170545', '-7', '589', 'ABQ', 'LAX'],
#  ['01180545', '0', '589', 'ABQ', 'LAX'],
#  ['01191950', '33', '589', 'ABQ', 'LAX'],
#  ['01201950', '56', '589', 'ABQ', 'LAX'],
#  ['01200545', '-7', '589', 'ABQ', 'LAX'],
#  ['01211950', '10', '589', 'ABQ', 'LAX'],
#  ['01210545', '-4', '589', 'ABQ', 'LAX'],
#  ['01221950', '58', '589', 'ABQ', 'LAX'],
#  ['01220545', '-8', '589', 'ABQ', 'LAX'],
#  ['01231950', '12', '589', 'ABQ', 'LAX'],
#  ['01230545', '0', '589', 'ABQ', 'LAX'],
#  ['01241950', '-8', '589', 'ABQ', 'LAX'],
#  ['01240545', '0', '589', 'ABQ', 'LAX'],
#  ['01250545', '-7', '589', 'ABQ', 'LAX'],
#  ['01261950', '-9', '589', 'ABQ', 'LAX'],
#  ['01271950', '112', '589', 'ABQ', 'LAX'],
#  ['01270545', '-8', '589', 'ABQ', 'LAX'],
#  ['01281950', '22', '589', 'ABQ', 'LAX'],
#  ['01280545', '-4', '589', 'ABQ', 'LAX'],
#  ['01291950', '62', '589', 'ABQ', 'LAX'],
#  ['01290545', '-7', '589', 'ABQ', 'LAX'],
#  ['01301950', '-8', '589', 'ABQ', 'LAX'],
#  ['01300545', '97', '589', 'ABQ', 'LAX'],
#  ['01311950', '-10', '589', 'ABQ', 'LAX'],
#  ['01310545', '6', '589', 'ABQ', 'LAX'],
#  ['01011225', '10', '589', 'ABQ', 'LAX'],
#  ['01012137', '-8', '285', 'ABQ', 'PHX'],
#  ['01010620', '-7', '285', 'ABQ', 'PHX'],
#  ['01011225', '-4', '285', 'ABQ', 'PHX'],
#  ['01010830', '-5', '285', 'ABQ', 'PHX'],
#  ['01011835', '-6', '285', 'ABQ', 'PHX'],
#  ['01010715', '-2', '428', 'ABQ', 'SLC'],
#  ['01011204', '26', '428', 'ABQ', 'SLC'],
#  ['01011626', '39', '589', 'ABQ', 'LAX'],
#  ['01010600', '-7', '779', 'ABQ', 'SFO'],
#  ['01011047', '25', '589', 'ABQ', 'LAX'],
#  ['01011344', '21', '303', 'ABQ', 'DEN'],
#  ['01021225', '4', '589', 'ABQ', 'LAX'],
#  ['01022137', '-6', '285', 'ABQ', 'PHX'],
#  ['01020620', '1', '285', 'ABQ', 'PHX'],
#  ['01021225', '-6', '285', 'ABQ', 'PHX'],
#  ['01020830', '-3', '285', 'ABQ', 'PHX'],
#  ['01021835', '-8', '285', 'ABQ', 'PHX'],
#  ['01020600', '-2', '428', 'ABQ', 'SLC'],
#  ['01021204', '11', '428', 'ABQ', 'SLC'],
#  ['01021825', '23', '428', 'ABQ', 'SLC'],
#  ['01020600', '0', '779', 'ABQ', 'SFO'],
#  ['01021933', '4', '303', 'ABQ', 'DEN'],
#  ['01021047', '-5', '589', 'ABQ', 'LAX'],
#  ['01021626', '4', '589', 'ABQ', 'LAX'],
#  ['01031225', '42', '589', 'ABQ', 'LAX'],
#  ['01032137', '-5', '285', 'ABQ', 'PHX'],
#  ['01030620', '-8', '285', 'ABQ', 'PHX'],
#  ['01031225', '-5', '285', 'ABQ', 'PHX'],
#  ['01030830', '-4', '285', 'ABQ', 'PHX'],
#  ['01031835', '3', '285', 'ABQ', 'PHX'],
#  ['01030600', '-1', '428', 'ABQ', 'SLC'],
#  ['01031204', '84', '428', 'ABQ', 'SLC'],
#  ['01031825', '-8', '428', 'ABQ', 'SLC'],
#  ['01030600', '-10', '779', 'ABQ', 'SFO'],
#  ['01031933', '-8', '303', 'ABQ', 'DEN'],
#  ['01031047', '-4', '589', 'ABQ', 'LAX'],
#  ['01031626', '2', '589', 'ABQ', 'LAX'],
#  ['01041225', '3', '589', 'ABQ', 'LAX'],
#  ['01042137', '0', '285', 'ABQ', 'PHX'],
#  ['01040620', '-9', '285', 'ABQ', 'PHX'],
#  ['01041225', '-6', '285', 'ABQ', 'PHX'],
#  ['01040830', '-2', '285', 'ABQ', 'PHX'],
#  ['01041835', '-8', '285', 'ABQ', 'PHX'],
#  ['01040600', '-2', '428', 'ABQ', 'SLC'],
#  ['01041204', '40', '428', 'ABQ', 'SLC'],
#  ['01041825', '-3', '428', 'ABQ', 'SLC'],
#  ['01041404', '52', '646', 'ABQ', 'IAH'],
#  ['01041933', '25', '303', 'ABQ', 'DEN'],
#  ['01040600', '-5', '779', 'ABQ', 'SFO'],
#  ['01041047', '45', '589', 'ABQ', 'LAX'],
#  ['01041626', '41', '589', 'ABQ', 'LAX'],
#  ['01051225', '3', '589', 'ABQ', 'LAX'],
#  ['01050545', '83', '589', 'ABQ', 'LAX'],
#  ['01052137', '4', '285', 'ABQ', 'PHX'],
#  ['01050620', '-6', '285', 'ABQ', 'PHX'],
#  ['01051225', '-6', '285', 'ABQ', 'PHX'],
#  ['01050830', '-7', '285', 'ABQ', 'PHX'],
#  ['01051835', '-3', '285', 'ABQ', 'PHX'],
#  ['01050605', '-2', '428', 'ABQ', 'SLC'],
#  ['01051204', '-1', '428', 'ABQ', 'SLC'],
#  ['01051825', '16', '428', 'ABQ', 'SLC'],
#  ['01051040', '-7', '646', 'ABQ', 'IAH'],
#  ['01050615', '-1', '646', 'ABQ', 'IAH'],
#  ['01051721', '70', '646', 'ABQ', 'IAH'],
#  ['01051411', '33', '646', 'ABQ', 'IAH'],
#  ['01051658', '53', '589', 'ABQ', 'LAX'],
#  ['01051933', '19', '303', 'ABQ', 'DEN'],
#  ['01050530', '-4', '303', 'ABQ', 'DEN'],
#  ['01050615', '0', '779', 'ABQ', 'SFO'],
#  ['01051051', '35', '589', 'ABQ', 'LAX'],
#  ['01061225', '3', '589', 'ABQ', 'LAX'],
#  ['01060620', '-2', '285', 'ABQ', 'PHX'],
#  ['01061225', '-4', '285', 'ABQ', 'PHX'],
#  ['01060830', '24', '285', 'ABQ', 'PHX'],
#  ['01061835', '-6', '285', 'ABQ', 'PHX'],
#  ['01060600', '40', '428', 'ABQ', 'SLC'],
#  ['01061720', '-2', '428', 'ABQ', 'SLC'],
#  ['01060600', '0', '779', 'ABQ', 'SFO'],
#  ['01061933', '-1', '303', 'ABQ', 'DEN'],
#  ['01061040', '-3', '589', 'ABQ', 'LAX'],
#  ['01061626', '-7', '589', 'ABQ', 'LAX'],
#  ['01071225', '5', '589', 'ABQ', 'LAX'],
#  ['01071225', '-6', '285', 'ABQ', 'PHX'],
#  ['01070830', '-6', '285', 'ABQ', 'PHX'],
#  ['01070620', '-1', '285', 'ABQ', 'PHX'],
#  ['01070600', '3', '428', 'ABQ', 'SLC'],
#  ['01071230', '-3', '428', 'ABQ', 'SLC'],
#  ['01071815', '-10', '428', 'ABQ', 'SLC'],
#  ['01071239', '0', '971', 'ABQ', 'ORD'],
#  ['01070815', '4', '779', 'ABQ', 'SFO'],
#  ['01071635', '-15', '589', 'ABQ', 'LAX'],
#  ['01081255', '24', '589', 'ABQ', 'LAX'],
#  ['01081225', '-8', '285', 'ABQ', 'PHX'],
#  ['01080830', '-8', '285', 'ABQ', 'PHX'],
#  ['01080620', '-5', '285', 'ABQ', 'PHX'],
#  ['01081835', '-10', '285', 'ABQ', 'PHX'],
#  ['01080600', '-3', '428', 'ABQ', 'SLC'],
#  ['01081230', '-4', '428', 'ABQ', 'SLC'],
#  ['01081815', '-8', '428', 'ABQ', 'SLC'],
#  ['01081239', '3', '971', 'ABQ', 'ORD'],
#  ['01080815', '36', '779', 'ABQ', 'SFO'],
#  ['01081635', '59', '589', 'ABQ', 'LAX'],
#  ['01091255', '11', '589', 'ABQ', 'LAX'],
#  ['01090620', '-7', '285', 'ABQ', 'PHX'],
#  ['01091225', '-7', '285', 'ABQ', 'PHX'],
#  ['01090830', '-7', '285', 'ABQ', 'PHX'],
#  ['01091835', '-8', '285', 'ABQ', 'PHX'],
#  ['01090600', '-2', '428', 'ABQ', 'SLC'],
#  ['01091230', '-3', '428', 'ABQ', 'SLC'],
#  ['01091720', '-4', '428', 'ABQ', 'SLC'],
#  ['01091239', '0', '971', 'ABQ', 'ORD'],
#  ['01090815', '151', '779', 'ABQ', 'SFO'],
#  ['01091635', '0', '589', 'ABQ', 'LAX'],
#  ['01101255', '-6', '589', 'ABQ', 'LAX'],
#  ['01100620', '-1', '285', 'ABQ', 'PHX'],
#  ['01101225', '-5', '285', 'ABQ', 'PHX'],
#  ['01100830', '-5', '285', 'ABQ', 'PHX'],
#  ['01101835', '-10', '285', 'ABQ', 'PHX'],
#  ['01100600', '-2', '428', 'ABQ', 'SLC'],
#  ['01101230', '-8', '428', 'ABQ', 'SLC'],
#  ['01101720', '-9', '428', 'ABQ', 'SLC'],
#  ['01101239', '92', '971', 'ABQ', 'ORD'],
#  ['01100815', '-6', '779', 'ABQ', 'SFO'],
#  ['01101635', '36', '589', 'ABQ', 'LAX'],
#  ['01111255', '-1', '589', 'ABQ', 'LAX'],
#  ['01111225', '-8', '285', 'ABQ', 'PHX'],
#  ['01110830', '-4', '285', 'ABQ', 'PHX'],
#  ['01110620', '-7', '285', 'ABQ', 'PHX'],
#  ['01111835', '-9', '285', 'ABQ', 'PHX'],
#  ['01110800', '-4', '428', 'ABQ', 'SLC'],
#  ['01111230', '-4', '428', 'ABQ', 'SLC'],
#  ['01111101', '8', '646', 'ABQ', 'IAH'],
#  ['01111239', '-8', '971', 'ABQ', 'ORD'],
#  ['01110815', '-4', '779', 'ABQ', 'SFO'],
#  ['01111635', '-5', '589', 'ABQ', 'LAX'],
#  ['01121255', '-2', '589', 'ABQ', 'LAX'],
#  ['01120545', '-8', '589', 'ABQ', 'LAX'],
#  ...]

# %%
departureRDD.count()
# Out:
# 1391579

# %%
#Departure RDD
departureRDD = (sc.textFile('departure_delays.csv', minPartitions=8).map(lambda element: element.split(",")))
departureRDD.collect()
# Out:
# [['date', 'delay', 'distance', 'origin', 'destination'],
#  ['01011245', '6', '602', 'ABE', 'ATL'],
#  ['01020600', '-8', '369', 'ABE', 'DTW'],
#  ['01021245', '-2', '602', 'ABE', 'ATL'],
#  ['01020605', '-4', '602', 'ABE', 'ATL'],
#  ['01031245', '-4', '602', 'ABE', 'ATL'],
#  ['01030605', '0', '602', 'ABE', 'ATL'],
#  ['01041243', '10', '602', 'ABE', 'ATL'],
#  ['01040605', '28', '602', 'ABE', 'ATL'],
#  ['01051245', '88', '602', 'ABE', 'ATL'],
#  ['01050605', '9', '602', 'ABE', 'ATL'],
#  ['01061215', '-6', '602', 'ABE', 'ATL'],
#  ['01061725', '69', '602', 'ABE', 'ATL'],
#  ['01061230', '0', '369', 'ABE', 'DTW'],
#  ['01060625', '-3', '602', 'ABE', 'ATL'],
#  ['01070600', '0', '369', 'ABE', 'DTW'],
#  ['01071725', '0', '602', 'ABE', 'ATL'],
#  ['01071230', '0', '369', 'ABE', 'DTW'],
#  ['01070625', '0', '602', 'ABE', 'ATL'],
#  ['01071219', '0', '569', 'ABE', 'ORD'],
#  ['01080600', '0', '369', 'ABE', 'DTW'],
#  ['01081230', '33', '369', 'ABE', 'DTW'],
#  ['01080625', '1', '602', 'ABE', 'ATL'],
#  ['01080607', '5', '569', 'ABE', 'ORD'],
#  ['01081219', '54', '569', 'ABE', 'ORD'],
#  ['01091215', '43', '602', 'ABE', 'ATL'],
#  ['01090600', '151', '369', 'ABE', 'DTW'],
#  ['01091725', '0', '602', 'ABE', 'ATL'],
#  ['01091230', '-4', '369', 'ABE', 'DTW'],
#  ['01090625', '8', '602', 'ABE', 'ATL'],
#  ['01091219', '83', '569', 'ABE', 'ORD'],
#  ['01101215', '-5', '602', 'ABE', 'ATL'],
#  ['01100600', '-5', '369', 'ABE', 'DTW'],
#  ['01101725', '7', '602', 'ABE', 'ATL'],
#  ['01101230', '-8', '369', 'ABE', 'DTW'],
#  ['01100625', '52', '602', 'ABE', 'ATL'],
#  ['01101219', '0', '569', 'ABE', 'ORD'],
#  ['01111215', '127', '602', 'ABE', 'ATL'],
#  ['01110600', '-9', '369', 'ABE', 'DTW'],
#  ['01110625', '-4', '602', 'ABE', 'ATL'],
#  ['01121215', '-5', '602', 'ABE', 'ATL'],
#  ['01121725', '-1', '602', 'ABE', 'ATL'],
#  ['01131215', '14', '602', 'ABE', 'ATL'],
#  ['01130600', '-7', '369', 'ABE', 'DTW'],
#  ['01131725', '-6', '602', 'ABE', 'ATL'],
#  ['01131230', '-13', '369', 'ABE', 'DTW'],
#  ['01130625', '29', '602', 'ABE', 'ATL'],
#  ['01131219', '-8', '569', 'ABE', 'ORD'],
#  ['01140600', '-9', '369', 'ABE', 'DTW'],
#  ['01141725', '-9', '602', 'ABE', 'ATL'],
#  ['01141230', '-8', '369', 'ABE', 'DTW'],
#  ['01140625', '-5', '602', 'ABE', 'ATL'],
#  ['01141219', '-10', '569', 'ABE', 'ORD'],
#  ['01150600', '0', '369', 'ABE', 'DTW'],
#  ['01151725', '-6', '602', 'ABE', 'ATL'],
#  ['01151230', '0', '369', 'ABE', 'DTW'],
#  ['01150625', '0', '602', 'ABE', 'ATL'],
#  ['01150607', '0', '569', 'ABE', 'ORD'],
#  ['01151219', '0', '569', 'ABE', 'ORD'],
#  ['01161215', '-10', '602', 'ABE', 'ATL'],
#  ['01160600', '-1', '369', 'ABE', 'DTW'],
#  ['01161725', '-6', '602', 'ABE', 'ATL'],
#  ['01161230', '-7', '369', 'ABE', 'DTW'],
#  ['01160625', '-4', '602', 'ABE', 'ATL'],
#  ['01161219', '68', '569', 'ABE', 'ORD'],
#  ['01171215', '-8', '602', 'ABE', 'ATL'],
#  ['01170600', '-5', '369', 'ABE', 'DTW'],
#  ['01171725', '5', '602', 'ABE', 'ATL'],
#  ['01171230', '-10', '369', 'ABE', 'DTW'],
#  ['01170625', '-6', '602', 'ABE', 'ATL'],
#  ['01171219', '-10', '569', 'ABE', 'ORD'],
#  ['01181215', '-12', '602', 'ABE', 'ATL'],
#  ['01180600', '-13', '369', 'ABE', 'DTW'],
#  ['01180625', '0', '602', 'ABE', 'ATL'],
#  ['01191215', '-16', '602', 'ABE', 'ATL'],
#  ['01191725', '-5', '602', 'ABE', 'ATL'],
#  ['01201215', '-8', '602', 'ABE', 'ATL'],
#  ['01201725', '-5', '602', 'ABE', 'ATL'],
#  ['01201230', '-11', '369', 'ABE', 'DTW'],
#  ['01200625', '-7', '602', 'ABE', 'ATL'],
#  ['01201219', '-6', '569', 'ABE', 'ORD'],
#  ['01210600', '89', '369', 'ABE', 'DTW'],
#  ['01211725', '0', '602', 'ABE', 'ATL'],
#  ['01211230', '44', '369', 'ABE', 'DTW'],
#  ['01210625', '-6', '602', 'ABE', 'ATL'],
#  ['01211219', '9', '569', 'ABE', 'ORD'],
#  ['01220600', '80', '369', 'ABE', 'DTW'],
#  ['01221230', '-5', '369', 'ABE', 'DTW'],
#  ['01220625', '333', '602', 'ABE', 'ATL'],
#  ['01220607', '219', '569', 'ABE', 'ORD'],
#  ['01221219', '15', '569', 'ABE', 'ORD'],
#  ['01231215', '-12', '602', 'ABE', 'ATL'],
#  ['01230600', '-3', '369', 'ABE', 'DTW'],
#  ['01231725', '180', '602', 'ABE', 'ATL'],
#  ['01231230', '-5', '369', 'ABE', 'DTW'],
#  ['01230625', '-8', '602', 'ABE', 'ATL'],
#  ['01231219', '-13', '569', 'ABE', 'ORD'],
#  ['01241215', '-11', '602', 'ABE', 'ATL'],
#  ['01240600', '-3', '369', 'ABE', 'DTW'],
#  ['01241725', '2', '602', 'ABE', 'ATL'],
#  ['01241230', '-5', '369', 'ABE', 'DTW'],
#  ['01240625', '-3', '602', 'ABE', 'ATL'],
#  ['01241219', '0', '569', 'ABE', 'ORD'],
#  ['01251215', '2', '602', 'ABE', 'ATL'],
#  ['01250600', '-4', '369', 'ABE', 'DTW'],
#  ['01250625', '-4', '602', 'ABE', 'ATL'],
#  ['01261215', '1', '602', 'ABE', 'ATL'],
#  ['01261725', '7', '602', 'ABE', 'ATL'],
#  ['01271215', '-4', '602', 'ABE', 'ATL'],
#  ['01270600', '-9', '369', 'ABE', 'DTW'],
#  ['01271725', '-8', '602', 'ABE', 'ATL'],
#  ['01271230', '-7', '369', 'ABE', 'DTW'],
#  ['01270625', '-1', '602', 'ABE', 'ATL'],
#  ['01271219', '0', '569', 'ABE', 'ORD'],
#  ['01280600', '-6', '369', 'ABE', 'DTW'],
#  ['01281725', '-3', '602', 'ABE', 'ATL'],
#  ['01281230', '-8', '369', 'ABE', 'DTW'],
#  ['01280625', '-4', '602', 'ABE', 'ATL'],
#  ['01281219', '0', '569', 'ABE', 'ORD'],
#  ['01290600', '0', '369', 'ABE', 'DTW'],
#  ['01291230', '0', '369', 'ABE', 'DTW'],
#  ['01290625', '4', '602', 'ABE', 'ATL'],
#  ['01290607', '92', '569', 'ABE', 'ORD'],
#  ['01291219', '-10', '569', 'ABE', 'ORD'],
#  ['01301215', '0', '602', 'ABE', 'ATL'],
#  ['01300600', '-1', '369', 'ABE', 'DTW'],
#  ['01301725', '10', '602', 'ABE', 'ATL'],
#  ['01301230', '0', '369', 'ABE', 'DTW'],
#  ['01300625', '0', '602', 'ABE', 'ATL'],
#  ['01301219', '-11', '569', 'ABE', 'ORD'],
#  ['01311215', '1', '602', 'ABE', 'ATL'],
#  ['01310600', '-4', '369', 'ABE', 'DTW'],
#  ['01311725', '25', '602', 'ABE', 'ATL'],
#  ['01311230', '-4', '369', 'ABE', 'DTW'],
#  ['01310625', '-5', '602', 'ABE', 'ATL'],
#  ['01311219', '24', '569', 'ABE', 'ORD'],
#  ['01011400', '26', '137', 'ABI', 'DFW'],
#  ['01011525', '-11', '137', 'ABI', 'DFW'],
#  ['01021400', '-5', '137', 'ABI', 'DFW'],
#  ['01021525', '47', '137', 'ABI', 'DFW'],
#  ['01031400', '-12', '137', 'ABI', 'DFW'],
#  ['01031525', '40', '137', 'ABI', 'DFW'],
#  ['01041400', '-12', '137', 'ABI', 'DFW'],
#  ['01041525', '3', '137', 'ABI', 'DFW'],
#  ['01051400', '-5', '137', 'ABI', 'DFW'],
#  ['01051525', '-5', '137', 'ABI', 'DFW'],
#  ['01061400', '2', '137', 'ABI', 'DFW'],
#  ['01061525', '22', '137', 'ABI', 'DFW'],
#  ['01071400', '-12', '137', 'ABI', 'DFW'],
#  ['01071525', '-15', '137', 'ABI', 'DFW'],
#  ['01081525', '21', '137', 'ABI', 'DFW'],
#  ['01091525', '-8', '137', 'ABI', 'DFW'],
#  ['01101525', '4', '137', 'ABI', 'DFW'],
#  ['01111525', '-23', '137', 'ABI', 'DFW'],
#  ['01121525', '-9', '137', 'ABI', 'DFW'],
#  ['01131525', '-12', '137', 'ABI', 'DFW'],
#  ['01141525', '-5', '137', 'ABI', 'DFW'],
#  ['01151525', '-17', '137', 'ABI', 'DFW'],
#  ['01161525', '2', '137', 'ABI', 'DFW'],
#  ['01171525', '-9', '137', 'ABI', 'DFW'],
#  ['01181525', '-5', '137', 'ABI', 'DFW'],
#  ['01191525', '-3', '137', 'ABI', 'DFW'],
#  ['01201525', '-6', '137', 'ABI', 'DFW'],
#  ['01211525', '-17', '137', 'ABI', 'DFW'],
#  ['01221525', '40', '137', 'ABI', 'DFW'],
#  ['01231525', '-12', '137', 'ABI', 'DFW'],
#  ['01241525', '21', '137', 'ABI', 'DFW'],
#  ['01251525', '-6', '137', 'ABI', 'DFW'],
#  ['01261525', '-12', '137', 'ABI', 'DFW'],
#  ['01271525', '-13', '137', 'ABI', 'DFW'],
#  ['01281525', '-10', '137', 'ABI', 'DFW'],
#  ['01291525', '146', '137', 'ABI', 'DFW'],
#  ['01301525', '-13', '137', 'ABI', 'DFW'],
#  ['01311525', '6', '137', 'ABI', 'DFW'],
#  ['01010925', '-9', '137', 'ABI', 'DFW'],
#  ['01011730', '72', '137', 'ABI', 'DFW'],
#  ['01010700', '-5', '137', 'ABI', 'DFW'],
#  ['01011155', '-6', '137', 'ABI', 'DFW'],
#  ['01010810', '62', '137', 'ABI', 'DFW'],
#  ['01020550', '-7', '137', 'ABI', 'DFW'],
#  ['01020925', '7', '137', 'ABI', 'DFW'],
#  ['01021730', '27', '137', 'ABI', 'DFW'],
#  ['01020700', '150', '137', 'ABI', 'DFW'],
#  ['01021155', '0', '137', 'ABI', 'DFW'],
#  ['01020810', '1', '137', 'ABI', 'DFW'],
#  ['01030550', '51', '137', 'ABI', 'DFW'],
#  ['01030925', '-7', '137', 'ABI', 'DFW'],
#  ['01031730', '-18', '137', 'ABI', 'DFW'],
#  ['01030700', '2', '137', 'ABI', 'DFW'],
#  ['01031155', '48', '137', 'ABI', 'DFW'],
#  ['01030810', '-3', '137', 'ABI', 'DFW'],
#  ['01040925', '-7', '137', 'ABI', 'DFW'],
#  ['01041730', '135', '137', 'ABI', 'DFW'],
#  ['01040700', '-3', '137', 'ABI', 'DFW'],
#  ['01041155', '-2', '137', 'ABI', 'DFW'],
#  ['01040810', '-12', '137', 'ABI', 'DFW'],
#  ['01050550', '-8', '137', 'ABI', 'DFW'],
#  ['01050925', '-10', '137', 'ABI', 'DFW'],
#  ['01051730', '-2', '137', 'ABI', 'DFW'],
#  ['01050700', '-6', '137', 'ABI', 'DFW'],
#  ['01051155', '-2', '137', 'ABI', 'DFW'],
#  ['01050810', '-12', '137', 'ABI', 'DFW'],
#  ['01060550', '-8', '137', 'ABI', 'DFW'],
#  ['01060925', '0', '137', 'ABI', 'DFW'],
#  ['01061730', '-7', '137', 'ABI', 'DFW'],
#  ['01060700', '-3', '137', 'ABI', 'DFW'],
#  ['01061155', '-4', '137', 'ABI', 'DFW'],
#  ['01060810', '-8', '137', 'ABI', 'DFW'],
#  ['01070550', '-3', '137', 'ABI', 'DFW'],
#  ['01070925', '62', '137', 'ABI', 'DFW'],
#  ['01071730', '0', '137', 'ABI', 'DFW'],
#  ['01070700', '4', '137', 'ABI', 'DFW'],
#  ['01071155', '10', '137', 'ABI', 'DFW'],
#  ['01070810', '-10', '137', 'ABI', 'DFW'],
#  ['01080550', '-9', '137', 'ABI', 'DFW'],
#  ['01080925', '-11', '137', 'ABI', 'DFW'],
#  ['01081730', '7', '137', 'ABI', 'DFW'],
#  ['01080700', '-8', '137', 'ABI', 'DFW'],
#  ['01081155', '-11', '137', 'ABI', 'DFW'],
#  ['01080810', '-13', '137', 'ABI', 'DFW'],
#  ['01081400', '10', '137', 'ABI', 'DFW'],
#  ['01090550', '395', '137', 'ABI', 'DFW'],
#  ['01090925', '0', '137', 'ABI', 'DFW'],
#  ['01091730', '38', '137', 'ABI', 'DFW'],
#  ['01090700', '6', '137', 'ABI', 'DFW'],
#  ['01091155', '21', '137', 'ABI', 'DFW'],
#  ['01090810', '16', '137', 'ABI', 'DFW'],
#  ['01091400', '-6', '137', 'ABI', 'DFW'],
#  ['01100550', '-4', '137', 'ABI', 'DFW'],
#  ['01100925', '34', '137', 'ABI', 'DFW'],
#  ['01101730', '-2', '137', 'ABI', 'DFW'],
#  ['01100700', '129', '137', 'ABI', 'DFW'],
#  ['01101155', '-1', '137', 'ABI', 'DFW'],
#  ['01100810', '-11', '137', 'ABI', 'DFW'],
#  ['01101400', '30', '137', 'ABI', 'DFW'],
#  ['01110905', '-8', '137', 'ABI', 'DFW'],
#  ['01111730', '-14', '137', 'ABI', 'DFW'],
#  ['01110700', '-5', '137', 'ABI', 'DFW'],
#  ['01111155', '16', '137', 'ABI', 'DFW'],
#  ['01110810', '-6', '137', 'ABI', 'DFW'],
#  ['01111400', '39', '137', 'ABI', 'DFW'],
#  ['01120550', '-12', '137', 'ABI', 'DFW'],
#  ['01120925', '-5', '137', 'ABI', 'DFW'],
#  ['01121730', '-9', '137', 'ABI', 'DFW'],
#  ['01120700', '35', '137', 'ABI', 'DFW'],
#  ['01121155', '158', '137', 'ABI', 'DFW'],
#  ['01120810', '-9', '137', 'ABI', 'DFW'],
#  ['01121400', '-9', '137', 'ABI', 'DFW'],
#  ['01130550', '-5', '137', 'ABI', 'DFW'],
#  ['01130925', '-7', '137', 'ABI', 'DFW'],
#  ['01131730', '-9', '137', 'ABI', 'DFW'],
#  ['01130700', '-9', '137', 'ABI', 'DFW'],
#  ['01131155', '-10', '137', 'ABI', 'DFW'],
#  ['01130810', '-7', '137', 'ABI', 'DFW'],
#  ['01131400', '-1', '137', 'ABI', 'DFW'],
#  ['01140550', '0', '137', 'ABI', 'DFW'],
#  ['01140925', '4', '137', 'ABI', 'DFW'],
#  ['01141730', '-13', '137', 'ABI', 'DFW'],
#  ['01140700', '49', '137', 'ABI', 'DFW'],
#  ['01141155', '-10', '137', 'ABI', 'DFW'],
#  ['01140810', '-8', '137', 'ABI', 'DFW'],
#  ['01141400', '-17', '137', 'ABI', 'DFW'],
#  ['01150550', '-11', '137', 'ABI', 'DFW'],
#  ['01150925', '-6', '137', 'ABI', 'DFW'],
#  ['01151730', '-9', '137', 'ABI', 'DFW'],
#  ['01150700', '-8', '137', 'ABI', 'DFW'],
#  ['01151155', '-5', '137', 'ABI', 'DFW'],
#  ['01150810', '-12', '137', 'ABI', 'DFW'],
#  ['01151400', '-3', '137', 'ABI', 'DFW'],
#  ['01160550', '-2', '137', 'ABI', 'DFW'],
#  ['01160925', '-12', '137', 'ABI', 'DFW'],
#  ['01161730', '-3', '137', 'ABI', 'DFW'],
#  ['01160700', '-8', '137', 'ABI', 'DFW'],
#  ['01161155', '56', '137', 'ABI', 'DFW'],
#  ['01160810', '-10', '137', 'ABI', 'DFW'],
#  ['01161400', '8', '137', 'ABI', 'DFW'],
#  ['01170550', '-1', '137', 'ABI', 'DFW'],
#  ['01170925', '-6', '137', 'ABI', 'DFW'],
#  ['01171730', '-5', '137', 'ABI', 'DFW'],
#  ['01170700', '-12', '137', 'ABI', 'DFW'],
#  ['01171155', '18', '137', 'ABI', 'DFW'],
#  ['01170810', '-11', '137', 'ABI', 'DFW'],
#  ['01171400', '-7', '137', 'ABI', 'DFW'],
#  ['01180905', '-7', '137', 'ABI', 'DFW'],
#  ['01181730', '-9', '137', 'ABI', 'DFW'],
#  ['01180700', '-10', '137', 'ABI', 'DFW'],
#  ['01181155', '-11', '137', 'ABI', 'DFW'],
#  ['01180810', '-13', '137', 'ABI', 'DFW'],
#  ['01181400', '6', '137', 'ABI', 'DFW'],
#  ['01190550', '-12', '137', 'ABI', 'DFW'],
#  ['01190925', '-12', '137', 'ABI', 'DFW'],
#  ['01191730', '-12', '137', 'ABI', 'DFW'],
#  ['01190700', '-9', '137', 'ABI', 'DFW'],
#  ['01191155', '-11', '137', 'ABI', 'DFW'],
#  ['01190810', '-22', '137', 'ABI', 'DFW'],
#  ['01191400', '-12', '137', 'ABI', 'DFW'],
#  ['01200550', '-9', '137', 'ABI', 'DFW'],
#  ['01200925', '-8', '137', 'ABI', 'DFW'],
#  ['01201730', '-8', '137', 'ABI', 'DFW'],
#  ['01200700', '-8', '137', 'ABI', 'DFW'],
#  ['01201155', '-5', '137', 'ABI', 'DFW'],
#  ['01200810', '19', '137', 'ABI', 'DFW'],
#  ['01201400', '3', '137', 'ABI', 'DFW'],
#  ['01210550', '-7', '137', 'ABI', 'DFW'],
#  ['01210925', '29', '137', 'ABI', 'DFW'],
#  ['01211730', '-9', '137', 'ABI', 'DFW'],
#  ['01210700', '-2', '137', 'ABI', 'DFW'],
#  ['01211155', '0', '137', 'ABI', 'DFW'],
#  ['01210810', '-8', '137', 'ABI', 'DFW'],
#  ['01211400', '-11', '137', 'ABI', 'DFW'],
#  ['01220550', '-12', '137', 'ABI', 'DFW'],
#  ['01220925', '-8', '137', 'ABI', 'DFW'],
#  ['01221730', '-10', '137', 'ABI', 'DFW'],
#  ['01220700', '-8', '137', 'ABI', 'DFW'],
#  ['01221155', '-6', '137', 'ABI', 'DFW'],
#  ['01220810', '-8', '137', 'ABI', 'DFW'],
#  ['01221400', '-4', '137', 'ABI', 'DFW'],
#  ['01230550', '-10', '137', 'ABI', 'DFW'],
#  ['01230925', '15', '137', 'ABI', 'DFW'],
#  ['01231730', '-7', '137', 'ABI', 'DFW'],
#  ['01230700', '-8', '137', 'ABI', 'DFW'],
#  ['01231155', '-5', '137', 'ABI', 'DFW'],
#  ['01230810', '-3', '137', 'ABI', 'DFW'],
#  ['01231400', '37', '137', 'ABI', 'DFW'],
#  ['01240550', '-8', '137', 'ABI', 'DFW'],
#  ['01240925', '-7', '137', 'ABI', 'DFW'],
#  ['01241730', '61', '137', 'ABI', 'DFW'],
#  ['01240700', '-14', '137', 'ABI', 'DFW'],
#  ['01241155', '-6', '137', 'ABI', 'DFW'],
#  ['01240810', '-6', '137', 'ABI', 'DFW'],
#  ['01241400', '-7', '137', 'ABI', 'DFW'],
#  ['01250905', '-13', '137', 'ABI', 'DFW'],
#  ['01251730', '-14', '137', 'ABI', 'DFW'],
#  ['01250700', '-6', '137', 'ABI', 'DFW'],
#  ['01251155', '-5', '137', 'ABI', 'DFW'],
#  ['01250810', '-14', '137', 'ABI', 'DFW'],
#  ['01251400', '-26', '137', 'ABI', 'DFW'],
#  ['01260550', '-8', '137', 'ABI', 'DFW'],
#  ['01260925', '-8', '137', 'ABI', 'DFW'],
#  ['01261730', '-4', '137', 'ABI', 'DFW'],
#  ['01260700', '-9', '137', 'ABI', 'DFW'],
#  ['01261155', '-13', '137', 'ABI', 'DFW'],
#  ['01260810', '-9', '137', 'ABI', 'DFW'],
#  ['01261400', '-11', '137', 'ABI', 'DFW'],
#  ['01270550', '-7', '137', 'ABI', 'DFW'],
#  ['01270925', '-5', '137', 'ABI', 'DFW'],
#  ['01271730', '-3', '137', 'ABI', 'DFW'],
#  ['01270700', '-7', '137', 'ABI', 'DFW'],
#  ['01271155', '-6', '137', 'ABI', 'DFW'],
#  ['01270810', '-10', '137', 'ABI', 'DFW'],
#  ['01271400', '-9', '137', 'ABI', 'DFW'],
#  ['01280550', '0', '137', 'ABI', 'DFW'],
#  ['01280925', '-4', '137', 'ABI', 'DFW'],
#  ['01281730', '-10', '137', 'ABI', 'DFW'],
#  ['01280700', '-6', '137', 'ABI', 'DFW'],
#  ['01281155', '-4', '137', 'ABI', 'DFW'],
#  ['01280810', '-5', '137', 'ABI', 'DFW'],
#  ['01281400', '-6', '137', 'ABI', 'DFW'],
#  ['01290550', '-5', '137', 'ABI', 'DFW'],
#  ['01290925', '57', '137', 'ABI', 'DFW'],
#  ['01291730', '8', '137', 'ABI', 'DFW'],
#  ['01290700', '-6', '137', 'ABI', 'DFW'],
#  ['01291155', '3', '137', 'ABI', 'DFW'],
#  ['01290810', '-8', '137', 'ABI', 'DFW'],
#  ['01291400', '-13', '137', 'ABI', 'DFW'],
#  ['01300550', '-4', '137', 'ABI', 'DFW'],
#  ['01300925', '-6', '137', 'ABI', 'DFW'],
#  ['01301730', '-7', '137', 'ABI', 'DFW'],
#  ['01300700', '-7', '137', 'ABI', 'DFW'],
#  ['01301155', '-6', '137', 'ABI', 'DFW'],
#  ['01300810', '-11', '137', 'ABI', 'DFW'],
#  ['01301400', '-13', '137', 'ABI', 'DFW'],
#  ['01310550', '-2', '137', 'ABI', 'DFW'],
#  ['01310925', '27', '137', 'ABI', 'DFW'],
#  ['01311730', '-6', '137', 'ABI', 'DFW'],
#  ['01310700', '-7', '137', 'ABI', 'DFW'],
#  ['01311155', '2', '137', 'ABI', 'DFW'],
#  ['01310810', '29', '137', 'ABI', 'DFW'],
#  ['01311400', '-13', '137', 'ABI', 'DFW'],
#  ['01011405', '1', '494', 'ABQ', 'DFW'],
#  ['01011520', '0', '494', 'ABQ', 'DFW'],
#  ['01010605', '-5', '494', 'ABQ', 'DFW'],
#  ['01010835', '-7', '494', 'ABQ', 'DFW'],
#  ['01010730', '-1', '494', 'ABQ', 'DFW'],
#  ['01011030', '-2', '494', 'ABQ', 'DFW'],
#  ['01011135', '-2', '494', 'ABQ', 'DFW'],
#  ['01021405', '8', '494', 'ABQ', 'DFW'],
#  ['01021520', '1', '494', 'ABQ', 'DFW'],
#  ['01020605', '118', '494', 'ABQ', 'DFW'],
#  ['01020835', '59', '494', 'ABQ', 'DFW'],
#  ['01020730', '87', '494', 'ABQ', 'DFW'],
#  ['01021030', '85', '494', 'ABQ', 'DFW'],
#  ['01021135', '115', '494', 'ABQ', 'DFW'],
#  ['01021655', '87', '494', 'ABQ', 'DFW'],
#  ['01031405', '38', '494', 'ABQ', 'DFW'],
#  ['01031520', '36', '494', 'ABQ', 'DFW'],
#  ['01030605', '2', '494', 'ABQ', 'DFW'],
#  ['01030835', '33', '494', 'ABQ', 'DFW'],
#  ['01030730', '-4', '494', 'ABQ', 'DFW'],
#  ['01031030', '-1', '494', 'ABQ', 'DFW'],
#  ['01031135', '-7', '494', 'ABQ', 'DFW'],
#  ['01031655', '85', '494', 'ABQ', 'DFW'],
#  ['01041405', '0', '494', 'ABQ', 'DFW'],
#  ['01041520', '0', '494', 'ABQ', 'DFW'],
#  ['01040605', '1', '494', 'ABQ', 'DFW'],
#  ['01040835', '-7', '494', 'ABQ', 'DFW'],
#  ['01040730', '0', '494', 'ABQ', 'DFW'],
#  ['01041030', '10', '494', 'ABQ', 'DFW'],
#  ['01041135', '-4', '494', 'ABQ', 'DFW'],
#  ['01051405', '47', '494', 'ABQ', 'DFW'],
#  ['01051520', '59', '494', 'ABQ', 'DFW'],
#  ['01050605', '1', '494', 'ABQ', 'DFW'],
#  ['01050835', '-2', '494', 'ABQ', 'DFW'],
#  ['01050730', '-2', '494', 'ABQ', 'DFW'],
#  ['01051030', '30', '494', 'ABQ', 'DFW'],
#  ['01051135', '9', '494', 'ABQ', 'DFW'],
#  ['01051655', '9', '494', 'ABQ', 'DFW'],
#  ['01061405', '25', '494', 'ABQ', 'DFW'],
#  ['01061520', '36', '494', 'ABQ', 'DFW'],
#  ['01060605', '-4', '494', 'ABQ', 'DFW'],
#  ['01060835', '-2', '494', 'ABQ', 'DFW'],
#  ['01060730', '-7', '494', 'ABQ', 'DFW'],
#  ['01061030', '-3', '494', 'ABQ', 'DFW'],
#  ['01061135', '71', '494', 'ABQ', 'DFW'],
#  ['01061655', '0', '494', 'ABQ', 'DFW'],
#  ['01071405', '78', '494', 'ABQ', 'DFW'],
#  ['01071520', '4', '494', 'ABQ', 'DFW'],
#  ['01070605', '0', '494', 'ABQ', 'DFW'],
#  ['01070835', '173', '494', 'ABQ', 'DFW'],
#  ['01070730', '-4', '494', 'ABQ', 'DFW'],
#  ['01071030', '1', '494', 'ABQ', 'DFW'],
#  ['01071135', '0', '494', 'ABQ', 'DFW'],
#  ['01081405', '-6', '494', 'ABQ', 'DFW'],
#  ['01081520', '17', '494', 'ABQ', 'DFW'],
#  ['01080605', '-7', '494', 'ABQ', 'DFW'],
#  ['01080835', '-6', '494', 'ABQ', 'DFW'],
#  ['01080730', '-5', '494', 'ABQ', 'DFW'],
#  ['01081030', '-6', '494', 'ABQ', 'DFW'],
#  ['01081135', '-1', '494', 'ABQ', 'DFW'],
#  ['01091405', '18', '494', 'ABQ', 'DFW'],
#  ['01091520', '-3', '494', 'ABQ', 'DFW'],
#  ['01090605', '-8', '494', 'ABQ', 'DFW'],
#  ['01090835', '-12', '494', 'ABQ', 'DFW'],
#  ['01090730', '-8', '494', 'ABQ', 'DFW'],
#  ['01091030', '9', '494', 'ABQ', 'DFW'],
#  ['01091135', '0', '494', 'ABQ', 'DFW'],
#  ['01101405', '-6', '494', 'ABQ', 'DFW'],
#  ['01101520', '-8', '494', 'ABQ', 'DFW'],
#  ['01100605', '-10', '494', 'ABQ', 'DFW'],
#  ['01100835', '-15', '494', 'ABQ', 'DFW'],
#  ['01100730', '-6', '494', 'ABQ', 'DFW'],
#  ['01101030', '-4', '494', 'ABQ', 'DFW'],
#  ['01101135', '-14', '494', 'ABQ', 'DFW'],
#  ['01111405', '43', '494', 'ABQ', 'DFW'],
#  ['01111520', '-8', '494', 'ABQ', 'DFW'],
#  ['01110605', '-6', '494', 'ABQ', 'DFW'],
#  ['01110835', '-9', '494', 'ABQ', 'DFW'],
#  ['01110730', '-8', '494', 'ABQ', 'DFW'],
#  ['01111030', '-7', '494', 'ABQ', 'DFW'],
#  ['01111135', '3', '494', 'ABQ', 'DFW'],
#  ['01121405', '-9', '494', 'ABQ', 'DFW'],
#  ['01121520', '-7', '494', 'ABQ', 'DFW'],
#  ['01120835', '-11', '494', 'ABQ', 'DFW'],
#  ['01120730', '-4', '494', 'ABQ', 'DFW'],
#  ['01121030', '-1', '494', 'ABQ', 'DFW'],
#  ['01121135', '-9', '494', 'ABQ', 'DFW'],
#  ['01131405', '2', '494', 'ABQ', 'DFW'],
#  ['01131520', '-12', '494', 'ABQ', 'DFW'],
#  ['01130605', '-8', '494', 'ABQ', 'DFW'],
#  ['01130835', '-12', '494', 'ABQ', 'DFW'],
#  ['01130730', '-3', '494', 'ABQ', 'DFW'],
#  ['01131030', '-10', '494', 'ABQ', 'DFW'],
#  ['01131135', '-7', '494', 'ABQ', 'DFW'],
#  ['01141405', '-6', '494', 'ABQ', 'DFW'],
#  ['01141520', '-4', '494', 'ABQ', 'DFW'],
#  ['01140605', '-5', '494', 'ABQ', 'DFW'],
#  ['01140835', '-7', '494', 'ABQ', 'DFW'],
#  ['01140730', '-9', '494', 'ABQ', 'DFW'],
#  ['01141030', '-7', '494', 'ABQ', 'DFW'],
#  ['01141135', '-6', '494', 'ABQ', 'DFW'],
#  ['01151405', '-3', '494', 'ABQ', 'DFW'],
#  ['01151520', '-4', '494', 'ABQ', 'DFW'],
#  ['01150605', '-4', '494', 'ABQ', 'DFW'],
#  ['01150835', '-10', '494', 'ABQ', 'DFW'],
#  ['01150730', '4', '494', 'ABQ', 'DFW'],
#  ['01151030', '-8', '494', 'ABQ', 'DFW'],
#  ['01151135', '-8', '494', 'ABQ', 'DFW'],
#  ['01161405', '43', '494', 'ABQ', 'DFW'],
#  ['01161520', '58', '494', 'ABQ', 'DFW'],
#  ['01160605', '-3', '494', 'ABQ', 'DFW'],
#  ['01160835', '-8', '494', 'ABQ', 'DFW'],
#  ['01160730', '-6', '494', 'ABQ', 'DFW'],
#  ['01161030', '-6', '494', 'ABQ', 'DFW'],
#  ['01161135', '-4', '494', 'ABQ', 'DFW'],
#  ['01171405', '-5', '494', 'ABQ', 'DFW'],
#  ['01171520', '-1', '494', 'ABQ', 'DFW'],
#  ['01170605', '-6', '494', 'ABQ', 'DFW'],
#  ['01170835', '0', '494', 'ABQ', 'DFW'],
#  ['01170730', '8', '494', 'ABQ', 'DFW'],
#  ['01171030', '-6', '494', 'ABQ', 'DFW'],
#  ['01171135', '-1', '494', 'ABQ', 'DFW'],
#  ['01181405', '0', '494', 'ABQ', 'DFW'],
#  ['01181520', '38', '494', 'ABQ', 'DFW'],
#  ['01180605', '-12', '494', 'ABQ', 'DFW'],
#  ['01180835', '-9', '494', 'ABQ', 'DFW'],
#  ['01180730', '-4', '494', 'ABQ', 'DFW'],
#  ['01181030', '-9', '494', 'ABQ', 'DFW'],
#  ['01181135', '-4', '494', 'ABQ', 'DFW'],
#  ['01191405', '-2', '494', 'ABQ', 'DFW'],
#  ['01191520', '-4', '494', 'ABQ', 'DFW'],
#  ['01190835', '-8', '494', 'ABQ', 'DFW'],
#  ['01190730', '-9', '494', 'ABQ', 'DFW'],
#  ['01191030', '-15', '494', 'ABQ', 'DFW'],
#  ['01191135', '-8', '494', 'ABQ', 'DFW'],
#  ['01201405', '-4', '494', 'ABQ', 'DFW'],
#  ['01201520', '-10', '494', 'ABQ', 'DFW'],
#  ['01200605', '-3', '494', 'ABQ', 'DFW'],
#  ['01200835', '-6', '494', 'ABQ', 'DFW'],
#  ['01200730', '-3', '494', 'ABQ', 'DFW'],
#  ['01201030', '-10', '494', 'ABQ', 'DFW'],
#  ['01201135', '-8', '494', 'ABQ', 'DFW'],
#  ['01211405', '-8', '494', 'ABQ', 'DFW'],
#  ['01211520', '2', '494', 'ABQ', 'DFW'],
#  ['01210605', '-12', '494', 'ABQ', 'DFW'],
#  ['01210835', '-9', '494', 'ABQ', 'DFW'],
#  ['01210730', '-12', '494', 'ABQ', 'DFW'],
#  ['01211030', '-5', '494', 'ABQ', 'DFW'],
#  ['01211135', '-11', '494', 'ABQ', 'DFW'],
#  ['01221405', '-9', '494', 'ABQ', 'DFW'],
#  ['01221520', '-6', '494', 'ABQ', 'DFW'],
#  ['01220605', '-10', '494', 'ABQ', 'DFW'],
#  ['01220835', '-7', '494', 'ABQ', 'DFW'],
#  ['01220730', '-4', '494', 'ABQ', 'DFW'],
#  ['01221030', '87', '494', 'ABQ', 'DFW'],
#  ['01221135', '-4', '494', 'ABQ', 'DFW'],
#  ['01231405', '76', '494', 'ABQ', 'DFW'],
#  ['01231520', '33', '494', 'ABQ', 'DFW'],
#  ['01230605', '-5', '494', 'ABQ', 'DFW'],
#  ['01230835', '-5', '494', 'ABQ', 'DFW'],
#  ['01230730', '-6', '494', 'ABQ', 'DFW'],
#  ['01231030', '62', '494', 'ABQ', 'DFW'],
#  ['01231135', '-1', '494', 'ABQ', 'DFW'],
#  ['01241405', '79', '494', 'ABQ', 'DFW'],
#  ['01241520', '6', '494', 'ABQ', 'DFW'],
#  ['01240605', '68', '494', 'ABQ', 'DFW'],
#  ['01240835', '3', '494', 'ABQ', 'DFW'],
#  ['01240730', '97', '494', 'ABQ', 'DFW'],
#  ['01241030', '-2', '494', 'ABQ', 'DFW'],
#  ['01241135', '0', '494', 'ABQ', 'DFW'],
#  ['01251405', '-7', '494', 'ABQ', 'DFW'],
#  ['01251520', '11', '494', 'ABQ', 'DFW'],
#  ['01250605', '-10', '494', 'ABQ', 'DFW'],
#  ['01250835', '-13', '494', 'ABQ', 'DFW'],
#  ['01250730', '-2', '494', 'ABQ', 'DFW'],
#  ['01251030', '-4', '494', 'ABQ', 'DFW'],
#  ['01251135', '-9', '494', 'ABQ', 'DFW'],
#  ['01261405', '-5', '494', 'ABQ', 'DFW'],
#  ['01261520', '11', '494', 'ABQ', 'DFW'],
#  ['01260835', '-5', '494', 'ABQ', 'DFW'],
#  ['01260730', '-2', '494', 'ABQ', 'DFW'],
#  ['01261030', '-6', '494', 'ABQ', 'DFW'],
#  ['01261135', '1', '494', 'ABQ', 'DFW'],
#  ['01271405', '-11', '494', 'ABQ', 'DFW'],
#  ['01271520', '-2', '494', 'ABQ', 'DFW'],
#  ['01270605', '0', '494', 'ABQ', 'DFW'],
#  ['01270835', '-13', '494', 'ABQ', 'DFW'],
#  ['01270730', '-12', '494', 'ABQ', 'DFW'],
#  ['01271030', '-6', '494', 'ABQ', 'DFW'],
#  ['01271135', '2', '494', 'ABQ', 'DFW'],
#  ['01281405', '0', '494', 'ABQ', 'DFW'],
#  ['01281520', '-8', '494', 'ABQ', 'DFW'],
#  ['01280605', '-12', '494', 'ABQ', 'DFW'],
#  ['01280835', '-4', '494', 'ABQ', 'DFW'],
#  ['01280730', '-10', '494', 'ABQ', 'DFW'],
#  ['01281030', '-6', '494', 'ABQ', 'DFW'],
#  ['01281135', '-7', '494', 'ABQ', 'DFW'],
#  ['01291405', '8', '494', 'ABQ', 'DFW'],
#  ['01291520', '-4', '494', 'ABQ', 'DFW'],
#  ['01290605', '-6', '494', 'ABQ', 'DFW'],
#  ['01290835', '1', '494', 'ABQ', 'DFW'],
#  ['01290730', '-6', '494', 'ABQ', 'DFW'],
#  ['01291030', '-4', '494', 'ABQ', 'DFW'],
#  ['01291135', '19', '494', 'ABQ', 'DFW'],
#  ['01301405', '-4', '494', 'ABQ', 'DFW'],
#  ['01301520', '-3', '494', 'ABQ', 'DFW'],
#  ['01300605', '-7', '494', 'ABQ', 'DFW'],
#  ['01300835', '-3', '494', 'ABQ', 'DFW'],
#  ['01300730', '-3', '494', 'ABQ', 'DFW'],
#  ['01301030', '0', '494', 'ABQ', 'DFW'],
#  ['01301135', '-1', '494', 'ABQ', 'DFW'],
#  ['01311405', '3', '494', 'ABQ', 'DFW'],
#  ['01311520', '4', '494', 'ABQ', 'DFW'],
#  ['01310605', '-6', '494', 'ABQ', 'DFW'],
#  ['01310835', '-9', '494', 'ABQ', 'DFW'],
#  ['01310730', '-5', '494', 'ABQ', 'DFW'],
#  ['01311030', '1', '494', 'ABQ', 'DFW'],
#  ['01311135', '-8', '494', 'ABQ', 'DFW'],
#  ['01012355', '0', '1586', 'ABQ', 'JFK'],
#  ['01022355', '158', '1586', 'ABQ', 'JFK'],
#  ['01032355', '0', '1586', 'ABQ', 'JFK'],
#  ['01042355', '0', '1586', 'ABQ', 'JFK'],
#  ['01052355', '0', '1586', 'ABQ', 'JFK'],
#  ['01062355', '0', '1586', 'ABQ', 'JFK'],
#  ['01072359', '14', '1586', 'ABQ', 'JFK'],
#  ['01082358', '-4', '1586', 'ABQ', 'JFK'],
#  ['01092358', '20', '1586', 'ABQ', 'JFK'],
#  ['01102358', '-2', '1586', 'ABQ', 'JFK'],
#  ['01112358', '116', '1586', 'ABQ', 'JFK'],
#  ['01122358', '0', '1586', 'ABQ', 'JFK'],
#  ['01132358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01142359', '-17', '1586', 'ABQ', 'JFK'],
#  ['01152358', '135', '1586', 'ABQ', 'JFK'],
#  ['01162358', '-13', '1586', 'ABQ', 'JFK'],
#  ['01172358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01182358', '-17', '1586', 'ABQ', 'JFK'],
#  ['01192358', '-18', '1586', 'ABQ', 'JFK'],
#  ['01202358', '-9', '1586', 'ABQ', 'JFK'],
#  ['01212359', '0', '1586', 'ABQ', 'JFK'],
#  ['01222358', '0', '1586', 'ABQ', 'JFK'],
#  ['01232358', '44', '1586', 'ABQ', 'JFK'],
#  ['01242358', '-6', '1586', 'ABQ', 'JFK'],
#  ['01252358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01262358', '-22', '1586', 'ABQ', 'JFK'],
#  ['01272358', '9', '1586', 'ABQ', 'JFK'],
#  ['01282359', '-20', '1586', 'ABQ', 'JFK'],
#  ['01292358', '17', '1586', 'ABQ', 'JFK'],
#  ['01302358', '7', '1586', 'ABQ', 'JFK'],
#  ['01312358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01011316', '-8', '1103', 'ABQ', 'ATL'],
#  ['01010730', '-4', '1103', 'ABQ', 'ATL'],
#  ['01011440', '-4', '852', 'ABQ', 'MSP'],
#  ['01010700', '-4', '852', 'ABQ', 'MSP'],
#  ['01020730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01020615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01021326', '6', '1103', 'ABQ', 'ATL'],
#  ['01021440', '-4', '852', 'ABQ', 'MSP'],
#  ['01020700', '-4', '852', 'ABQ', 'MSP'],
#  ['01030730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01030615', '0', '1103', 'ABQ', 'ATL'],
#  ['01031326', '6', '1103', 'ABQ', 'ATL'],
#  ['01031440', '6', '852', 'ABQ', 'MSP'],
#  ['01030700', '58', '852', 'ABQ', 'MSP'],
#  ['01040730', '-1', '1103', 'ABQ', 'ATL'],
#  ['01040615', '0', '1103', 'ABQ', 'ATL'],
#  ['01041326', '31', '1103', 'ABQ', 'ATL'],
#  ['01041440', '-3', '852', 'ABQ', 'MSP'],
#  ['01040700', '1', '852', 'ABQ', 'MSP'],
#  ['01051326', '26', '1103', 'ABQ', 'ATL'],
#  ['01050730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01050615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01051440', '40', '852', 'ABQ', 'MSP'],
#  ['01050700', '0', '852', 'ABQ', 'MSP'],
#  ['01060600', '-1', '852', 'ABQ', 'MSP'],
#  ['01061230', '-3', '428', 'ABQ', 'SLC'],
#  ['01061328', '36', '1103', 'ABQ', 'ATL'],
#  ['01060730', '44', '1103', 'ABQ', 'ATL'],
#  ['01060615', '22', '1103', 'ABQ', 'ATL'],
#  ['01071328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01070615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01081328', '16', '1103', 'ABQ', 'ATL'],
#  ['01080615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01091328', '73', '1103', 'ABQ', 'ATL'],
#  ['01090615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01101328', '17', '1103', 'ABQ', 'ATL'],
#  ['01100615', '0', '1103', 'ABQ', 'ATL'],
#  ['01111328', '15', '1103', 'ABQ', 'ATL'],
#  ['01110615', '-1', '1103', 'ABQ', 'ATL'],
#  ['01121328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01120615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01131328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01130615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01141328', '0', '1103', 'ABQ', 'ATL'],
#  ['01140615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01151328', '385', '1103', 'ABQ', 'ATL'],
#  ['01150615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01161328', '11', '1103', 'ABQ', 'ATL'],
#  ['01160615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01171328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01170615', '489', '1103', 'ABQ', 'ATL'],
#  ['01181328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01180615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01191328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01190615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01201328', '9', '1103', 'ABQ', 'ATL'],
#  ['01200615', '0', '1103', 'ABQ', 'ATL'],
#  ['01211328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01210615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01221328', '-5', '1103', 'ABQ', 'ATL'],
#  ['01220615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01231328', '30', '1103', 'ABQ', 'ATL'],
#  ['01230615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01241328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01240615', '1', '1103', 'ABQ', 'ATL'],
#  ['01251328', '-6', '1103', 'ABQ', 'ATL'],
#  ['01250615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01261328', '-1', '1103', 'ABQ', 'ATL'],
#  ['01260615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01271328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01270615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01281328', '0', '1103', 'ABQ', 'ATL'],
#  ['01280615', '0', '1103', 'ABQ', 'ATL'],
#  ['01291328', '141', '1103', 'ABQ', 'ATL'],
#  ['01290615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01301328', '296', '1103', 'ABQ', 'ATL'],
#  ['01300615', '0', '1103', 'ABQ', 'ATL'],
#  ['01311328', '0', '1103', 'ABQ', 'ATL'],
#  ['01310615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01011712', '57', '646', 'ABQ', 'IAH'],
#  ['01011420', '-6', '646', 'ABQ', 'IAH'],
#  ['01011042', '-10', '646', 'ABQ', 'IAH'],
#  ['01010805', '23', '646', 'ABQ', 'IAH'],
#  ['01011933', '0', '303', 'ABQ', 'DEN'],
#  ['01021726', '-6', '646', 'ABQ', 'IAH'],
#  ['01021411', '-6', '646', 'ABQ', 'IAH'],
#  ['01021050', '37', '646', 'ABQ', 'IAH'],
#  ['01020610', '0', '646', 'ABQ', 'IAH'],
#  ['01020536', '0', '303', 'ABQ', 'DEN'],
#  ['01031712', '8', '646', 'ABQ', 'IAH'],
#  ['01031411', '0', '646', 'ABQ', 'IAH'],
#  ['01031050', '0', '646', 'ABQ', 'IAH'],
#  ['01030610', '-1', '646', 'ABQ', 'IAH'],
#  ['01030536', '-7', '303', 'ABQ', 'DEN'],
#  ['01041712', '138', '646', 'ABQ', 'IAH'],
#  ['01041050', '-6', '646', 'ABQ', 'IAH'],
#  ['01040805', '-7', '646', 'ABQ', 'IAH'],
#  ['01040530', '15', '303', 'ABQ', 'DEN'],
#  ['01050805', '-7', '646', 'ABQ', 'IAH'],
#  ['01061712', '26', '646', 'ABQ', 'IAH'],
#  ['01061411', '0', '646', 'ABQ', 'IAH'],
#  ['01061050', '194', '646', 'ABQ', 'IAH'],
#  ['01060610', '-5', '646', 'ABQ', 'IAH'],
#  ['01060536', '0', '303', 'ABQ', 'DEN'],
#  ['01071053', '10', '646', 'ABQ', 'IAH'],
#  ['01071713', '8', '646', 'ABQ', 'IAH'],
#  ['01070903', '0', '646', 'ABQ', 'IAH'],
#  ['01081713', '9', '646', 'ABQ', 'IAH'],
#  ['01080903', '-7', '646', 'ABQ', 'IAH'],
#  ['01081101', '80', '646', 'ABQ', 'IAH'],
#  ['01080736', '-2', '303', 'ABQ', 'DEN'],
#  ['01091713', '51', '646', 'ABQ', 'IAH'],
#  ['01090903', '-7', '646', 'ABQ', 'IAH'],
#  ['01101713', '-6', '646', 'ABQ', 'IAH'],
#  ['01100903', '-7', '646', 'ABQ', 'IAH'],
#  ['01110903', '-12', '646', 'ABQ', 'IAH'],
#  ['01120903', '-7', '646', 'ABQ', 'IAH'],
#  ['01121713', '-4', '646', 'ABQ', 'IAH'],
#  ['01120720', '-1', '303', 'ABQ', 'DEN'],
#  ['01121722', '-12', '303', 'ABQ', 'DEN'],
#  ['01121007', '-10', '303', 'ABQ', 'DEN'],
#  ['01131713', '-4', '646', 'ABQ', 'IAH'],
#  ['01130903', '-6', '646', 'ABQ', 'IAH'],
#  ['01141101', '-9', '646', 'ABQ', 'IAH'],
#  ['01141713', '-10', '646', 'ABQ', 'IAH'],
#  ['01140903', '-10', '646', 'ABQ', 'IAH'],
#  ['01151713', '58', '646', 'ABQ', 'IAH'],
#  ['01150903', '-8', '646', 'ABQ', 'IAH'],
#  ['01151101', '-14', '646', 'ABQ', 'IAH'],
#  ['01150736', '-8', '303', 'ABQ', 'DEN'],
#  ['01161713', '7', '646', 'ABQ', 'IAH'],
#  ['01160903', '-5', '646', 'ABQ', 'IAH'],
#  ['01171713', '-8', '646', 'ABQ', 'IAH'],
#  ['01170903', '23', '646', 'ABQ', 'IAH'],
#  ['01180903', '-10', '646', 'ABQ', 'IAH'],
#  ['01190903', '-7', '646', 'ABQ', 'IAH'],
#  ['01191713', '-2', '646', 'ABQ', 'IAH'],
#  ['01190720', '-5', '303', 'ABQ', 'DEN'],
#  ['01191722', '-14', '303', 'ABQ', 'DEN'],
#  ['01191007', '-9', '303', 'ABQ', 'DEN'],
#  ['01201713', '-2', '646', 'ABQ', 'IAH'],
#  ['01200903', '-3', '646', 'ABQ', 'IAH'],
#  ['01211101', '7', '646', 'ABQ', 'IAH'],
#  ['01211713', '-6', '646', 'ABQ', 'IAH'],
#  ['01210903', '-11', '646', 'ABQ', 'IAH'],
#  ['01221713', '12', '646', 'ABQ', 'IAH'],
#  ['01220903', '-5', '646', 'ABQ', 'IAH'],
#  ['01221101', '-6', '646', 'ABQ', 'IAH'],
#  ['01220736', '-7', '303', 'ABQ', 'DEN'],
#  ['01231713', '0', '646', 'ABQ', 'IAH'],
#  ['01230903', '-6', '646', 'ABQ', 'IAH'],
#  ['01241713', '-8', '646', 'ABQ', 'IAH'],
#  ['01240903', '0', '646', 'ABQ', 'IAH'],
#  ['01250903', '-4', '646', 'ABQ', 'IAH'],
#  ['01260903', '7', '646', 'ABQ', 'IAH'],
#  ['01261713', '1', '646', 'ABQ', 'IAH'],
#  ['01260720', '1', '303', 'ABQ', 'DEN'],
#  ['01261722', '-11', '303', 'ABQ', 'DEN'],
#  ['01261007', '-13', '303', 'ABQ', 'DEN'],
#  ['01271713', '-7', '646', 'ABQ', 'IAH'],
#  ['01270903', '-7', '646', 'ABQ', 'IAH'],
#  ['01281101', '0', '646', 'ABQ', 'IAH'],
#  ['01281713', '0', '646', 'ABQ', 'IAH'],
#  ['01280903', '0', '646', 'ABQ', 'IAH'],
#  ['01291713', '102', '646', 'ABQ', 'IAH'],
#  ['01290903', '146', '646', 'ABQ', 'IAH'],
#  ['01291101', '127', '646', 'ABQ', 'IAH'],
#  ['01290736', '9', '303', 'ABQ', 'DEN'],
#  ['01301713', '-3', '646', 'ABQ', 'IAH'],
#  ['01300903', '-8', '646', 'ABQ', 'IAH'],
#  ['01311713', '1', '646', 'ABQ', 'IAH'],
#  ['01310903', '12', '646', 'ABQ', 'IAH'],
#  ['01011450', '7', '303', 'ABQ', 'DEN'],
#  ['01021450', '32', '303', 'ABQ', 'DEN'],
#  ['01020800', '-8', '303', 'ABQ', 'DEN'],
#  ['01031450', '2', '303', 'ABQ', 'DEN'],
#  ['01030800', '-3', '303', 'ABQ', 'DEN'],
#  ['01040800', '94', '303', 'ABQ', 'DEN'],
#  ['01050800', '-4', '303', 'ABQ', 'DEN'],
#  ['01060800', '140', '303', 'ABQ', 'DEN'],
#  ['01011950', '128', '589', 'ABQ', 'LAX'],
#  ['01010545', '0', '589', 'ABQ', 'LAX'],
#  ['01021950', '95', '589', 'ABQ', 'LAX'],
#  ['01020545', '0', '589', 'ABQ', 'LAX'],
#  ['01031950', '25', '589', 'ABQ', 'LAX'],
#  ['01030545', '0', '589', 'ABQ', 'LAX'],
#  ['01040545', '-4', '589', 'ABQ', 'LAX'],
#  ['01051950', '53', '589', 'ABQ', 'LAX'],
#  ['01061950', '53', '589', 'ABQ', 'LAX'],
#  ['01060545', '22', '589', 'ABQ', 'LAX'],
#  ['01071950', '122', '589', 'ABQ', 'LAX'],
#  ['01070545', '-4', '589', 'ABQ', 'LAX'],
#  ['01081950', '13', '589', 'ABQ', 'LAX'],
#  ['01080545', '33', '589', 'ABQ', 'LAX'],
#  ['01091950', '-8', '589', 'ABQ', 'LAX'],
#  ['01090545', '-4', '589', 'ABQ', 'LAX'],
#  ['01101950', '0', '589', 'ABQ', 'LAX'],
#  ['01100545', '-4', '589', 'ABQ', 'LAX'],
#  ['01110545', '7', '589', 'ABQ', 'LAX'],
#  ['01121950', '-9', '589', 'ABQ', 'LAX'],
#  ['01131950', '0', '589', 'ABQ', 'LAX'],
#  ['01130545', '14', '589', 'ABQ', 'LAX'],
#  ['01141950', '-6', '589', 'ABQ', 'LAX'],
#  ['01140545', '-5', '589', 'ABQ', 'LAX'],
#  ['01151950', '0', '589', 'ABQ', 'LAX'],
#  ['01150545', '0', '589', 'ABQ', 'LAX'],
#  ['01161950', '-7', '589', 'ABQ', 'LAX'],
#  ['01160545', '-1', '589', 'ABQ', 'LAX'],
#  ['01171950', '8', '589', 'ABQ', 'LAX'],
#  ['01170545', '-7', '589', 'ABQ', 'LAX'],
#  ['01180545', '0', '589', 'ABQ', 'LAX'],
#  ['01191950', '33', '589', 'ABQ', 'LAX'],
#  ['01201950', '56', '589', 'ABQ', 'LAX'],
#  ['01200545', '-7', '589', 'ABQ', 'LAX'],
#  ['01211950', '10', '589', 'ABQ', 'LAX'],
#  ['01210545', '-4', '589', 'ABQ', 'LAX'],
#  ['01221950', '58', '589', 'ABQ', 'LAX'],
#  ['01220545', '-8', '589', 'ABQ', 'LAX'],
#  ['01231950', '12', '589', 'ABQ', 'LAX'],
#  ['01230545', '0', '589', 'ABQ', 'LAX'],
#  ['01241950', '-8', '589', 'ABQ', 'LAX'],
#  ['01240545', '0', '589', 'ABQ', 'LAX'],
#  ['01250545', '-7', '589', 'ABQ', 'LAX'],
#  ['01261950', '-9', '589', 'ABQ', 'LAX'],
#  ['01271950', '112', '589', 'ABQ', 'LAX'],
#  ['01270545', '-8', '589', 'ABQ', 'LAX'],
#  ['01281950', '22', '589', 'ABQ', 'LAX'],
#  ['01280545', '-4', '589', 'ABQ', 'LAX'],
#  ['01291950', '62', '589', 'ABQ', 'LAX'],
#  ['01290545', '-7', '589', 'ABQ', 'LAX'],
#  ['01301950', '-8', '589', 'ABQ', 'LAX'],
#  ['01300545', '97', '589', 'ABQ', 'LAX'],
#  ['01311950', '-10', '589', 'ABQ', 'LAX'],
#  ['01310545', '6', '589', 'ABQ', 'LAX'],
#  ['01011225', '10', '589', 'ABQ', 'LAX'],
#  ['01012137', '-8', '285', 'ABQ', 'PHX'],
#  ['01010620', '-7', '285', 'ABQ', 'PHX'],
#  ['01011225', '-4', '285', 'ABQ', 'PHX'],
#  ['01010830', '-5', '285', 'ABQ', 'PHX'],
#  ['01011835', '-6', '285', 'ABQ', 'PHX'],
#  ['01010715', '-2', '428', 'ABQ', 'SLC'],
#  ['01011204', '26', '428', 'ABQ', 'SLC'],
#  ['01011626', '39', '589', 'ABQ', 'LAX'],
#  ['01010600', '-7', '779', 'ABQ', 'SFO'],
#  ['01011047', '25', '589', 'ABQ', 'LAX'],
#  ['01011344', '21', '303', 'ABQ', 'DEN'],
#  ['01021225', '4', '589', 'ABQ', 'LAX'],
#  ['01022137', '-6', '285', 'ABQ', 'PHX'],
#  ['01020620', '1', '285', 'ABQ', 'PHX'],
#  ['01021225', '-6', '285', 'ABQ', 'PHX'],
#  ['01020830', '-3', '285', 'ABQ', 'PHX'],
#  ['01021835', '-8', '285', 'ABQ', 'PHX'],
#  ['01020600', '-2', '428', 'ABQ', 'SLC'],
#  ['01021204', '11', '428', 'ABQ', 'SLC'],
#  ['01021825', '23', '428', 'ABQ', 'SLC'],
#  ['01020600', '0', '779', 'ABQ', 'SFO'],
#  ['01021933', '4', '303', 'ABQ', 'DEN'],
#  ['01021047', '-5', '589', 'ABQ', 'LAX'],
#  ['01021626', '4', '589', 'ABQ', 'LAX'],
#  ['01031225', '42', '589', 'ABQ', 'LAX'],
#  ['01032137', '-5', '285', 'ABQ', 'PHX'],
#  ['01030620', '-8', '285', 'ABQ', 'PHX'],
#  ['01031225', '-5', '285', 'ABQ', 'PHX'],
#  ['01030830', '-4', '285', 'ABQ', 'PHX'],
#  ['01031835', '3', '285', 'ABQ', 'PHX'],
#  ['01030600', '-1', '428', 'ABQ', 'SLC'],
#  ['01031204', '84', '428', 'ABQ', 'SLC'],
#  ['01031825', '-8', '428', 'ABQ', 'SLC'],
#  ['01030600', '-10', '779', 'ABQ', 'SFO'],
#  ['01031933', '-8', '303', 'ABQ', 'DEN'],
#  ['01031047', '-4', '589', 'ABQ', 'LAX'],
#  ['01031626', '2', '589', 'ABQ', 'LAX'],
#  ['01041225', '3', '589', 'ABQ', 'LAX'],
#  ['01042137', '0', '285', 'ABQ', 'PHX'],
#  ['01040620', '-9', '285', 'ABQ', 'PHX'],
#  ['01041225', '-6', '285', 'ABQ', 'PHX'],
#  ['01040830', '-2', '285', 'ABQ', 'PHX'],
#  ['01041835', '-8', '285', 'ABQ', 'PHX'],
#  ['01040600', '-2', '428', 'ABQ', 'SLC'],
#  ['01041204', '40', '428', 'ABQ', 'SLC'],
#  ['01041825', '-3', '428', 'ABQ', 'SLC'],
#  ['01041404', '52', '646', 'ABQ', 'IAH'],
#  ['01041933', '25', '303', 'ABQ', 'DEN'],
#  ['01040600', '-5', '779', 'ABQ', 'SFO'],
#  ['01041047', '45', '589', 'ABQ', 'LAX'],
#  ['01041626', '41', '589', 'ABQ', 'LAX'],
#  ['01051225', '3', '589', 'ABQ', 'LAX'],
#  ['01050545', '83', '589', 'ABQ', 'LAX'],
#  ['01052137', '4', '285', 'ABQ', 'PHX'],
#  ['01050620', '-6', '285', 'ABQ', 'PHX'],
#  ['01051225', '-6', '285', 'ABQ', 'PHX'],
#  ['01050830', '-7', '285', 'ABQ', 'PHX'],
#  ['01051835', '-3', '285', 'ABQ', 'PHX'],
#  ['01050605', '-2', '428', 'ABQ', 'SLC'],
#  ['01051204', '-1', '428', 'ABQ', 'SLC'],
#  ['01051825', '16', '428', 'ABQ', 'SLC'],
#  ['01051040', '-7', '646', 'ABQ', 'IAH'],
#  ['01050615', '-1', '646', 'ABQ', 'IAH'],
#  ['01051721', '70', '646', 'ABQ', 'IAH'],
#  ['01051411', '33', '646', 'ABQ', 'IAH'],
#  ['01051658', '53', '589', 'ABQ', 'LAX'],
#  ['01051933', '19', '303', 'ABQ', 'DEN'],
#  ['01050530', '-4', '303', 'ABQ', 'DEN'],
#  ['01050615', '0', '779', 'ABQ', 'SFO'],
#  ['01051051', '35', '589', 'ABQ', 'LAX'],
#  ['01061225', '3', '589', 'ABQ', 'LAX'],
#  ['01060620', '-2', '285', 'ABQ', 'PHX'],
#  ['01061225', '-4', '285', 'ABQ', 'PHX'],
#  ['01060830', '24', '285', 'ABQ', 'PHX'],
#  ['01061835', '-6', '285', 'ABQ', 'PHX'],
#  ['01060600', '40', '428', 'ABQ', 'SLC'],
#  ['01061720', '-2', '428', 'ABQ', 'SLC'],
#  ['01060600', '0', '779', 'ABQ', 'SFO'],
#  ['01061933', '-1', '303', 'ABQ', 'DEN'],
#  ['01061040', '-3', '589', 'ABQ', 'LAX'],
#  ['01061626', '-7', '589', 'ABQ', 'LAX'],
#  ['01071225', '5', '589', 'ABQ', 'LAX'],
#  ['01071225', '-6', '285', 'ABQ', 'PHX'],
#  ['01070830', '-6', '285', 'ABQ', 'PHX'],
#  ['01070620', '-1', '285', 'ABQ', 'PHX'],
#  ['01070600', '3', '428', 'ABQ', 'SLC'],
#  ['01071230', '-3', '428', 'ABQ', 'SLC'],
#  ['01071815', '-10', '428', 'ABQ', 'SLC'],
#  ['01071239', '0', '971', 'ABQ', 'ORD'],
#  ['01070815', '4', '779', 'ABQ', 'SFO'],
#  ['01071635', '-15', '589', 'ABQ', 'LAX'],
#  ['01081255', '24', '589', 'ABQ', 'LAX'],
#  ['01081225', '-8', '285', 'ABQ', 'PHX'],
#  ['01080830', '-8', '285', 'ABQ', 'PHX'],
#  ['01080620', '-5', '285', 'ABQ', 'PHX'],
#  ['01081835', '-10', '285', 'ABQ', 'PHX'],
#  ['01080600', '-3', '428', 'ABQ', 'SLC'],
#  ['01081230', '-4', '428', 'ABQ', 'SLC'],
#  ['01081815', '-8', '428', 'ABQ', 'SLC'],
#  ['01081239', '3', '971', 'ABQ', 'ORD'],
#  ['01080815', '36', '779', 'ABQ', 'SFO'],
#  ['01081635', '59', '589', 'ABQ', 'LAX'],
#  ['01091255', '11', '589', 'ABQ', 'LAX'],
#  ['01090620', '-7', '285', 'ABQ', 'PHX'],
#  ['01091225', '-7', '285', 'ABQ', 'PHX'],
#  ['01090830', '-7', '285', 'ABQ', 'PHX'],
#  ['01091835', '-8', '285', 'ABQ', 'PHX'],
#  ['01090600', '-2', '428', 'ABQ', 'SLC'],
#  ['01091230', '-3', '428', 'ABQ', 'SLC'],
#  ['01091720', '-4', '428', 'ABQ', 'SLC'],
#  ['01091239', '0', '971', 'ABQ', 'ORD'],
#  ['01090815', '151', '779', 'ABQ', 'SFO'],
#  ['01091635', '0', '589', 'ABQ', 'LAX'],
#  ['01101255', '-6', '589', 'ABQ', 'LAX'],
#  ['01100620', '-1', '285', 'ABQ', 'PHX'],
#  ['01101225', '-5', '285', 'ABQ', 'PHX'],
#  ['01100830', '-5', '285', 'ABQ', 'PHX'],
#  ['01101835', '-10', '285', 'ABQ', 'PHX'],
#  ['01100600', '-2', '428', 'ABQ', 'SLC'],
#  ['01101230', '-8', '428', 'ABQ', 'SLC'],
#  ['01101720', '-9', '428', 'ABQ', 'SLC'],
#  ['01101239', '92', '971', 'ABQ', 'ORD'],
#  ['01100815', '-6', '779', 'ABQ', 'SFO'],
#  ['01101635', '36', '589', 'ABQ', 'LAX'],
#  ['01111255', '-1', '589', 'ABQ', 'LAX'],
#  ['01111225', '-8', '285', 'ABQ', 'PHX'],
#  ['01110830', '-4', '285', 'ABQ', 'PHX'],
#  ['01110620', '-7', '285', 'ABQ', 'PHX'],
#  ['01111835', '-9', '285', 'ABQ', 'PHX'],
#  ['01110800', '-4', '428', 'ABQ', 'SLC'],
#  ['01111230', '-4', '428', 'ABQ', 'SLC'],
#  ['01111101', '8', '646', 'ABQ', 'IAH'],
#  ['01111239', '-8', '971', 'ABQ', 'ORD'],
#  ['01110815', '-4', '779', 'ABQ', 'SFO'],
#  ['01111635', '-5', '589', 'ABQ', 'LAX'],
#  ['01121255', '-2', '589', 'ABQ', 'LAX'],
#  ['01120545', '-8', '589', 'ABQ', 'LAX'],
#  ...]

# %%
departureRDD.count()
# Out:
# 1391579

# %%
# Use map() to extract out the first two columns
departureRDD.map(lambda c: (c[0], c[1])).take(5)
# Out:
# [('date', 'delay'),
#  ('01011245', '6'),
#  ('01020600', '-8'),
#  ('01021245', '-2'),
#  ('01020605', '-4')]

# %%
# User filter() to filter where second column == "WA"
(aiportRDD.map(lambda c: (c[0], c[1])).filter(lambda c: c[1] == "WA").take(5))
# Out:
# [('Bellingham', 'WA'),
#  ('Moses Lake', 'WA'),
#  ('Pasco', 'WA'),
#  ('Pullman', 'WA'),
#  ('Seattle', 'WA')]

# %% [markdown]
# ## RDD Transformations

# %%
aiportRDD = sc.textFile('airport-code.txt', minPartitions=4, use_unicode=True).map(lambda line: line.split("\t"))
aiportRDD.collect()
# Out:
# [['City', 'State', 'Country', 'IATA'],
#  ['Abbotsford', 'BC', 'Canada', 'YXX'],
#  ['Aberdeen', 'SD', 'USA', 'ABR'],
#  ['Abilene', 'TX', 'USA', 'ABI'],
#  ['Akron', 'OH', 'USA', 'CAK'],
#  ['Alamosa', 'CO', 'USA', 'ALS'],
#  ['Albany', 'GA', 'USA', 'ABY'],
#  ['Albany', 'NY', 'USA', 'ALB'],
#  ['Albuquerque', 'NM', 'USA', 'ABQ'],
#  ['Alexandria', 'LA', 'USA', 'AEX'],
#  ['Allentown', 'PA', 'USA', 'ABE'],
#  ['Alliance', 'NE', 'USA', 'AIA'],
#  ['Alpena', 'MI', 'USA', 'APN'],
#  ['Altoona', 'PA', 'USA', 'AOO'],
#  ['Amarillo', 'TX', 'USA', 'AMA'],
#  ['Anahim Lake', 'BC', 'Canada', 'YAA'],
#  ['Anchorage', 'AK', 'USA', 'ANC'],
#  ['Appleton', 'WI', 'USA', 'ATW'],
#  ['Arviat', 'NWT', 'Canada', 'YEK'],
#  ['Asheville', 'NC', 'USA', 'AVL'],
#  ['Aspen', 'CO', 'USA', 'ASE'],
#  ['Athens', 'GA', 'USA', 'AHN'],
#  ['Atlanta', 'GA', 'USA', 'ATL'],
#  ['Atlantic City', 'NJ', 'USA', 'ACY'],
#  ['Augusta', 'GA', 'USA', 'AGS'],
#  ['Augusta', 'ME', 'USA', 'AUG'],
#  ['Austin', 'TX', 'USA', 'AUS'],
#  ['Bagotville', 'PQ', 'Canada', 'YBG'],
#  ['Baie-Comeau', 'PQ', 'Canada', 'YBC'],
#  ['Bakersfield', 'CA', 'USA', 'BFL'],
#  ['Baltimore', 'MD', 'USA', 'BWI'],
#  ['Bangor', 'ME', 'USA', 'BGR'],
#  ['Bar Harbor', 'ME', 'USA', 'BHB'],
#  ['Barrow', 'AK', 'USA', 'BRW'],
#  ['Baton Rouge', 'LA', 'USA', 'BTR'],
#  ['Beaumont', 'TX', 'USA', 'BPT'],
#  ['Beckley', 'WV', 'USA', 'BKW'],
#  ['Bedford', 'MA', 'USA', 'BED'],
#  ['Bellingham', 'WA', 'USA', 'BLI'],
#  ['Bemidji', 'MN', 'USA', 'BJI'],
#  ['Bethel', 'AK', 'USA', 'BET'],
#  ['Bettles', 'AK', 'USA', 'BTT'],
#  ['Billings', 'MT', 'USA', 'BIL'],
#  ['Binghamton', 'NY', 'USA', 'BGM'],
#  ['Birmingham', 'AL', 'USA', 'BHM'],
#  ['Bismarck', 'ND', 'USA', 'BIS'],
#  ['Bloomington', 'IL', 'USA', 'BMI'],
#  ['Bloomington', 'IN', 'USA', 'BMG'],
#  ['Bluefield', 'WV', 'USA', 'BLF'],
#  ['Boise', 'ID', 'USA', 'BOI'],
#  ['Boston', 'MA', 'USA', 'BOS'],
#  ['Bozeman', 'MT', 'USA', 'BZN'],
#  ['Brookings', 'SD', 'USA', 'BKX'],
#  ['Brownsville', 'TX', 'USA', 'BRO'],
#  ['Brunswick', 'GA', 'USA', 'BQK'],
#  ['Buffalo', 'NY', 'USA', 'BUF'],
#  ['Burbank', 'CA', 'USA', 'BUR'],
#  ['Burlington', 'IA', 'USA', 'BRL'],
#  ['Burlington', 'MA', 'USA', 'BBF'],
#  ['Burlington', 'VT', 'USA', 'BTV'],
#  ['Butte', 'MT', 'USA', 'BTM'],
#  ['Calgary', 'AB', 'Canada', 'YYC'],
#  ['Campbell River', 'BC', 'Canada', 'YBL'],
#  ['"Cap-aux-Meules, Magdalens Islands"', 'PQ', 'Canada', 'YGR'],
#  ['Cape Girardeau', 'MO', 'USA', 'CGI'],
#  ['Carlsbad', 'CA', 'USA', 'CLD'],
#  ['Carlsbad', 'NM', 'USA', 'CNM'],
#  ['Casper', 'WY', 'USA', 'CPR'],
#  ['Castlegar', 'BC', 'Canada', 'YCG'],
#  ['Cedar Rapids', 'IA', 'USA', 'CID'],
#  ['Champaign', 'IL', 'USA', 'CMI'],
#  ['Charleston', 'SC', 'USA', 'CHS'],
#  ['Charleston', 'WV', 'USA', 'CRW'],
#  ['Charlotte', 'NC', 'USA', 'CLT'],
#  ['Charlottesville', 'VA', 'USA', 'CHO'],
#  ['Charlottetown', 'PEI', 'Canada', 'YYG'],
#  ['Chattanooga', 'TN', 'USA', 'CHA'],
#  ['Cheyenne', 'WY', 'USA', 'CYS'],
#  ['Chibougamau', 'PQ', 'Canada', 'YMT'],
#  ['Chicago', 'IL', 'USA', 'MDW'],
#  ['Chicago', 'IL', 'USA', 'ORD'],
#  ['Chicago', 'IL', 'USA', 'CHI'],
#  ['Chico', 'CA', 'USA', 'CIC'],
#  ['Churchill', 'MB', 'Canada', 'YYQ'],
#  ['Cincinnati', 'OH', 'USA', 'CVG'],
#  ['Clarksburg', 'WV', 'USA', 'CKB'],
#  ['Cleveland', 'OH', 'USA', 'CLE'],
#  ['Clovis', 'NM', 'USA', 'CVN'],
#  ['Cody', 'WY', 'USA', 'COD'],
#  ['College Station', 'TX', 'USA', 'CLL'],
#  ['Colorado Springs', 'CO', 'USA', 'COS'],
#  ['Columbia', 'MO', 'USA', 'COU'],
#  ['Columbia', 'SC', 'USA', 'CAE'],
#  ['Columbus', 'GA', 'USA', 'CSG'],
#  ['Columbus', 'IN', 'USA', 'CLU'],
#  ['Columbus', 'MS', 'USA', 'GTR'],
#  ['Columbus', 'NE', 'USA', 'OLU'],
#  ['Columbus', 'OH', 'USA', 'CMH'],
#  ['Cordova', 'AK', 'USA', 'CDV'],
#  ['Corpus Christi', 'TX', 'USA', 'CRP'],
#  ['Cranbrook', 'BC', 'Canada', 'YXC'],
#  ['Dallas', 'TX', 'USA', 'DFW'],
#  ['Dallas', 'TX', 'USA', 'DAL'],
#  ['Dayton', 'OH', 'USA', 'DAY'],
#  ['Daytona Beach', 'FL', 'USA', 'DAB'],
#  ['Decatur', 'IL', 'USA', 'DEC'],
#  ['Deer Lake', 'NF', 'Canada', 'YDF'],
#  ['Denver', 'CO', 'USA', 'DEN'],
#  ['Des Moines', 'IA', 'USA', 'DSM'],
#  ['Detroit', 'MI', 'USA', 'DTW'],
#  ['Detroit', 'MI', 'USA', 'DTT'],
#  ['Devils Lake', 'ND', 'USA', 'DVL'],
#  ['Dickinson', 'ND', 'USA', 'DIK'],
#  ['Dillingham', 'AK', 'USA', 'DLG'],
#  ['Dodge City', 'KS', 'USA', 'DDC'],
#  ['Dothan', 'AL', 'USA', 'DHN'],
#  ['Dryden', 'ON', 'Canada', 'YHD'],
#  ['Du Bois', 'PA', 'USA', 'DUJ'],
#  ['Dubuque', 'IA', 'USA', 'DBQ'],
#  ['Duluth', 'MN', 'USA', 'DLH'],
#  ['Durango', 'CO', 'USA', 'DRO'],
#  ['"Dutch Harbor, Un Island"', 'AK', 'USA', 'DUT'],
#  ['Eau Claire', 'WI', 'USA', 'EAU'],
#  ['Edmonton', 'AB', 'Canada', 'YEG'],
#  ['Eek', 'AK', 'USA', 'EEK'],
#  ['El Centro', 'CA', 'USA', 'IPL'],
#  ['El Dorado', 'AR', 'USA', 'ELD'],
#  ['El Paso', 'TX', 'USA', 'ELP'],
#  ['Elko', 'NV', 'USA', 'EKO'],
#  ['Elmira', 'NY', 'USA', 'ELM'],
#  ['Enid', 'OK', 'USA', 'WDG'],
#  ['Erie', 'PA', 'USA', 'ERI'],
#  ['Escanaba', 'MI', 'USA', 'ESC'],
#  ['Eugene', 'OR', 'USA', 'EUG'],
#  ['Eureka', 'CA', 'USA', 'ACV'],
#  ['Evansville', 'IN', 'USA', 'EVV'],
#  ['Fairbanks', 'AK', 'USA', 'FAI'],
#  ['Fargo', 'ND', 'USA', 'FAR'],
#  ['Farmington', 'NM', 'USA', 'FMN'],
#  ['Fayetteville', 'AR', 'USA', 'XNA'],
#  ['Fayetteville', 'NC', 'USA', 'FAY'],
#  ['Flagstaff', 'AZ', 'USA', 'FLG'],
#  ['Flin Flon', 'MB', 'Canada', 'YFO'],
#  ['Flint', 'MI', 'USA', 'FNT'],
#  ['Florence', 'SC', 'USA', 'FLO'],
#  ['Fort Dodge', 'IA', 'USA', 'FOD'],
#  ['Fort Lauderdale', 'FL', 'USA', 'FLL'],
#  ['Fort Leonard Wood', 'MO', 'USA', 'TBN'],
#  ['Fort McMurray', 'AB', 'Canada', 'YMM'],
#  ['Fort Myers', 'FL', 'USA', 'RSW'],
#  ['Fort Nelson', 'BC', 'Canada', 'YYE'],
#  ['Fort Saint John', 'BC', 'Canada', 'YXJ'],
#  ['Fort Smith', 'AR', 'USA', 'FSM'],
#  ['Fort Smith', 'NWT', 'Canada', 'YSM'],
#  ['Fort Walton Beach', 'FL', 'USA', 'VPS'],
#  ['Fort Wayne', 'IN', 'USA', 'FWA'],
#  ['Fort Yukon', 'AK', 'USA', 'FYU'],
#  ['Fredericton', 'NB', 'Canada', 'YFC'],
#  ['Fresno', 'CA', 'USA', 'FAT'],
#  ['Gainesville', 'FL', 'USA', 'GNV'],
#  ['Gander', 'NF', 'Canada', 'YQX'],
#  ['Garden City', 'KS', 'USA', 'GCK'],
#  ['Gaspe', 'PQ', 'Canada', 'YGP'],
#  ['Gillette', 'WY', 'USA', 'GCC'],
#  ['Glendive', 'MT', 'USA', 'GDV'],
#  ['Grand Forks', 'ND', 'USA', 'GFK'],
#  ['Grand Island', 'NE', 'USA', 'GRI'],
#  ['Grand Junction', 'CO', 'USA', 'GJT'],
#  ['Grand Rapids', 'MI', 'USA', 'GRR'],
#  ['Grande Prairie', 'AB', 'Canada', 'YQU'],
#  ['Great Bend', 'KS', 'USA', 'GBD'],
#  ['Great Falls', 'MT', 'USA', 'GTF'],
#  ['Green Bay', 'WI', 'USA', 'GRB'],
#  ['Greenbrier', 'WV', 'USA', 'LWB'],
#  ['Greensboro', 'NC', 'USA', 'GSO'],
#  ['Greenville', 'MS', 'USA', 'GLH'],
#  ['Greenville', 'NC', 'USA', 'PGV'],
#  ['Greenville', 'SC', 'USA', 'GSP'],
#  ['Gulfport', 'MS', 'USA', 'GPT'],
#  ['Gunnison', 'CO', 'USA', 'GUC'],
#  ['Hagerstown', 'MD', 'USA', 'HGR'],
#  ['Halifax', 'NS', 'Canada', 'YHZ'],
#  ['Hamilton', 'ON', 'Canada', 'YHM'],
#  ['"Hana, Maui"', 'HI', 'USA', 'HNM'],
#  ['Hancock', 'MI', 'USA', 'CMX'],
#  ['Harlingen', 'TX', 'USA', 'HRL'],
#  ['Harrisburg', 'PA', 'USA', 'MDT'],
#  ['Harrison', 'AR', 'USA', 'HRO'],
#  ['Hartford', 'CT', 'USA', 'BDL'],
#  ['Havre', 'MT', 'USA', 'HVR'],
#  ['Hays', 'KS', 'USA', 'HYS'],
#  ['Helena', 'MT', 'USA', 'HLN'],
#  ['Hibbing', 'MN', 'USA', 'HIB'],
#  ['Hilo', 'HI', 'USA', 'Big'],
#  ['Hilton Head Island', 'SC', 'USA', 'HHH'],
#  ['Hobbs', 'NM', 'USA', 'HOB'],
#  ['Homer', 'AK', 'USA', 'HOM'],
#  ['"Honolulu, Oahu"', 'HI', 'USA', 'HNL'],
#  ['"Hoolehua, Molokai"', 'HI', 'USA', 'MKK'],
#  ['Hot Springs', 'AR', 'USA', 'HOT'],
#  ['Houston', 'TX', 'USA', 'IAH'],
#  ['Houston', 'TX', 'USA', 'HOU'],
#  ['Houston', 'TX', 'USA', 'EFD'],
#  ['Huntington', 'WV', 'USA', 'HTS'],
#  ['Huntsville', 'AL', 'USA', 'HSV'],
#  ['Huron', 'SD', 'USA', 'HON'],
#  ['Hyannis', 'MA', 'USA', 'HYA'],
#  ['Idaho Falls', 'ID', 'USA', 'IDA'],
#  ['Indianapolis', 'IN', 'USA', 'IND'],
#  ['International Falls', 'MN', 'USA', 'INL'],
#  ['Inyokern', 'CA', 'USA', 'IYK'],
#  ['Iqaluit', 'Nunavut', 'Canada', 'YFB'],
#  ['Iron Mountain', 'MI', 'USA', 'IMT'],
#  ['Ironwood', 'MI', 'USA', 'IWD'],
#  ['Islip', 'NY', 'USA', 'ISP'],
#  ['Ithaca', 'NY', 'USA', 'ITH'],
#  ['Jackson Hole', 'WY', 'USA', 'JAC'],
#  ['Jackson', 'MS', 'USA', 'JAN'],
#  ['Jackson', 'TN', 'USA', 'MKL'],
#  ['Jacksonville', 'FL', 'USA', 'JAX'],
#  ['Jacksonville', 'NC', 'USA', 'OAJ'],
#  ['Jamestown', 'ND', 'USA', 'JMS'],
#  ['Jamestown', 'NY', 'USA', 'JHW'],
#  ['Johnstown', 'PA', 'USA', 'JST'],
#  ['Jonesboro', 'AR', 'USA', 'JBR'],
#  ['Joplin', 'MO', 'USA', 'JLN'],
#  ['Juneau', 'AK', 'USA', 'JNU'],
#  ['"Kahului, Maui"', 'HI', 'USA', 'OGG'],
#  ['Kailua-Kona', 'Hawaii', 'USA', 'Big'],
#  ['Kalamazoo', 'MI', 'USA', 'AZO'],
#  ['"Kalaupapa, Molokai"', 'HI', 'USA', 'LUP'],
#  ['Kalispell', 'MT', 'USA', 'FCA'],
#  ['Kamloops', 'BC', 'Canada', 'YKA'],
#  ['Kamuela', 'Hawaii', 'USA', 'Big'],
#  ['Kansas City', 'MO', 'USA', 'MCI'],
#  ['"Kapalua, Maui"', 'HI', 'USA', 'JHM'],
#  ['Kearney', 'NE', 'USA', 'EAR'],
#  ['Kelowna', 'BC', 'Canada', 'YLW'],
#  ['Kenai', 'AK', 'USA', 'ENA'],
#  ['Kenora', 'ON', 'Canada', 'YQK'],
#  ['Ketchikan', 'AK', 'USA', 'KTN'],
#  ['Key West', 'FL', 'USA', 'EYW'],
#  ['Killeen', 'TX', 'USA', 'GRK'],
#  ['King Salmon', 'AK', 'USA', 'AKN'],
#  ['Kingman', 'AZ', 'USA', 'IGM'],
#  ['Kingston', 'ON', 'Canada', 'YGK'],
#  ['Kirksville', 'MO', 'USA', 'IRK'],
#  ['Klamath Falls', 'OR', 'USA', 'LMT'],
#  ['Knoxville', 'TN', 'USA', 'TYS'],
#  ['Kodiak', 'AK', 'USA', 'ADQ'],
#  ['La Crosse', 'WI', 'USA', 'LSE'],
#  ['Lafayette', 'LA', 'USA', 'LFT'],
#  ['Lake Charles', 'LA', 'USA', 'LCH'],
#  ['Lake Havasu City', 'AZ', 'USA', 'HII'],
#  ['"Lanai City, Lanai"', 'HI', 'USA', 'LNY'],
#  ['Lancaster', 'PA', 'USA', 'LNS'],
#  ['Lansing', 'MI', 'USA', 'LAN'],
#  ['Laramie', 'WY', 'USA', 'LAR'],
#  ['Laredo', 'TX', 'USA', 'LRD'],
#  ['Las Cruces', 'NM', 'USA', 'LRU'],
#  ['Las Vegas', 'NV', 'USA', 'LAS'],
#  ['Latrobe', 'PA', 'USA', 'LBE'],
#  ['Laurel', 'MS', 'USA', 'PIB'],
#  ['Lawton', 'OK', 'USA', 'LAW'],
#  ['Lebanon', 'NH', 'USA', 'LEB'],
#  ['Lethbridge', 'AB', 'Canada', 'YQL'],
#  ['Lewiston', 'ID', 'USA', 'LWS'],
#  ['Lewiston', 'ME', 'USA', 'LEW'],
#  ['Lewistown', 'MT', 'USA', 'LWT'],
#  ['Lexington', 'KY', 'USA', 'LEX'],
#  ['Liberal', 'KS', 'USA', 'LBL'],
#  ['"Lihue, Kauai"', 'HI', 'USA', 'LIH'],
#  ['Lincoln', 'NE', 'USA', 'LNK'],
#  ['Little Rock', 'AR', 'USA', 'LIT'],
#  ['London', 'ON', 'Canada', 'YXU'],
#  ['Long Beach', 'CA', 'USA', 'LGB'],
#  ['Longview', 'TX', 'USA', 'GGG'],
#  ['Los Angeles', 'CA', 'USA', 'QLA'],
#  ['Los Angeles', 'CA', 'USA', 'LAX'],
#  ['Louisville', 'KY', 'USA', 'SDF'],
#  ['Lubbock', 'TX', 'USA', 'LBB'],
#  ['Lynchburg', 'VA', 'USA', 'LYH'],
#  ['Macon', 'GA', 'USA', 'MCN'],
#  ['Madison', 'WI', 'USA', 'MSN'],
#  ['Manchester', 'NH', 'USA', 'MHT'],
#  ['Manhattan', 'KS', 'USA', 'MHK'],
#  ['Manistee', 'MI', 'USA', 'MBL'],
#  ['Marion', 'IL', 'USA', 'MWA'],
#  ['Marquette', 'MI', 'USA', 'MQT'],
#  ["Martha's Vineyard", 'MA', 'USA', 'MVY'],
#  ['Mason City', 'IA', 'USA', 'MCW'],
#  ['Massena', 'NY', 'USA', 'MSS'],
#  ['McAllen', 'TX', 'USA', 'MFE'],
#  ['McCook', 'NE', 'USA', 'MCK'],
#  ['Medford', 'OR', 'USA', 'MFR'],
#  ['Medicine Hat', 'AB', 'Canada', 'YXH'],
#  ['Melbourne', 'FL', 'USA', 'MLB'],
#  ['Memphis', 'TN', 'USA', 'MEM'],
#  ['Meridian', 'MS', 'USA', 'MEI'],
#  ['Miami', 'FL', 'USA', 'MIA'],
#  ['Midland', 'TX', 'USA', 'MAF'],
#  ['Miles City', 'MT', 'USA', 'MLS'],
#  ['Milwaukee', 'WI', 'USA', 'MKE'],
#  ['Minneapolis', 'MN', 'USA', 'MSP'],
#  ['Minot', 'ND', 'USA', 'MOT'],
#  ['Missoula', 'MT', 'USA', 'MSO'],
#  ['Mobile', 'AL', 'USA', 'MOB'],
#  ['Modesto', 'CA', 'USA', 'MOD'],
#  ['Moline', 'IL', 'USA', 'MLI'],
#  ['Moncton', 'NB', 'Canada', 'YQM'],
#  ['Monroe', 'LA', 'USA', 'MLU'],
#  ['Mont-Joli', 'PQ', 'Canada', 'YYY'],
#  ['Monterey', 'CA', 'USA', 'MRY'],
#  ['Montgomery', 'AL', 'USA', 'MGM'],
#  ['Montreal', 'PQ', 'Canada', 'YUL'],
#  ['Montreal', 'PQ', 'Canada', 'YMQ'],
#  ['Montrose', 'CO', 'USA', 'MTJ'],
#  ['Morgantown', 'WV', 'USA', 'MGW'],
#  ['Moses Lake', 'WA', 'USA', 'MWH'],
#  ['Muscle Shoals', 'AL', 'USA', 'MSL'],
#  ['Muskegon', 'MI', 'USA', 'MKG'],
#  ['Myrtle Beach', 'SC', 'USA', 'MYR'],
#  ['Nanaimo', 'BC', 'Canada', 'YCD'],
#  ['Nantucket', 'MA', 'USA', 'ACK'],
#  ['Naples', 'FL', 'USA', 'APF'],
#  ['Nashville', 'TN', 'USA', 'BNA'],
#  ['New Bern', 'NC', 'USA', 'EWN'],
#  ['New Haven', 'CT', 'USA', 'HVN'],
#  ['New Orleans', 'LA', 'USA', 'MSY'],
#  ['New York', 'NY', 'USA', 'JFK'],
#  ['New York', 'NY', 'USA', 'NYC'],
#  ['New York', 'NY', 'USA', 'LGA'],
#  ['Newark', 'NJ', 'USA', 'EWR'],
#  ['Newburgh', 'NY', 'USA', 'SWF'],
#  ['Newport News', 'VA', 'USA', 'PHF'],
#  ['Nome', 'AK', 'USA', 'OME'],
#  ['Norfolk', 'VA', 'USA', 'ORF'],
#  ['North Bay', 'ON', 'Canada', 'YYB'],
#  ['North Bend', 'OR', 'USA', 'OTH'],
#  ['North Platte', 'NE', 'USA', 'LBF'],
#  ['Oakland', 'CA', 'USA', 'OAK'],
#  ['Ogdensburg', 'NY', 'USA', 'OGS'],
#  ['Oklahoma City', 'OK', 'USA', 'OKC'],
#  ['Omaha', 'NE', 'USA', 'OMA'],
#  ['Ontario', 'CA', 'USA', 'ONT'],
#  ['Orange County', 'CA', 'USA', 'SNA'],
#  ['Orlando', 'FL', 'USA', 'MCO'],
#  ['Oshkosh', 'WI', 'USA', 'OSH'],
#  ['Ottawa', 'ON', 'Canada', 'YOW'],
#  ['Owensboro', 'KY', 'USA', 'OWB'],
#  ['Oxnard', 'CA', 'USA', 'OXR'],
#  ['Paducah', 'KY', 'USA', 'PAH'],
#  ['Page', 'AZ', 'USA', 'PGA'],
#  ['Palm Springs', 'CA', 'USA', 'PSP'],
#  ['Panama City', 'FL', 'USA', 'PFN'],
#  ['Parkersburg', 'WV', 'USA', 'PKB'],
#  ['Pasco', 'WA', 'USA', 'PSC'],
#  ['Pellston', 'MI', 'USA', 'PLN'],
#  ['Pendleton', 'OR', 'USA', 'PDT'],
#  ['Pensacola', 'FL', 'USA', 'PNS'],
#  ['Penticton', 'BC', 'Canada', 'YYF'],
#  ['Peoria', 'IL', 'USA', 'PIA'],
#  ['Philadelphia', 'PA', 'USA', 'PHL'],
#  ['Phoenix', 'AZ', 'USA', 'PHX'],
#  ['Pierre', 'SD', 'USA', 'PIR'],
#  ['Pinehurst', 'NC', 'USA', 'SOP'],
#  ['Pittsburgh', 'PA', 'USA', 'PIT'],
#  ['Pocatello', 'ID', 'USA', 'PIH'],
#  ['Ponca City', 'OK', 'USA', 'PNC'],
#  ['Port Hardy', 'BC', 'Canada', 'YZT'],
#  ['Portland', 'ME', 'USA', 'PWM'],
#  ['Portland', 'OR', 'USA', 'PDX'],
#  ['Portsmouth', 'NH', 'USA', 'PSM'],
#  ['Powell River', 'BC', 'Canada', 'YPW'],
#  ['Prescott', 'AZ', 'USA', 'PRC'],
#  ['Presque Isle', 'ME', 'USA', 'PQI'],
#  ['Prince George', 'BC', 'Canada', 'YXS'],
#  ['Prince Rupert', 'BC', 'Canada', 'YPR'],
#  ['Providence', 'RI', 'USA', 'PVD'],
#  ['Provincetown', 'MA', 'USA', 'PVC'],
#  ['Pueblo', 'CO', 'USA', 'PUB'],
#  ['Pullman', 'WA', 'USA', 'PUW'],
#  ['Quebec', 'PQ', 'Canada', 'YQB'],
#  ['Quesnel', 'BC', 'Canada', 'YQZ'],
#  ['Quincy', 'IL', 'USA', 'UIN'],
#  ['Raleigh', 'NC', 'USA', 'RDU'],
#  ['Rankin Inlet', 'NWT', 'Canada', 'YRT'],
#  ['Rapid City', 'SD', 'USA', 'RAP'],
#  ['Red Lake', 'ON', 'Canada', 'YRL'],
#  ['Redding', 'CA', 'USA', 'RDD'],
#  ['Redmond', 'OR', 'USA', 'RDM'],
#  ['Regina', 'SK', 'Canada', 'YQR'],
#  ['Reno', 'NV', 'USA', 'RNO'],
#  ['Rhinelander', 'WI', 'USA', 'RHI'],
#  ['Richmond', 'VA', 'USA', 'RIC'],
#  ['Riverton', 'WY', 'USA', 'RIW'],
#  ['Roanoke', 'VA', 'USA', 'ROA'],
#  ['Roberval', 'PQ', 'Canada', 'YRJ'],
#  ['Rochester', 'MN', 'USA', 'RST'],
#  ['Rochester', 'NY', 'USA', 'ROC'],
#  ['Rock Springs', 'WY', 'USA', 'RKS'],
#  ['Rockford', 'IL', 'USA', 'RFD'],
#  ['Rockland', 'ME', 'USA', 'RKD'],
#  ['Roswell', 'NM', 'USA', 'ROW'],
#  ['Rouyn-Noranda', 'PQ', 'Canada', 'YUY'],
#  ['Rutland', 'VT', 'USA', 'RUT'],
#  ['Sacramento', 'CA', 'USA', 'SMF'],
#  ['Saginaw', 'MI', 'USA', 'MBS'],
#  ['Saint John', 'NB', 'Canada', 'YSJ'],
#  ['Salina', 'KS', 'USA', 'SLN'],
#  ['Salisbury', 'MD', 'USA', 'SBY'],
#  ['Salt Lake City', 'UT', 'USA', 'SLC'],
#  ['San Angelo', 'TX', 'USA', 'SJT'],
#  ['San Antonio', 'TX', 'USA', 'SAT'],
#  ['San Diego', 'CA', 'USA', 'SAN'],
#  ['San Francisco', 'CA', 'USA', 'QSF'],
#  ['San Francisco', 'CA', 'USA', 'SFO'],
#  ['San Jose', 'CA', 'USA', 'SJC'],
#  ['San Luis Obispo', 'CA', 'USA', 'SBP'],
#  ['Sand Point', 'AK', 'USA', 'SDP'],
#  ['"Sandspit, Queen Charlotte Islands"', 'BC', 'Canada', 'YZP'],
#  ['Santa Barbara', 'CA', 'USA', 'SBA'],
#  ['Santa Fe', 'NM', 'USA', 'SAF'],
#  ['Santa Maria', 'CA', 'USA', 'SMX'],
#  ['Santa Rosa', 'CA', 'USA', 'STS'],
#  ['Saranac Lake', 'NY', 'USA', 'SLK'],
#  ['Sarasota', 'FL', 'USA', 'SRQ'],
#  ['Sarnia', 'ON', 'Canada', 'YZR'],
#  ['Saskatoon', 'SK', 'Canada', 'YXE'],
#  ['Sault Ste. Marie', 'MI', 'USA', 'CIU'],
#  ['Sault Ste. Marie', 'ON', 'Canada', 'YAM'],
#  ['Savannah', 'GA', 'USA', 'SAV'],
#  ['Scottsbluff', 'NE', 'USA', 'BFF'],
#  ['Seattle', 'WA', 'USA', 'SEA'],
#  ['Sept-Iles', 'PQ', 'Canada', 'YZV'],
#  ['Shenandoah Valley Airport', 'VA', 'USA', 'SHD'],
#  ['Sheridan', 'WY', 'USA', 'SHR'],
#  ['Shreveport', 'LA', 'USA', 'SHV'],
#  ['Sidney', 'MT', 'USA', 'SDY'],
#  ['Silver City', 'NM', 'USA', 'SVC'],
#  ['Sioux City', 'IA', 'USA', 'SUX'],
#  ['Sioux Falls', 'SD', 'USA', 'FSD'],
#  ['Sioux Lookout', 'ON', 'Canada', 'YXL'],
#  ['Sitka', 'AK', 'USA', 'SIT'],
#  ['Skagway', 'AK', 'USA', 'SGY'],
#  ['Smithers', 'BC', 'Canada', 'YYD'],
#  ['South Bend', 'IN', 'USA', 'SBN'],
#  ['Spokane', 'WA', 'USA', 'GEG'],
#  ['Springfield', 'IL', 'USA', 'SPI'],
#  ['Springfield', 'MA', 'USA', 'CEF'],
#  ['Springfield', 'MO', 'USA', 'SGF'],
#  ['Springfield', 'VT', 'USA', 'VSF'],
#  ['St. Cloud', 'MN', 'USA', 'STC'],
#  ['St. George', 'UT', 'USA', 'SGU'],
#  ["St. John's", 'NF', 'Canada', 'YYT'],
#  ['St. Louis', 'MO', 'USA', 'STL'],
#  ['St. Petersburg', 'FL', 'USA', 'PIE'],
#  ['State College', 'PA', 'USA', 'SCE'],
#  ['Steamboat Springs', 'CO', 'USA', 'SBS'],
#  ['Sudbury', 'ON', 'Canada', 'YSB'],
#  ['Sun Valley', 'ID', 'USA', 'SUN'],
#  ['"Sydney, Cape Breton Island"', 'NS', 'Canada', 'YQY'],
#  ['Syracuse', 'NY', 'USA', 'SYR'],
#  ['Tallahassee', 'FL', 'USA', 'TLH'],
#  ['Tampa', 'FL', 'USA', 'TPA'],
#  ['Telluride', 'CO', 'USA', 'TEX'],
#  ['Terrace', 'BC', 'Canada', 'YXT'],
#  ['Texarkana', 'AR', 'USA', 'TXK'],
#  ['Thief River Falls', 'MN', 'USA', 'TVF'],
#  ['Thompson', 'MB', 'Canada', 'YTH'],
#  ['Thunder Bay', 'ON', 'Canada', 'YQT'],
#  ['Timmins', 'ON', 'Canada', 'YTS'],
#  ['Toksook Bay', 'AK', 'USA', 'OOK'],
#  ['Toledo', 'OH', 'USA', 'TOL'],
#  ['Eureka', 'KS', 'USA', 'TOP'],
#  ['Toronto', 'ON', 'Canada', 'YYZ'],
#  ['Toronto', 'ON', 'Canada', 'YTZ'],
#  ['Toronto', 'ON', 'Canada', 'YTO'],
#  ['Traverse City', 'MI', 'USA', 'TVC'],
#  ['Trenton', 'NJ', 'USA', 'TTN'],
#  ['Tri-City Airport', 'TN', 'USA', 'TRI'],
#  ['Tucson', 'AZ', 'USA', 'TUS'],
#  ['Tulsa', 'OK', 'USA', 'TUL'],
#  ['Tupelo', 'MS', 'USA', 'TUP'],
#  ['Twin Falls', 'ID', 'USA', 'TWF'],
#  ['Tyler', 'TX', 'USA', 'TYR'],
#  ['Unalakleet', 'AK', 'USA', 'UNK'],
#  ['Vail', 'CO', 'USA', 'EGE'],
#  ["Val-d'Or", 'PQ', 'Canada', 'YVO'],
#  ['Valdez', 'AK', 'USA', 'VDZ'],
#  ['Valdosta', 'GA', 'USA', 'VLD'],
#  ['Vancouver', 'BC', 'Canada', 'YVR'],
#  ['Victoria', 'BC', 'Canada', 'YYJ'],
#  ['Victoria', 'TX', 'USA', 'VCT'],
#  ['Visalia', 'CA', 'USA', 'VIS'],
#  ['"Wabush, Labrador"', 'NF', 'Canada', 'YWK'],
#  ['Waco', 'TX', 'USA', 'ACT'],
#  ['Walla Walla', 'WA', 'USA', 'ALW'],
#  ['Washington DC', '', 'USA', 'IAD'],
#  ['Washington DC', '', 'USA', 'DCA'],
#  ['Washington DC', '', 'USA', 'WAS'],
#  ['Waterloo', 'IA', 'USA', 'ALO'],
#  ['Watertown', 'NY', 'USA', 'ART'],
#  ['Watertown', 'SD', 'USA', 'ATY'],
#  ['Wausau', 'WI', 'USA', 'CWA'],
#  ['Wenatchee', 'WA', 'USA', 'EAT'],
#  ['West Palm Beach', 'FL', 'USA', 'PBI'],
#  ['West Yellowstone', 'MT', 'USA', 'WYS'],
#  ['White Plains', 'NY', 'USA', 'HPN'],
#  ['Whitehorse', 'YT', 'Canada', 'YXY'],
#  ['Wichita Falls', 'TX', 'USA', 'SPS'],
#  ['Wichita', 'KS', 'USA', 'ICT'],
#  ['Wilkes-Barre', 'PA', 'USA', 'AVP'],
#  ['Williams Lake', 'BC', 'Canada', 'YWL'],
#  ['Williamsport', 'PA', 'USA', 'IPT'],
#  ['Williston', 'ND', 'USA', 'ISN'],
#  ['Wilmington', 'DE', 'USA', 'ILG'],
#  ['Wilmington', 'NC', 'USA', 'ILM'],
#  ['Windsor', 'ON', 'Canada', 'YQG'],
#  ['Winnipeg', 'MB', 'Canada', 'YWG'],
#  ['Wolf Point', 'MT', 'USA', 'OLF'],
#  ['Worland', 'WY', 'USA', 'WRL'],
#  ['Wrangell', 'AK', 'USA', 'WRG'],
#  ['Yakima', 'WA', 'USA', 'YKM'],
#  ['Yakutat', 'AK', 'USA', 'YAK'],
#  ['Yellowknife', 'NWT', 'Canada', 'YZF'],
#  ['Yuma', 'AZ', 'USA', 'YUM']]

# %%
#Departure RDD
departure_flightRDD = (sc.textFile('departure_delays.csv', minPartitions=8).map(lambda element: element.split(",")))
departure_flightRDD.collect()
# Out:
# [['date', 'delay', 'distance', 'origin', 'destination'],
#  ['01011245', '6', '602', 'ABE', 'ATL'],
#  ['01020600', '-8', '369', 'ABE', 'DTW'],
#  ['01021245', '-2', '602', 'ABE', 'ATL'],
#  ['01020605', '-4', '602', 'ABE', 'ATL'],
#  ['01031245', '-4', '602', 'ABE', 'ATL'],
#  ['01030605', '0', '602', 'ABE', 'ATL'],
#  ['01041243', '10', '602', 'ABE', 'ATL'],
#  ['01040605', '28', '602', 'ABE', 'ATL'],
#  ['01051245', '88', '602', 'ABE', 'ATL'],
#  ['01050605', '9', '602', 'ABE', 'ATL'],
#  ['01061215', '-6', '602', 'ABE', 'ATL'],
#  ['01061725', '69', '602', 'ABE', 'ATL'],
#  ['01061230', '0', '369', 'ABE', 'DTW'],
#  ['01060625', '-3', '602', 'ABE', 'ATL'],
#  ['01070600', '0', '369', 'ABE', 'DTW'],
#  ['01071725', '0', '602', 'ABE', 'ATL'],
#  ['01071230', '0', '369', 'ABE', 'DTW'],
#  ['01070625', '0', '602', 'ABE', 'ATL'],
#  ['01071219', '0', '569', 'ABE', 'ORD'],
#  ['01080600', '0', '369', 'ABE', 'DTW'],
#  ['01081230', '33', '369', 'ABE', 'DTW'],
#  ['01080625', '1', '602', 'ABE', 'ATL'],
#  ['01080607', '5', '569', 'ABE', 'ORD'],
#  ['01081219', '54', '569', 'ABE', 'ORD'],
#  ['01091215', '43', '602', 'ABE', 'ATL'],
#  ['01090600', '151', '369', 'ABE', 'DTW'],
#  ['01091725', '0', '602', 'ABE', 'ATL'],
#  ['01091230', '-4', '369', 'ABE', 'DTW'],
#  ['01090625', '8', '602', 'ABE', 'ATL'],
#  ['01091219', '83', '569', 'ABE', 'ORD'],
#  ['01101215', '-5', '602', 'ABE', 'ATL'],
#  ['01100600', '-5', '369', 'ABE', 'DTW'],
#  ['01101725', '7', '602', 'ABE', 'ATL'],
#  ['01101230', '-8', '369', 'ABE', 'DTW'],
#  ['01100625', '52', '602', 'ABE', 'ATL'],
#  ['01101219', '0', '569', 'ABE', 'ORD'],
#  ['01111215', '127', '602', 'ABE', 'ATL'],
#  ['01110600', '-9', '369', 'ABE', 'DTW'],
#  ['01110625', '-4', '602', 'ABE', 'ATL'],
#  ['01121215', '-5', '602', 'ABE', 'ATL'],
#  ['01121725', '-1', '602', 'ABE', 'ATL'],
#  ['01131215', '14', '602', 'ABE', 'ATL'],
#  ['01130600', '-7', '369', 'ABE', 'DTW'],
#  ['01131725', '-6', '602', 'ABE', 'ATL'],
#  ['01131230', '-13', '369', 'ABE', 'DTW'],
#  ['01130625', '29', '602', 'ABE', 'ATL'],
#  ['01131219', '-8', '569', 'ABE', 'ORD'],
#  ['01140600', '-9', '369', 'ABE', 'DTW'],
#  ['01141725', '-9', '602', 'ABE', 'ATL'],
#  ['01141230', '-8', '369', 'ABE', 'DTW'],
#  ['01140625', '-5', '602', 'ABE', 'ATL'],
#  ['01141219', '-10', '569', 'ABE', 'ORD'],
#  ['01150600', '0', '369', 'ABE', 'DTW'],
#  ['01151725', '-6', '602', 'ABE', 'ATL'],
#  ['01151230', '0', '369', 'ABE', 'DTW'],
#  ['01150625', '0', '602', 'ABE', 'ATL'],
#  ['01150607', '0', '569', 'ABE', 'ORD'],
#  ['01151219', '0', '569', 'ABE', 'ORD'],
#  ['01161215', '-10', '602', 'ABE', 'ATL'],
#  ['01160600', '-1', '369', 'ABE', 'DTW'],
#  ['01161725', '-6', '602', 'ABE', 'ATL'],
#  ['01161230', '-7', '369', 'ABE', 'DTW'],
#  ['01160625', '-4', '602', 'ABE', 'ATL'],
#  ['01161219', '68', '569', 'ABE', 'ORD'],
#  ['01171215', '-8', '602', 'ABE', 'ATL'],
#  ['01170600', '-5', '369', 'ABE', 'DTW'],
#  ['01171725', '5', '602', 'ABE', 'ATL'],
#  ['01171230', '-10', '369', 'ABE', 'DTW'],
#  ['01170625', '-6', '602', 'ABE', 'ATL'],
#  ['01171219', '-10', '569', 'ABE', 'ORD'],
#  ['01181215', '-12', '602', 'ABE', 'ATL'],
#  ['01180600', '-13', '369', 'ABE', 'DTW'],
#  ['01180625', '0', '602', 'ABE', 'ATL'],
#  ['01191215', '-16', '602', 'ABE', 'ATL'],
#  ['01191725', '-5', '602', 'ABE', 'ATL'],
#  ['01201215', '-8', '602', 'ABE', 'ATL'],
#  ['01201725', '-5', '602', 'ABE', 'ATL'],
#  ['01201230', '-11', '369', 'ABE', 'DTW'],
#  ['01200625', '-7', '602', 'ABE', 'ATL'],
#  ['01201219', '-6', '569', 'ABE', 'ORD'],
#  ['01210600', '89', '369', 'ABE', 'DTW'],
#  ['01211725', '0', '602', 'ABE', 'ATL'],
#  ['01211230', '44', '369', 'ABE', 'DTW'],
#  ['01210625', '-6', '602', 'ABE', 'ATL'],
#  ['01211219', '9', '569', 'ABE', 'ORD'],
#  ['01220600', '80', '369', 'ABE', 'DTW'],
#  ['01221230', '-5', '369', 'ABE', 'DTW'],
#  ['01220625', '333', '602', 'ABE', 'ATL'],
#  ['01220607', '219', '569', 'ABE', 'ORD'],
#  ['01221219', '15', '569', 'ABE', 'ORD'],
#  ['01231215', '-12', '602', 'ABE', 'ATL'],
#  ['01230600', '-3', '369', 'ABE', 'DTW'],
#  ['01231725', '180', '602', 'ABE', 'ATL'],
#  ['01231230', '-5', '369', 'ABE', 'DTW'],
#  ['01230625', '-8', '602', 'ABE', 'ATL'],
#  ['01231219', '-13', '569', 'ABE', 'ORD'],
#  ['01241215', '-11', '602', 'ABE', 'ATL'],
#  ['01240600', '-3', '369', 'ABE', 'DTW'],
#  ['01241725', '2', '602', 'ABE', 'ATL'],
#  ['01241230', '-5', '369', 'ABE', 'DTW'],
#  ['01240625', '-3', '602', 'ABE', 'ATL'],
#  ['01241219', '0', '569', 'ABE', 'ORD'],
#  ['01251215', '2', '602', 'ABE', 'ATL'],
#  ['01250600', '-4', '369', 'ABE', 'DTW'],
#  ['01250625', '-4', '602', 'ABE', 'ATL'],
#  ['01261215', '1', '602', 'ABE', 'ATL'],
#  ['01261725', '7', '602', 'ABE', 'ATL'],
#  ['01271215', '-4', '602', 'ABE', 'ATL'],
#  ['01270600', '-9', '369', 'ABE', 'DTW'],
#  ['01271725', '-8', '602', 'ABE', 'ATL'],
#  ['01271230', '-7', '369', 'ABE', 'DTW'],
#  ['01270625', '-1', '602', 'ABE', 'ATL'],
#  ['01271219', '0', '569', 'ABE', 'ORD'],
#  ['01280600', '-6', '369', 'ABE', 'DTW'],
#  ['01281725', '-3', '602', 'ABE', 'ATL'],
#  ['01281230', '-8', '369', 'ABE', 'DTW'],
#  ['01280625', '-4', '602', 'ABE', 'ATL'],
#  ['01281219', '0', '569', 'ABE', 'ORD'],
#  ['01290600', '0', '369', 'ABE', 'DTW'],
#  ['01291230', '0', '369', 'ABE', 'DTW'],
#  ['01290625', '4', '602', 'ABE', 'ATL'],
#  ['01290607', '92', '569', 'ABE', 'ORD'],
#  ['01291219', '-10', '569', 'ABE', 'ORD'],
#  ['01301215', '0', '602', 'ABE', 'ATL'],
#  ['01300600', '-1', '369', 'ABE', 'DTW'],
#  ['01301725', '10', '602', 'ABE', 'ATL'],
#  ['01301230', '0', '369', 'ABE', 'DTW'],
#  ['01300625', '0', '602', 'ABE', 'ATL'],
#  ['01301219', '-11', '569', 'ABE', 'ORD'],
#  ['01311215', '1', '602', 'ABE', 'ATL'],
#  ['01310600', '-4', '369', 'ABE', 'DTW'],
#  ['01311725', '25', '602', 'ABE', 'ATL'],
#  ['01311230', '-4', '369', 'ABE', 'DTW'],
#  ['01310625', '-5', '602', 'ABE', 'ATL'],
#  ['01311219', '24', '569', 'ABE', 'ORD'],
#  ['01011400', '26', '137', 'ABI', 'DFW'],
#  ['01011525', '-11', '137', 'ABI', 'DFW'],
#  ['01021400', '-5', '137', 'ABI', 'DFW'],
#  ['01021525', '47', '137', 'ABI', 'DFW'],
#  ['01031400', '-12', '137', 'ABI', 'DFW'],
#  ['01031525', '40', '137', 'ABI', 'DFW'],
#  ['01041400', '-12', '137', 'ABI', 'DFW'],
#  ['01041525', '3', '137', 'ABI', 'DFW'],
#  ['01051400', '-5', '137', 'ABI', 'DFW'],
#  ['01051525', '-5', '137', 'ABI', 'DFW'],
#  ['01061400', '2', '137', 'ABI', 'DFW'],
#  ['01061525', '22', '137', 'ABI', 'DFW'],
#  ['01071400', '-12', '137', 'ABI', 'DFW'],
#  ['01071525', '-15', '137', 'ABI', 'DFW'],
#  ['01081525', '21', '137', 'ABI', 'DFW'],
#  ['01091525', '-8', '137', 'ABI', 'DFW'],
#  ['01101525', '4', '137', 'ABI', 'DFW'],
#  ['01111525', '-23', '137', 'ABI', 'DFW'],
#  ['01121525', '-9', '137', 'ABI', 'DFW'],
#  ['01131525', '-12', '137', 'ABI', 'DFW'],
#  ['01141525', '-5', '137', 'ABI', 'DFW'],
#  ['01151525', '-17', '137', 'ABI', 'DFW'],
#  ['01161525', '2', '137', 'ABI', 'DFW'],
#  ['01171525', '-9', '137', 'ABI', 'DFW'],
#  ['01181525', '-5', '137', 'ABI', 'DFW'],
#  ['01191525', '-3', '137', 'ABI', 'DFW'],
#  ['01201525', '-6', '137', 'ABI', 'DFW'],
#  ['01211525', '-17', '137', 'ABI', 'DFW'],
#  ['01221525', '40', '137', 'ABI', 'DFW'],
#  ['01231525', '-12', '137', 'ABI', 'DFW'],
#  ['01241525', '21', '137', 'ABI', 'DFW'],
#  ['01251525', '-6', '137', 'ABI', 'DFW'],
#  ['01261525', '-12', '137', 'ABI', 'DFW'],
#  ['01271525', '-13', '137', 'ABI', 'DFW'],
#  ['01281525', '-10', '137', 'ABI', 'DFW'],
#  ['01291525', '146', '137', 'ABI', 'DFW'],
#  ['01301525', '-13', '137', 'ABI', 'DFW'],
#  ['01311525', '6', '137', 'ABI', 'DFW'],
#  ['01010925', '-9', '137', 'ABI', 'DFW'],
#  ['01011730', '72', '137', 'ABI', 'DFW'],
#  ['01010700', '-5', '137', 'ABI', 'DFW'],
#  ['01011155', '-6', '137', 'ABI', 'DFW'],
#  ['01010810', '62', '137', 'ABI', 'DFW'],
#  ['01020550', '-7', '137', 'ABI', 'DFW'],
#  ['01020925', '7', '137', 'ABI', 'DFW'],
#  ['01021730', '27', '137', 'ABI', 'DFW'],
#  ['01020700', '150', '137', 'ABI', 'DFW'],
#  ['01021155', '0', '137', 'ABI', 'DFW'],
#  ['01020810', '1', '137', 'ABI', 'DFW'],
#  ['01030550', '51', '137', 'ABI', 'DFW'],
#  ['01030925', '-7', '137', 'ABI', 'DFW'],
#  ['01031730', '-18', '137', 'ABI', 'DFW'],
#  ['01030700', '2', '137', 'ABI', 'DFW'],
#  ['01031155', '48', '137', 'ABI', 'DFW'],
#  ['01030810', '-3', '137', 'ABI', 'DFW'],
#  ['01040925', '-7', '137', 'ABI', 'DFW'],
#  ['01041730', '135', '137', 'ABI', 'DFW'],
#  ['01040700', '-3', '137', 'ABI', 'DFW'],
#  ['01041155', '-2', '137', 'ABI', 'DFW'],
#  ['01040810', '-12', '137', 'ABI', 'DFW'],
#  ['01050550', '-8', '137', 'ABI', 'DFW'],
#  ['01050925', '-10', '137', 'ABI', 'DFW'],
#  ['01051730', '-2', '137', 'ABI', 'DFW'],
#  ['01050700', '-6', '137', 'ABI', 'DFW'],
#  ['01051155', '-2', '137', 'ABI', 'DFW'],
#  ['01050810', '-12', '137', 'ABI', 'DFW'],
#  ['01060550', '-8', '137', 'ABI', 'DFW'],
#  ['01060925', '0', '137', 'ABI', 'DFW'],
#  ['01061730', '-7', '137', 'ABI', 'DFW'],
#  ['01060700', '-3', '137', 'ABI', 'DFW'],
#  ['01061155', '-4', '137', 'ABI', 'DFW'],
#  ['01060810', '-8', '137', 'ABI', 'DFW'],
#  ['01070550', '-3', '137', 'ABI', 'DFW'],
#  ['01070925', '62', '137', 'ABI', 'DFW'],
#  ['01071730', '0', '137', 'ABI', 'DFW'],
#  ['01070700', '4', '137', 'ABI', 'DFW'],
#  ['01071155', '10', '137', 'ABI', 'DFW'],
#  ['01070810', '-10', '137', 'ABI', 'DFW'],
#  ['01080550', '-9', '137', 'ABI', 'DFW'],
#  ['01080925', '-11', '137', 'ABI', 'DFW'],
#  ['01081730', '7', '137', 'ABI', 'DFW'],
#  ['01080700', '-8', '137', 'ABI', 'DFW'],
#  ['01081155', '-11', '137', 'ABI', 'DFW'],
#  ['01080810', '-13', '137', 'ABI', 'DFW'],
#  ['01081400', '10', '137', 'ABI', 'DFW'],
#  ['01090550', '395', '137', 'ABI', 'DFW'],
#  ['01090925', '0', '137', 'ABI', 'DFW'],
#  ['01091730', '38', '137', 'ABI', 'DFW'],
#  ['01090700', '6', '137', 'ABI', 'DFW'],
#  ['01091155', '21', '137', 'ABI', 'DFW'],
#  ['01090810', '16', '137', 'ABI', 'DFW'],
#  ['01091400', '-6', '137', 'ABI', 'DFW'],
#  ['01100550', '-4', '137', 'ABI', 'DFW'],
#  ['01100925', '34', '137', 'ABI', 'DFW'],
#  ['01101730', '-2', '137', 'ABI', 'DFW'],
#  ['01100700', '129', '137', 'ABI', 'DFW'],
#  ['01101155', '-1', '137', 'ABI', 'DFW'],
#  ['01100810', '-11', '137', 'ABI', 'DFW'],
#  ['01101400', '30', '137', 'ABI', 'DFW'],
#  ['01110905', '-8', '137', 'ABI', 'DFW'],
#  ['01111730', '-14', '137', 'ABI', 'DFW'],
#  ['01110700', '-5', '137', 'ABI', 'DFW'],
#  ['01111155', '16', '137', 'ABI', 'DFW'],
#  ['01110810', '-6', '137', 'ABI', 'DFW'],
#  ['01111400', '39', '137', 'ABI', 'DFW'],
#  ['01120550', '-12', '137', 'ABI', 'DFW'],
#  ['01120925', '-5', '137', 'ABI', 'DFW'],
#  ['01121730', '-9', '137', 'ABI', 'DFW'],
#  ['01120700', '35', '137', 'ABI', 'DFW'],
#  ['01121155', '158', '137', 'ABI', 'DFW'],
#  ['01120810', '-9', '137', 'ABI', 'DFW'],
#  ['01121400', '-9', '137', 'ABI', 'DFW'],
#  ['01130550', '-5', '137', 'ABI', 'DFW'],
#  ['01130925', '-7', '137', 'ABI', 'DFW'],
#  ['01131730', '-9', '137', 'ABI', 'DFW'],
#  ['01130700', '-9', '137', 'ABI', 'DFW'],
#  ['01131155', '-10', '137', 'ABI', 'DFW'],
#  ['01130810', '-7', '137', 'ABI', 'DFW'],
#  ['01131400', '-1', '137', 'ABI', 'DFW'],
#  ['01140550', '0', '137', 'ABI', 'DFW'],
#  ['01140925', '4', '137', 'ABI', 'DFW'],
#  ['01141730', '-13', '137', 'ABI', 'DFW'],
#  ['01140700', '49', '137', 'ABI', 'DFW'],
#  ['01141155', '-10', '137', 'ABI', 'DFW'],
#  ['01140810', '-8', '137', 'ABI', 'DFW'],
#  ['01141400', '-17', '137', 'ABI', 'DFW'],
#  ['01150550', '-11', '137', 'ABI', 'DFW'],
#  ['01150925', '-6', '137', 'ABI', 'DFW'],
#  ['01151730', '-9', '137', 'ABI', 'DFW'],
#  ['01150700', '-8', '137', 'ABI', 'DFW'],
#  ['01151155', '-5', '137', 'ABI', 'DFW'],
#  ['01150810', '-12', '137', 'ABI', 'DFW'],
#  ['01151400', '-3', '137', 'ABI', 'DFW'],
#  ['01160550', '-2', '137', 'ABI', 'DFW'],
#  ['01160925', '-12', '137', 'ABI', 'DFW'],
#  ['01161730', '-3', '137', 'ABI', 'DFW'],
#  ['01160700', '-8', '137', 'ABI', 'DFW'],
#  ['01161155', '56', '137', 'ABI', 'DFW'],
#  ['01160810', '-10', '137', 'ABI', 'DFW'],
#  ['01161400', '8', '137', 'ABI', 'DFW'],
#  ['01170550', '-1', '137', 'ABI', 'DFW'],
#  ['01170925', '-6', '137', 'ABI', 'DFW'],
#  ['01171730', '-5', '137', 'ABI', 'DFW'],
#  ['01170700', '-12', '137', 'ABI', 'DFW'],
#  ['01171155', '18', '137', 'ABI', 'DFW'],
#  ['01170810', '-11', '137', 'ABI', 'DFW'],
#  ['01171400', '-7', '137', 'ABI', 'DFW'],
#  ['01180905', '-7', '137', 'ABI', 'DFW'],
#  ['01181730', '-9', '137', 'ABI', 'DFW'],
#  ['01180700', '-10', '137', 'ABI', 'DFW'],
#  ['01181155', '-11', '137', 'ABI', 'DFW'],
#  ['01180810', '-13', '137', 'ABI', 'DFW'],
#  ['01181400', '6', '137', 'ABI', 'DFW'],
#  ['01190550', '-12', '137', 'ABI', 'DFW'],
#  ['01190925', '-12', '137', 'ABI', 'DFW'],
#  ['01191730', '-12', '137', 'ABI', 'DFW'],
#  ['01190700', '-9', '137', 'ABI', 'DFW'],
#  ['01191155', '-11', '137', 'ABI', 'DFW'],
#  ['01190810', '-22', '137', 'ABI', 'DFW'],
#  ['01191400', '-12', '137', 'ABI', 'DFW'],
#  ['01200550', '-9', '137', 'ABI', 'DFW'],
#  ['01200925', '-8', '137', 'ABI', 'DFW'],
#  ['01201730', '-8', '137', 'ABI', 'DFW'],
#  ['01200700', '-8', '137', 'ABI', 'DFW'],
#  ['01201155', '-5', '137', 'ABI', 'DFW'],
#  ['01200810', '19', '137', 'ABI', 'DFW'],
#  ['01201400', '3', '137', 'ABI', 'DFW'],
#  ['01210550', '-7', '137', 'ABI', 'DFW'],
#  ['01210925', '29', '137', 'ABI', 'DFW'],
#  ['01211730', '-9', '137', 'ABI', 'DFW'],
#  ['01210700', '-2', '137', 'ABI', 'DFW'],
#  ['01211155', '0', '137', 'ABI', 'DFW'],
#  ['01210810', '-8', '137', 'ABI', 'DFW'],
#  ['01211400', '-11', '137', 'ABI', 'DFW'],
#  ['01220550', '-12', '137', 'ABI', 'DFW'],
#  ['01220925', '-8', '137', 'ABI', 'DFW'],
#  ['01221730', '-10', '137', 'ABI', 'DFW'],
#  ['01220700', '-8', '137', 'ABI', 'DFW'],
#  ['01221155', '-6', '137', 'ABI', 'DFW'],
#  ['01220810', '-8', '137', 'ABI', 'DFW'],
#  ['01221400', '-4', '137', 'ABI', 'DFW'],
#  ['01230550', '-10', '137', 'ABI', 'DFW'],
#  ['01230925', '15', '137', 'ABI', 'DFW'],
#  ['01231730', '-7', '137', 'ABI', 'DFW'],
#  ['01230700', '-8', '137', 'ABI', 'DFW'],
#  ['01231155', '-5', '137', 'ABI', 'DFW'],
#  ['01230810', '-3', '137', 'ABI', 'DFW'],
#  ['01231400', '37', '137', 'ABI', 'DFW'],
#  ['01240550', '-8', '137', 'ABI', 'DFW'],
#  ['01240925', '-7', '137', 'ABI', 'DFW'],
#  ['01241730', '61', '137', 'ABI', 'DFW'],
#  ['01240700', '-14', '137', 'ABI', 'DFW'],
#  ['01241155', '-6', '137', 'ABI', 'DFW'],
#  ['01240810', '-6', '137', 'ABI', 'DFW'],
#  ['01241400', '-7', '137', 'ABI', 'DFW'],
#  ['01250905', '-13', '137', 'ABI', 'DFW'],
#  ['01251730', '-14', '137', 'ABI', 'DFW'],
#  ['01250700', '-6', '137', 'ABI', 'DFW'],
#  ['01251155', '-5', '137', 'ABI', 'DFW'],
#  ['01250810', '-14', '137', 'ABI', 'DFW'],
#  ['01251400', '-26', '137', 'ABI', 'DFW'],
#  ['01260550', '-8', '137', 'ABI', 'DFW'],
#  ['01260925', '-8', '137', 'ABI', 'DFW'],
#  ['01261730', '-4', '137', 'ABI', 'DFW'],
#  ['01260700', '-9', '137', 'ABI', 'DFW'],
#  ['01261155', '-13', '137', 'ABI', 'DFW'],
#  ['01260810', '-9', '137', 'ABI', 'DFW'],
#  ['01261400', '-11', '137', 'ABI', 'DFW'],
#  ['01270550', '-7', '137', 'ABI', 'DFW'],
#  ['01270925', '-5', '137', 'ABI', 'DFW'],
#  ['01271730', '-3', '137', 'ABI', 'DFW'],
#  ['01270700', '-7', '137', 'ABI', 'DFW'],
#  ['01271155', '-6', '137', 'ABI', 'DFW'],
#  ['01270810', '-10', '137', 'ABI', 'DFW'],
#  ['01271400', '-9', '137', 'ABI', 'DFW'],
#  ['01280550', '0', '137', 'ABI', 'DFW'],
#  ['01280925', '-4', '137', 'ABI', 'DFW'],
#  ['01281730', '-10', '137', 'ABI', 'DFW'],
#  ['01280700', '-6', '137', 'ABI', 'DFW'],
#  ['01281155', '-4', '137', 'ABI', 'DFW'],
#  ['01280810', '-5', '137', 'ABI', 'DFW'],
#  ['01281400', '-6', '137', 'ABI', 'DFW'],
#  ['01290550', '-5', '137', 'ABI', 'DFW'],
#  ['01290925', '57', '137', 'ABI', 'DFW'],
#  ['01291730', '8', '137', 'ABI', 'DFW'],
#  ['01290700', '-6', '137', 'ABI', 'DFW'],
#  ['01291155', '3', '137', 'ABI', 'DFW'],
#  ['01290810', '-8', '137', 'ABI', 'DFW'],
#  ['01291400', '-13', '137', 'ABI', 'DFW'],
#  ['01300550', '-4', '137', 'ABI', 'DFW'],
#  ['01300925', '-6', '137', 'ABI', 'DFW'],
#  ['01301730', '-7', '137', 'ABI', 'DFW'],
#  ['01300700', '-7', '137', 'ABI', 'DFW'],
#  ['01301155', '-6', '137', 'ABI', 'DFW'],
#  ['01300810', '-11', '137', 'ABI', 'DFW'],
#  ['01301400', '-13', '137', 'ABI', 'DFW'],
#  ['01310550', '-2', '137', 'ABI', 'DFW'],
#  ['01310925', '27', '137', 'ABI', 'DFW'],
#  ['01311730', '-6', '137', 'ABI', 'DFW'],
#  ['01310700', '-7', '137', 'ABI', 'DFW'],
#  ['01311155', '2', '137', 'ABI', 'DFW'],
#  ['01310810', '29', '137', 'ABI', 'DFW'],
#  ['01311400', '-13', '137', 'ABI', 'DFW'],
#  ['01011405', '1', '494', 'ABQ', 'DFW'],
#  ['01011520', '0', '494', 'ABQ', 'DFW'],
#  ['01010605', '-5', '494', 'ABQ', 'DFW'],
#  ['01010835', '-7', '494', 'ABQ', 'DFW'],
#  ['01010730', '-1', '494', 'ABQ', 'DFW'],
#  ['01011030', '-2', '494', 'ABQ', 'DFW'],
#  ['01011135', '-2', '494', 'ABQ', 'DFW'],
#  ['01021405', '8', '494', 'ABQ', 'DFW'],
#  ['01021520', '1', '494', 'ABQ', 'DFW'],
#  ['01020605', '118', '494', 'ABQ', 'DFW'],
#  ['01020835', '59', '494', 'ABQ', 'DFW'],
#  ['01020730', '87', '494', 'ABQ', 'DFW'],
#  ['01021030', '85', '494', 'ABQ', 'DFW'],
#  ['01021135', '115', '494', 'ABQ', 'DFW'],
#  ['01021655', '87', '494', 'ABQ', 'DFW'],
#  ['01031405', '38', '494', 'ABQ', 'DFW'],
#  ['01031520', '36', '494', 'ABQ', 'DFW'],
#  ['01030605', '2', '494', 'ABQ', 'DFW'],
#  ['01030835', '33', '494', 'ABQ', 'DFW'],
#  ['01030730', '-4', '494', 'ABQ', 'DFW'],
#  ['01031030', '-1', '494', 'ABQ', 'DFW'],
#  ['01031135', '-7', '494', 'ABQ', 'DFW'],
#  ['01031655', '85', '494', 'ABQ', 'DFW'],
#  ['01041405', '0', '494', 'ABQ', 'DFW'],
#  ['01041520', '0', '494', 'ABQ', 'DFW'],
#  ['01040605', '1', '494', 'ABQ', 'DFW'],
#  ['01040835', '-7', '494', 'ABQ', 'DFW'],
#  ['01040730', '0', '494', 'ABQ', 'DFW'],
#  ['01041030', '10', '494', 'ABQ', 'DFW'],
#  ['01041135', '-4', '494', 'ABQ', 'DFW'],
#  ['01051405', '47', '494', 'ABQ', 'DFW'],
#  ['01051520', '59', '494', 'ABQ', 'DFW'],
#  ['01050605', '1', '494', 'ABQ', 'DFW'],
#  ['01050835', '-2', '494', 'ABQ', 'DFW'],
#  ['01050730', '-2', '494', 'ABQ', 'DFW'],
#  ['01051030', '30', '494', 'ABQ', 'DFW'],
#  ['01051135', '9', '494', 'ABQ', 'DFW'],
#  ['01051655', '9', '494', 'ABQ', 'DFW'],
#  ['01061405', '25', '494', 'ABQ', 'DFW'],
#  ['01061520', '36', '494', 'ABQ', 'DFW'],
#  ['01060605', '-4', '494', 'ABQ', 'DFW'],
#  ['01060835', '-2', '494', 'ABQ', 'DFW'],
#  ['01060730', '-7', '494', 'ABQ', 'DFW'],
#  ['01061030', '-3', '494', 'ABQ', 'DFW'],
#  ['01061135', '71', '494', 'ABQ', 'DFW'],
#  ['01061655', '0', '494', 'ABQ', 'DFW'],
#  ['01071405', '78', '494', 'ABQ', 'DFW'],
#  ['01071520', '4', '494', 'ABQ', 'DFW'],
#  ['01070605', '0', '494', 'ABQ', 'DFW'],
#  ['01070835', '173', '494', 'ABQ', 'DFW'],
#  ['01070730', '-4', '494', 'ABQ', 'DFW'],
#  ['01071030', '1', '494', 'ABQ', 'DFW'],
#  ['01071135', '0', '494', 'ABQ', 'DFW'],
#  ['01081405', '-6', '494', 'ABQ', 'DFW'],
#  ['01081520', '17', '494', 'ABQ', 'DFW'],
#  ['01080605', '-7', '494', 'ABQ', 'DFW'],
#  ['01080835', '-6', '494', 'ABQ', 'DFW'],
#  ['01080730', '-5', '494', 'ABQ', 'DFW'],
#  ['01081030', '-6', '494', 'ABQ', 'DFW'],
#  ['01081135', '-1', '494', 'ABQ', 'DFW'],
#  ['01091405', '18', '494', 'ABQ', 'DFW'],
#  ['01091520', '-3', '494', 'ABQ', 'DFW'],
#  ['01090605', '-8', '494', 'ABQ', 'DFW'],
#  ['01090835', '-12', '494', 'ABQ', 'DFW'],
#  ['01090730', '-8', '494', 'ABQ', 'DFW'],
#  ['01091030', '9', '494', 'ABQ', 'DFW'],
#  ['01091135', '0', '494', 'ABQ', 'DFW'],
#  ['01101405', '-6', '494', 'ABQ', 'DFW'],
#  ['01101520', '-8', '494', 'ABQ', 'DFW'],
#  ['01100605', '-10', '494', 'ABQ', 'DFW'],
#  ['01100835', '-15', '494', 'ABQ', 'DFW'],
#  ['01100730', '-6', '494', 'ABQ', 'DFW'],
#  ['01101030', '-4', '494', 'ABQ', 'DFW'],
#  ['01101135', '-14', '494', 'ABQ', 'DFW'],
#  ['01111405', '43', '494', 'ABQ', 'DFW'],
#  ['01111520', '-8', '494', 'ABQ', 'DFW'],
#  ['01110605', '-6', '494', 'ABQ', 'DFW'],
#  ['01110835', '-9', '494', 'ABQ', 'DFW'],
#  ['01110730', '-8', '494', 'ABQ', 'DFW'],
#  ['01111030', '-7', '494', 'ABQ', 'DFW'],
#  ['01111135', '3', '494', 'ABQ', 'DFW'],
#  ['01121405', '-9', '494', 'ABQ', 'DFW'],
#  ['01121520', '-7', '494', 'ABQ', 'DFW'],
#  ['01120835', '-11', '494', 'ABQ', 'DFW'],
#  ['01120730', '-4', '494', 'ABQ', 'DFW'],
#  ['01121030', '-1', '494', 'ABQ', 'DFW'],
#  ['01121135', '-9', '494', 'ABQ', 'DFW'],
#  ['01131405', '2', '494', 'ABQ', 'DFW'],
#  ['01131520', '-12', '494', 'ABQ', 'DFW'],
#  ['01130605', '-8', '494', 'ABQ', 'DFW'],
#  ['01130835', '-12', '494', 'ABQ', 'DFW'],
#  ['01130730', '-3', '494', 'ABQ', 'DFW'],
#  ['01131030', '-10', '494', 'ABQ', 'DFW'],
#  ['01131135', '-7', '494', 'ABQ', 'DFW'],
#  ['01141405', '-6', '494', 'ABQ', 'DFW'],
#  ['01141520', '-4', '494', 'ABQ', 'DFW'],
#  ['01140605', '-5', '494', 'ABQ', 'DFW'],
#  ['01140835', '-7', '494', 'ABQ', 'DFW'],
#  ['01140730', '-9', '494', 'ABQ', 'DFW'],
#  ['01141030', '-7', '494', 'ABQ', 'DFW'],
#  ['01141135', '-6', '494', 'ABQ', 'DFW'],
#  ['01151405', '-3', '494', 'ABQ', 'DFW'],
#  ['01151520', '-4', '494', 'ABQ', 'DFW'],
#  ['01150605', '-4', '494', 'ABQ', 'DFW'],
#  ['01150835', '-10', '494', 'ABQ', 'DFW'],
#  ['01150730', '4', '494', 'ABQ', 'DFW'],
#  ['01151030', '-8', '494', 'ABQ', 'DFW'],
#  ['01151135', '-8', '494', 'ABQ', 'DFW'],
#  ['01161405', '43', '494', 'ABQ', 'DFW'],
#  ['01161520', '58', '494', 'ABQ', 'DFW'],
#  ['01160605', '-3', '494', 'ABQ', 'DFW'],
#  ['01160835', '-8', '494', 'ABQ', 'DFW'],
#  ['01160730', '-6', '494', 'ABQ', 'DFW'],
#  ['01161030', '-6', '494', 'ABQ', 'DFW'],
#  ['01161135', '-4', '494', 'ABQ', 'DFW'],
#  ['01171405', '-5', '494', 'ABQ', 'DFW'],
#  ['01171520', '-1', '494', 'ABQ', 'DFW'],
#  ['01170605', '-6', '494', 'ABQ', 'DFW'],
#  ['01170835', '0', '494', 'ABQ', 'DFW'],
#  ['01170730', '8', '494', 'ABQ', 'DFW'],
#  ['01171030', '-6', '494', 'ABQ', 'DFW'],
#  ['01171135', '-1', '494', 'ABQ', 'DFW'],
#  ['01181405', '0', '494', 'ABQ', 'DFW'],
#  ['01181520', '38', '494', 'ABQ', 'DFW'],
#  ['01180605', '-12', '494', 'ABQ', 'DFW'],
#  ['01180835', '-9', '494', 'ABQ', 'DFW'],
#  ['01180730', '-4', '494', 'ABQ', 'DFW'],
#  ['01181030', '-9', '494', 'ABQ', 'DFW'],
#  ['01181135', '-4', '494', 'ABQ', 'DFW'],
#  ['01191405', '-2', '494', 'ABQ', 'DFW'],
#  ['01191520', '-4', '494', 'ABQ', 'DFW'],
#  ['01190835', '-8', '494', 'ABQ', 'DFW'],
#  ['01190730', '-9', '494', 'ABQ', 'DFW'],
#  ['01191030', '-15', '494', 'ABQ', 'DFW'],
#  ['01191135', '-8', '494', 'ABQ', 'DFW'],
#  ['01201405', '-4', '494', 'ABQ', 'DFW'],
#  ['01201520', '-10', '494', 'ABQ', 'DFW'],
#  ['01200605', '-3', '494', 'ABQ', 'DFW'],
#  ['01200835', '-6', '494', 'ABQ', 'DFW'],
#  ['01200730', '-3', '494', 'ABQ', 'DFW'],
#  ['01201030', '-10', '494', 'ABQ', 'DFW'],
#  ['01201135', '-8', '494', 'ABQ', 'DFW'],
#  ['01211405', '-8', '494', 'ABQ', 'DFW'],
#  ['01211520', '2', '494', 'ABQ', 'DFW'],
#  ['01210605', '-12', '494', 'ABQ', 'DFW'],
#  ['01210835', '-9', '494', 'ABQ', 'DFW'],
#  ['01210730', '-12', '494', 'ABQ', 'DFW'],
#  ['01211030', '-5', '494', 'ABQ', 'DFW'],
#  ['01211135', '-11', '494', 'ABQ', 'DFW'],
#  ['01221405', '-9', '494', 'ABQ', 'DFW'],
#  ['01221520', '-6', '494', 'ABQ', 'DFW'],
#  ['01220605', '-10', '494', 'ABQ', 'DFW'],
#  ['01220835', '-7', '494', 'ABQ', 'DFW'],
#  ['01220730', '-4', '494', 'ABQ', 'DFW'],
#  ['01221030', '87', '494', 'ABQ', 'DFW'],
#  ['01221135', '-4', '494', 'ABQ', 'DFW'],
#  ['01231405', '76', '494', 'ABQ', 'DFW'],
#  ['01231520', '33', '494', 'ABQ', 'DFW'],
#  ['01230605', '-5', '494', 'ABQ', 'DFW'],
#  ['01230835', '-5', '494', 'ABQ', 'DFW'],
#  ['01230730', '-6', '494', 'ABQ', 'DFW'],
#  ['01231030', '62', '494', 'ABQ', 'DFW'],
#  ['01231135', '-1', '494', 'ABQ', 'DFW'],
#  ['01241405', '79', '494', 'ABQ', 'DFW'],
#  ['01241520', '6', '494', 'ABQ', 'DFW'],
#  ['01240605', '68', '494', 'ABQ', 'DFW'],
#  ['01240835', '3', '494', 'ABQ', 'DFW'],
#  ['01240730', '97', '494', 'ABQ', 'DFW'],
#  ['01241030', '-2', '494', 'ABQ', 'DFW'],
#  ['01241135', '0', '494', 'ABQ', 'DFW'],
#  ['01251405', '-7', '494', 'ABQ', 'DFW'],
#  ['01251520', '11', '494', 'ABQ', 'DFW'],
#  ['01250605', '-10', '494', 'ABQ', 'DFW'],
#  ['01250835', '-13', '494', 'ABQ', 'DFW'],
#  ['01250730', '-2', '494', 'ABQ', 'DFW'],
#  ['01251030', '-4', '494', 'ABQ', 'DFW'],
#  ['01251135', '-9', '494', 'ABQ', 'DFW'],
#  ['01261405', '-5', '494', 'ABQ', 'DFW'],
#  ['01261520', '11', '494', 'ABQ', 'DFW'],
#  ['01260835', '-5', '494', 'ABQ', 'DFW'],
#  ['01260730', '-2', '494', 'ABQ', 'DFW'],
#  ['01261030', '-6', '494', 'ABQ', 'DFW'],
#  ['01261135', '1', '494', 'ABQ', 'DFW'],
#  ['01271405', '-11', '494', 'ABQ', 'DFW'],
#  ['01271520', '-2', '494', 'ABQ', 'DFW'],
#  ['01270605', '0', '494', 'ABQ', 'DFW'],
#  ['01270835', '-13', '494', 'ABQ', 'DFW'],
#  ['01270730', '-12', '494', 'ABQ', 'DFW'],
#  ['01271030', '-6', '494', 'ABQ', 'DFW'],
#  ['01271135', '2', '494', 'ABQ', 'DFW'],
#  ['01281405', '0', '494', 'ABQ', 'DFW'],
#  ['01281520', '-8', '494', 'ABQ', 'DFW'],
#  ['01280605', '-12', '494', 'ABQ', 'DFW'],
#  ['01280835', '-4', '494', 'ABQ', 'DFW'],
#  ['01280730', '-10', '494', 'ABQ', 'DFW'],
#  ['01281030', '-6', '494', 'ABQ', 'DFW'],
#  ['01281135', '-7', '494', 'ABQ', 'DFW'],
#  ['01291405', '8', '494', 'ABQ', 'DFW'],
#  ['01291520', '-4', '494', 'ABQ', 'DFW'],
#  ['01290605', '-6', '494', 'ABQ', 'DFW'],
#  ['01290835', '1', '494', 'ABQ', 'DFW'],
#  ['01290730', '-6', '494', 'ABQ', 'DFW'],
#  ['01291030', '-4', '494', 'ABQ', 'DFW'],
#  ['01291135', '19', '494', 'ABQ', 'DFW'],
#  ['01301405', '-4', '494', 'ABQ', 'DFW'],
#  ['01301520', '-3', '494', 'ABQ', 'DFW'],
#  ['01300605', '-7', '494', 'ABQ', 'DFW'],
#  ['01300835', '-3', '494', 'ABQ', 'DFW'],
#  ['01300730', '-3', '494', 'ABQ', 'DFW'],
#  ['01301030', '0', '494', 'ABQ', 'DFW'],
#  ['01301135', '-1', '494', 'ABQ', 'DFW'],
#  ['01311405', '3', '494', 'ABQ', 'DFW'],
#  ['01311520', '4', '494', 'ABQ', 'DFW'],
#  ['01310605', '-6', '494', 'ABQ', 'DFW'],
#  ['01310835', '-9', '494', 'ABQ', 'DFW'],
#  ['01310730', '-5', '494', 'ABQ', 'DFW'],
#  ['01311030', '1', '494', 'ABQ', 'DFW'],
#  ['01311135', '-8', '494', 'ABQ', 'DFW'],
#  ['01012355', '0', '1586', 'ABQ', 'JFK'],
#  ['01022355', '158', '1586', 'ABQ', 'JFK'],
#  ['01032355', '0', '1586', 'ABQ', 'JFK'],
#  ['01042355', '0', '1586', 'ABQ', 'JFK'],
#  ['01052355', '0', '1586', 'ABQ', 'JFK'],
#  ['01062355', '0', '1586', 'ABQ', 'JFK'],
#  ['01072359', '14', '1586', 'ABQ', 'JFK'],
#  ['01082358', '-4', '1586', 'ABQ', 'JFK'],
#  ['01092358', '20', '1586', 'ABQ', 'JFK'],
#  ['01102358', '-2', '1586', 'ABQ', 'JFK'],
#  ['01112358', '116', '1586', 'ABQ', 'JFK'],
#  ['01122358', '0', '1586', 'ABQ', 'JFK'],
#  ['01132358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01142359', '-17', '1586', 'ABQ', 'JFK'],
#  ['01152358', '135', '1586', 'ABQ', 'JFK'],
#  ['01162358', '-13', '1586', 'ABQ', 'JFK'],
#  ['01172358', '-10', '1586', 'ABQ', 'JFK'],
#  ['01182358', '-17', '1586', 'ABQ', 'JFK'],
#  ['01192358', '-18', '1586', 'ABQ', 'JFK'],
#  ['01202358', '-9', '1586', 'ABQ', 'JFK'],
#  ['01212359', '0', '1586', 'ABQ', 'JFK'],
#  ['01222358', '0', '1586', 'ABQ', 'JFK'],
#  ['01232358', '44', '1586', 'ABQ', 'JFK'],
#  ['01242358', '-6', '1586', 'ABQ', 'JFK'],
#  ['01252358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01262358', '-22', '1586', 'ABQ', 'JFK'],
#  ['01272358', '9', '1586', 'ABQ', 'JFK'],
#  ['01282359', '-20', '1586', 'ABQ', 'JFK'],
#  ['01292358', '17', '1586', 'ABQ', 'JFK'],
#  ['01302358', '7', '1586', 'ABQ', 'JFK'],
#  ['01312358', '-12', '1586', 'ABQ', 'JFK'],
#  ['01011316', '-8', '1103', 'ABQ', 'ATL'],
#  ['01010730', '-4', '1103', 'ABQ', 'ATL'],
#  ['01011440', '-4', '852', 'ABQ', 'MSP'],
#  ['01010700', '-4', '852', 'ABQ', 'MSP'],
#  ['01020730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01020615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01021326', '6', '1103', 'ABQ', 'ATL'],
#  ['01021440', '-4', '852', 'ABQ', 'MSP'],
#  ['01020700', '-4', '852', 'ABQ', 'MSP'],
#  ['01030730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01030615', '0', '1103', 'ABQ', 'ATL'],
#  ['01031326', '6', '1103', 'ABQ', 'ATL'],
#  ['01031440', '6', '852', 'ABQ', 'MSP'],
#  ['01030700', '58', '852', 'ABQ', 'MSP'],
#  ['01040730', '-1', '1103', 'ABQ', 'ATL'],
#  ['01040615', '0', '1103', 'ABQ', 'ATL'],
#  ['01041326', '31', '1103', 'ABQ', 'ATL'],
#  ['01041440', '-3', '852', 'ABQ', 'MSP'],
#  ['01040700', '1', '852', 'ABQ', 'MSP'],
#  ['01051326', '26', '1103', 'ABQ', 'ATL'],
#  ['01050730', '-2', '1103', 'ABQ', 'ATL'],
#  ['01050615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01051440', '40', '852', 'ABQ', 'MSP'],
#  ['01050700', '0', '852', 'ABQ', 'MSP'],
#  ['01060600', '-1', '852', 'ABQ', 'MSP'],
#  ['01061230', '-3', '428', 'ABQ', 'SLC'],
#  ['01061328', '36', '1103', 'ABQ', 'ATL'],
#  ['01060730', '44', '1103', 'ABQ', 'ATL'],
#  ['01060615', '22', '1103', 'ABQ', 'ATL'],
#  ['01071328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01070615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01081328', '16', '1103', 'ABQ', 'ATL'],
#  ['01080615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01091328', '73', '1103', 'ABQ', 'ATL'],
#  ['01090615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01101328', '17', '1103', 'ABQ', 'ATL'],
#  ['01100615', '0', '1103', 'ABQ', 'ATL'],
#  ['01111328', '15', '1103', 'ABQ', 'ATL'],
#  ['01110615', '-1', '1103', 'ABQ', 'ATL'],
#  ['01121328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01120615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01131328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01130615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01141328', '0', '1103', 'ABQ', 'ATL'],
#  ['01140615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01151328', '385', '1103', 'ABQ', 'ATL'],
#  ['01150615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01161328', '11', '1103', 'ABQ', 'ATL'],
#  ['01160615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01171328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01170615', '489', '1103', 'ABQ', 'ATL'],
#  ['01181328', '-7', '1103', 'ABQ', 'ATL'],
#  ['01180615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01191328', '-4', '1103', 'ABQ', 'ATL'],
#  ['01190615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01201328', '9', '1103', 'ABQ', 'ATL'],
#  ['01200615', '0', '1103', 'ABQ', 'ATL'],
#  ['01211328', '-3', '1103', 'ABQ', 'ATL'],
#  ['01210615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01221328', '-5', '1103', 'ABQ', 'ATL'],
#  ['01220615', '-3', '1103', 'ABQ', 'ATL'],
#  ['01231328', '30', '1103', 'ABQ', 'ATL'],
#  ['01230615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01241328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01240615', '1', '1103', 'ABQ', 'ATL'],
#  ['01251328', '-6', '1103', 'ABQ', 'ATL'],
#  ['01250615', '-4', '1103', 'ABQ', 'ATL'],
#  ['01261328', '-1', '1103', 'ABQ', 'ATL'],
#  ['01260615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01271328', '-2', '1103', 'ABQ', 'ATL'],
#  ['01270615', '-6', '1103', 'ABQ', 'ATL'],
#  ['01281328', '0', '1103', 'ABQ', 'ATL'],
#  ['01280615', '0', '1103', 'ABQ', 'ATL'],
#  ['01291328', '141', '1103', 'ABQ', 'ATL'],
#  ['01290615', '-2', '1103', 'ABQ', 'ATL'],
#  ['01301328', '296', '1103', 'ABQ', 'ATL'],
#  ['01300615', '0', '1103', 'ABQ', 'ATL'],
#  ['01311328', '0', '1103', 'ABQ', 'ATL'],
#  ['01310615', '-5', '1103', 'ABQ', 'ATL'],
#  ['01011712', '57', '646', 'ABQ', 'IAH'],
#  ['01011420', '-6', '646', 'ABQ', 'IAH'],
#  ['01011042', '-10', '646', 'ABQ', 'IAH'],
#  ['01010805', '23', '646', 'ABQ', 'IAH'],
#  ['01011933', '0', '303', 'ABQ', 'DEN'],
#  ['01021726', '-6', '646', 'ABQ', 'IAH'],
#  ['01021411', '-6', '646', 'ABQ', 'IAH'],
#  ['01021050', '37', '646', 'ABQ', 'IAH'],
#  ['01020610', '0', '646', 'ABQ', 'IAH'],
#  ['01020536', '0', '303', 'ABQ', 'DEN'],
#  ['01031712', '8', '646', 'ABQ', 'IAH'],
#  ['01031411', '0', '646', 'ABQ', 'IAH'],
#  ['01031050', '0', '646', 'ABQ', 'IAH'],
#  ['01030610', '-1', '646', 'ABQ', 'IAH'],
#  ['01030536', '-7', '303', 'ABQ', 'DEN'],
#  ['01041712', '138', '646', 'ABQ', 'IAH'],
#  ['01041050', '-6', '646', 'ABQ', 'IAH'],
#  ['01040805', '-7', '646', 'ABQ', 'IAH'],
#  ['01040530', '15', '303', 'ABQ', 'DEN'],
#  ['01050805', '-7', '646', 'ABQ', 'IAH'],
#  ['01061712', '26', '646', 'ABQ', 'IAH'],
#  ['01061411', '0', '646', 'ABQ', 'IAH'],
#  ['01061050', '194', '646', 'ABQ', 'IAH'],
#  ['01060610', '-5', '646', 'ABQ', 'IAH'],
#  ['01060536', '0', '303', 'ABQ', 'DEN'],
#  ['01071053', '10', '646', 'ABQ', 'IAH'],
#  ['01071713', '8', '646', 'ABQ', 'IAH'],
#  ['01070903', '0', '646', 'ABQ', 'IAH'],
#  ['01081713', '9', '646', 'ABQ', 'IAH'],
#  ['01080903', '-7', '646', 'ABQ', 'IAH'],
#  ['01081101', '80', '646', 'ABQ', 'IAH'],
#  ['01080736', '-2', '303', 'ABQ', 'DEN'],
#  ['01091713', '51', '646', 'ABQ', 'IAH'],
#  ['01090903', '-7', '646', 'ABQ', 'IAH'],
#  ['01101713', '-6', '646', 'ABQ', 'IAH'],
#  ['01100903', '-7', '646', 'ABQ', 'IAH'],
#  ['01110903', '-12', '646', 'ABQ', 'IAH'],
#  ['01120903', '-7', '646', 'ABQ', 'IAH'],
#  ['01121713', '-4', '646', 'ABQ', 'IAH'],
#  ['01120720', '-1', '303', 'ABQ', 'DEN'],
#  ['01121722', '-12', '303', 'ABQ', 'DEN'],
#  ['01121007', '-10', '303', 'ABQ', 'DEN'],
#  ['01131713', '-4', '646', 'ABQ', 'IAH'],
#  ['01130903', '-6', '646', 'ABQ', 'IAH'],
#  ['01141101', '-9', '646', 'ABQ', 'IAH'],
#  ['01141713', '-10', '646', 'ABQ', 'IAH'],
#  ['01140903', '-10', '646', 'ABQ', 'IAH'],
#  ['01151713', '58', '646', 'ABQ', 'IAH'],
#  ['01150903', '-8', '646', 'ABQ', 'IAH'],
#  ['01151101', '-14', '646', 'ABQ', 'IAH'],
#  ['01150736', '-8', '303', 'ABQ', 'DEN'],
#  ['01161713', '7', '646', 'ABQ', 'IAH'],
#  ['01160903', '-5', '646', 'ABQ', 'IAH'],
#  ['01171713', '-8', '646', 'ABQ', 'IAH'],
#  ['01170903', '23', '646', 'ABQ', 'IAH'],
#  ['01180903', '-10', '646', 'ABQ', 'IAH'],
#  ['01190903', '-7', '646', 'ABQ', 'IAH'],
#  ['01191713', '-2', '646', 'ABQ', 'IAH'],
#  ['01190720', '-5', '303', 'ABQ', 'DEN'],
#  ['01191722', '-14', '303', 'ABQ', 'DEN'],
#  ['01191007', '-9', '303', 'ABQ', 'DEN'],
#  ['01201713', '-2', '646', 'ABQ', 'IAH'],
#  ['01200903', '-3', '646', 'ABQ', 'IAH'],
#  ['01211101', '7', '646', 'ABQ', 'IAH'],
#  ['01211713', '-6', '646', 'ABQ', 'IAH'],
#  ['01210903', '-11', '646', 'ABQ', 'IAH'],
#  ['01221713', '12', '646', 'ABQ', 'IAH'],
#  ['01220903', '-5', '646', 'ABQ', 'IAH'],
#  ['01221101', '-6', '646', 'ABQ', 'IAH'],
#  ['01220736', '-7', '303', 'ABQ', 'DEN'],
#  ['01231713', '0', '646', 'ABQ', 'IAH'],
#  ['01230903', '-6', '646', 'ABQ', 'IAH'],
#  ['01241713', '-8', '646', 'ABQ', 'IAH'],
#  ['01240903', '0', '646', 'ABQ', 'IAH'],
#  ['01250903', '-4', '646', 'ABQ', 'IAH'],
#  ['01260903', '7', '646', 'ABQ', 'IAH'],
#  ['01261713', '1', '646', 'ABQ', 'IAH'],
#  ['01260720', '1', '303', 'ABQ', 'DEN'],
#  ['01261722', '-11', '303', 'ABQ', 'DEN'],
#  ['01261007', '-13', '303', 'ABQ', 'DEN'],
#  ['01271713', '-7', '646', 'ABQ', 'IAH'],
#  ['01270903', '-7', '646', 'ABQ', 'IAH'],
#  ['01281101', '0', '646', 'ABQ', 'IAH'],
#  ['01281713', '0', '646', 'ABQ', 'IAH'],
#  ['01280903', '0', '646', 'ABQ', 'IAH'],
#  ['01291713', '102', '646', 'ABQ', 'IAH'],
#  ['01290903', '146', '646', 'ABQ', 'IAH'],
#  ['01291101', '127', '646', 'ABQ', 'IAH'],
#  ['01290736', '9', '303', 'ABQ', 'DEN'],
#  ['01301713', '-3', '646', 'ABQ', 'IAH'],
#  ['01300903', '-8', '646', 'ABQ', 'IAH'],
#  ['01311713', '1', '646', 'ABQ', 'IAH'],
#  ['01310903', '12', '646', 'ABQ', 'IAH'],
#  ['01011450', '7', '303', 'ABQ', 'DEN'],
#  ['01021450', '32', '303', 'ABQ', 'DEN'],
#  ['01020800', '-8', '303', 'ABQ', 'DEN'],
#  ['01031450', '2', '303', 'ABQ', 'DEN'],
#  ['01030800', '-3', '303', 'ABQ', 'DEN'],
#  ['01040800', '94', '303', 'ABQ', 'DEN'],
#  ['01050800', '-4', '303', 'ABQ', 'DEN'],
#  ['01060800', '140', '303', 'ABQ', 'DEN'],
#  ['01011950', '128', '589', 'ABQ', 'LAX'],
#  ['01010545', '0', '589', 'ABQ', 'LAX'],
#  ['01021950', '95', '589', 'ABQ', 'LAX'],
#  ['01020545', '0', '589', 'ABQ', 'LAX'],
#  ['01031950', '25', '589', 'ABQ', 'LAX'],
#  ['01030545', '0', '589', 'ABQ', 'LAX'],
#  ['01040545', '-4', '589', 'ABQ', 'LAX'],
#  ['01051950', '53', '589', 'ABQ', 'LAX'],
#  ['01061950', '53', '589', 'ABQ', 'LAX'],
#  ['01060545', '22', '589', 'ABQ', 'LAX'],
#  ['01071950', '122', '589', 'ABQ', 'LAX'],
#  ['01070545', '-4', '589', 'ABQ', 'LAX'],
#  ['01081950', '13', '589', 'ABQ', 'LAX'],
#  ['01080545', '33', '589', 'ABQ', 'LAX'],
#  ['01091950', '-8', '589', 'ABQ', 'LAX'],
#  ['01090545', '-4', '589', 'ABQ', 'LAX'],
#  ['01101950', '0', '589', 'ABQ', 'LAX'],
#  ['01100545', '-4', '589', 'ABQ', 'LAX'],
#  ['01110545', '7', '589', 'ABQ', 'LAX'],
#  ['01121950', '-9', '589', 'ABQ', 'LAX'],
#  ['01131950', '0', '589', 'ABQ', 'LAX'],
#  ['01130545', '14', '589', 'ABQ', 'LAX'],
#  ['01141950', '-6', '589', 'ABQ', 'LAX'],
#  ['01140545', '-5', '589', 'ABQ', 'LAX'],
#  ['01151950', '0', '589', 'ABQ', 'LAX'],
#  ['01150545', '0', '589', 'ABQ', 'LAX'],
#  ['01161950', '-7', '589', 'ABQ', 'LAX'],
#  ['01160545', '-1', '589', 'ABQ', 'LAX'],
#  ['01171950', '8', '589', 'ABQ', 'LAX'],
#  ['01170545', '-7', '589', 'ABQ', 'LAX'],
#  ['01180545', '0', '589', 'ABQ', 'LAX'],
#  ['01191950', '33', '589', 'ABQ', 'LAX'],
#  ['01201950', '56', '589', 'ABQ', 'LAX'],
#  ['01200545', '-7', '589', 'ABQ', 'LAX'],
#  ['01211950', '10', '589', 'ABQ', 'LAX'],
#  ['01210545', '-4', '589', 'ABQ', 'LAX'],
#  ['01221950', '58', '589', 'ABQ', 'LAX'],
#  ['01220545', '-8', '589', 'ABQ', 'LAX'],
#  ['01231950', '12', '589', 'ABQ', 'LAX'],
#  ['01230545', '0', '589', 'ABQ', 'LAX'],
#  ['01241950', '-8', '589', 'ABQ', 'LAX'],
#  ['01240545', '0', '589', 'ABQ', 'LAX'],
#  ['01250545', '-7', '589', 'ABQ', 'LAX'],
#  ['01261950', '-9', '589', 'ABQ', 'LAX'],
#  ['01271950', '112', '589', 'ABQ', 'LAX'],
#  ['01270545', '-8', '589', 'ABQ', 'LAX'],
#  ['01281950', '22', '589', 'ABQ', 'LAX'],
#  ['01280545', '-4', '589', 'ABQ', 'LAX'],
#  ['01291950', '62', '589', 'ABQ', 'LAX'],
#  ['01290545', '-7', '589', 'ABQ', 'LAX'],
#  ['01301950', '-8', '589', 'ABQ', 'LAX'],
#  ['01300545', '97', '589', 'ABQ', 'LAX'],
#  ['01311950', '-10', '589', 'ABQ', 'LAX'],
#  ['01310545', '6', '589', 'ABQ', 'LAX'],
#  ['01011225', '10', '589', 'ABQ', 'LAX'],
#  ['01012137', '-8', '285', 'ABQ', 'PHX'],
#  ['01010620', '-7', '285', 'ABQ', 'PHX'],
#  ['01011225', '-4', '285', 'ABQ', 'PHX'],
#  ['01010830', '-5', '285', 'ABQ', 'PHX'],
#  ['01011835', '-6', '285', 'ABQ', 'PHX'],
#  ['01010715', '-2', '428', 'ABQ', 'SLC'],
#  ['01011204', '26', '428', 'ABQ', 'SLC'],
#  ['01011626', '39', '589', 'ABQ', 'LAX'],
#  ['01010600', '-7', '779', 'ABQ', 'SFO'],
#  ['01011047', '25', '589', 'ABQ', 'LAX'],
#  ['01011344', '21', '303', 'ABQ', 'DEN'],
#  ['01021225', '4', '589', 'ABQ', 'LAX'],
#  ['01022137', '-6', '285', 'ABQ', 'PHX'],
#  ['01020620', '1', '285', 'ABQ', 'PHX'],
#  ['01021225', '-6', '285', 'ABQ', 'PHX'],
#  ['01020830', '-3', '285', 'ABQ', 'PHX'],
#  ['01021835', '-8', '285', 'ABQ', 'PHX'],
#  ['01020600', '-2', '428', 'ABQ', 'SLC'],
#  ['01021204', '11', '428', 'ABQ', 'SLC'],
#  ['01021825', '23', '428', 'ABQ', 'SLC'],
#  ['01020600', '0', '779', 'ABQ', 'SFO'],
#  ['01021933', '4', '303', 'ABQ', 'DEN'],
#  ['01021047', '-5', '589', 'ABQ', 'LAX'],
#  ['01021626', '4', '589', 'ABQ', 'LAX'],
#  ['01031225', '42', '589', 'ABQ', 'LAX'],
#  ['01032137', '-5', '285', 'ABQ', 'PHX'],
#  ['01030620', '-8', '285', 'ABQ', 'PHX'],
#  ['01031225', '-5', '285', 'ABQ', 'PHX'],
#  ['01030830', '-4', '285', 'ABQ', 'PHX'],
#  ['01031835', '3', '285', 'ABQ', 'PHX'],
#  ['01030600', '-1', '428', 'ABQ', 'SLC'],
#  ['01031204', '84', '428', 'ABQ', 'SLC'],
#  ['01031825', '-8', '428', 'ABQ', 'SLC'],
#  ['01030600', '-10', '779', 'ABQ', 'SFO'],
#  ['01031933', '-8', '303', 'ABQ', 'DEN'],
#  ['01031047', '-4', '589', 'ABQ', 'LAX'],
#  ['01031626', '2', '589', 'ABQ', 'LAX'],
#  ['01041225', '3', '589', 'ABQ', 'LAX'],
#  ['01042137', '0', '285', 'ABQ', 'PHX'],
#  ['01040620', '-9', '285', 'ABQ', 'PHX'],
#  ['01041225', '-6', '285', 'ABQ', 'PHX'],
#  ['01040830', '-2', '285', 'ABQ', 'PHX'],
#  ['01041835', '-8', '285', 'ABQ', 'PHX'],
#  ['01040600', '-2', '428', 'ABQ', 'SLC'],
#  ['01041204', '40', '428', 'ABQ', 'SLC'],
#  ['01041825', '-3', '428', 'ABQ', 'SLC'],
#  ['01041404', '52', '646', 'ABQ', 'IAH'],
#  ['01041933', '25', '303', 'ABQ', 'DEN'],
#  ['01040600', '-5', '779', 'ABQ', 'SFO'],
#  ['01041047', '45', '589', 'ABQ', 'LAX'],
#  ['01041626', '41', '589', 'ABQ', 'LAX'],
#  ['01051225', '3', '589', 'ABQ', 'LAX'],
#  ['01050545', '83', '589', 'ABQ', 'LAX'],
#  ['01052137', '4', '285', 'ABQ', 'PHX'],
#  ['01050620', '-6', '285', 'ABQ', 'PHX'],
#  ['01051225', '-6', '285', 'ABQ', 'PHX'],
#  ['01050830', '-7', '285', 'ABQ', 'PHX'],
#  ['01051835', '-3', '285', 'ABQ', 'PHX'],
#  ['01050605', '-2', '428', 'ABQ', 'SLC'],
#  ['01051204', '-1', '428', 'ABQ', 'SLC'],
#  ['01051825', '16', '428', 'ABQ', 'SLC'],
#  ['01051040', '-7', '646', 'ABQ', 'IAH'],
#  ['01050615', '-1', '646', 'ABQ', 'IAH'],
#  ['01051721', '70', '646', 'ABQ', 'IAH'],
#  ['01051411', '33', '646', 'ABQ', 'IAH'],
#  ['01051658', '53', '589', 'ABQ', 'LAX'],
#  ['01051933', '19', '303', 'ABQ', 'DEN'],
#  ['01050530', '-4', '303', 'ABQ', 'DEN'],
#  ['01050615', '0', '779', 'ABQ', 'SFO'],
#  ['01051051', '35', '589', 'ABQ', 'LAX'],
#  ['01061225', '3', '589', 'ABQ', 'LAX'],
#  ['01060620', '-2', '285', 'ABQ', 'PHX'],
#  ['01061225', '-4', '285', 'ABQ', 'PHX'],
#  ['01060830', '24', '285', 'ABQ', 'PHX'],
#  ['01061835', '-6', '285', 'ABQ', 'PHX'],
#  ['01060600', '40', '428', 'ABQ', 'SLC'],
#  ['01061720', '-2', '428', 'ABQ', 'SLC'],
#  ['01060600', '0', '779', 'ABQ', 'SFO'],
#  ['01061933', '-1', '303', 'ABQ', 'DEN'],
#  ['01061040', '-3', '589', 'ABQ', 'LAX'],
#  ['01061626', '-7', '589', 'ABQ', 'LAX'],
#  ['01071225', '5', '589', 'ABQ', 'LAX'],
#  ['01071225', '-6', '285', 'ABQ', 'PHX'],
#  ['01070830', '-6', '285', 'ABQ', 'PHX'],
#  ['01070620', '-1', '285', 'ABQ', 'PHX'],
#  ['01070600', '3', '428', 'ABQ', 'SLC'],
#  ['01071230', '-3', '428', 'ABQ', 'SLC'],
#  ['01071815', '-10', '428', 'ABQ', 'SLC'],
#  ['01071239', '0', '971', 'ABQ', 'ORD'],
#  ['01070815', '4', '779', 'ABQ', 'SFO'],
#  ['01071635', '-15', '589', 'ABQ', 'LAX'],
#  ['01081255', '24', '589', 'ABQ', 'LAX'],
#  ['01081225', '-8', '285', 'ABQ', 'PHX'],
#  ['01080830', '-8', '285', 'ABQ', 'PHX'],
#  ['01080620', '-5', '285', 'ABQ', 'PHX'],
#  ['01081835', '-10', '285', 'ABQ', 'PHX'],
#  ['01080600', '-3', '428', 'ABQ', 'SLC'],
#  ['01081230', '-4', '428', 'ABQ', 'SLC'],
#  ['01081815', '-8', '428', 'ABQ', 'SLC'],
#  ['01081239', '3', '971', 'ABQ', 'ORD'],
#  ['01080815', '36', '779', 'ABQ', 'SFO'],
#  ['01081635', '59', '589', 'ABQ', 'LAX'],
#  ['01091255', '11', '589', 'ABQ', 'LAX'],
#  ['01090620', '-7', '285', 'ABQ', 'PHX'],
#  ['01091225', '-7', '285', 'ABQ', 'PHX'],
#  ['01090830', '-7', '285', 'ABQ', 'PHX'],
#  ['01091835', '-8', '285', 'ABQ', 'PHX'],
#  ['01090600', '-2', '428', 'ABQ', 'SLC'],
#  ['01091230', '-3', '428', 'ABQ', 'SLC'],
#  ['01091720', '-4', '428', 'ABQ', 'SLC'],
#  ['01091239', '0', '971', 'ABQ', 'ORD'],
#  ['01090815', '151', '779', 'ABQ', 'SFO'],
#  ['01091635', '0', '589', 'ABQ', 'LAX'],
#  ['01101255', '-6', '589', 'ABQ', 'LAX'],
#  ['01100620', '-1', '285', 'ABQ', 'PHX'],
#  ['01101225', '-5', '285', 'ABQ', 'PHX'],
#  ['01100830', '-5', '285', 'ABQ', 'PHX'],
#  ['01101835', '-10', '285', 'ABQ', 'PHX'],
#  ['01100600', '-2', '428', 'ABQ', 'SLC'],
#  ['01101230', '-8', '428', 'ABQ', 'SLC'],
#  ['01101720', '-9', '428', 'ABQ', 'SLC'],
#  ['01101239', '92', '971', 'ABQ', 'ORD'],
#  ['01100815', '-6', '779', 'ABQ', 'SFO'],
#  ['01101635', '36', '589', 'ABQ', 'LAX'],
#  ['01111255', '-1', '589', 'ABQ', 'LAX'],
#  ['01111225', '-8', '285', 'ABQ', 'PHX'],
#  ['01110830', '-4', '285', 'ABQ', 'PHX'],
#  ['01110620', '-7', '285', 'ABQ', 'PHX'],
#  ['01111835', '-9', '285', 'ABQ', 'PHX'],
#  ['01110800', '-4', '428', 'ABQ', 'SLC'],
#  ['01111230', '-4', '428', 'ABQ', 'SLC'],
#  ['01111101', '8', '646', 'ABQ', 'IAH'],
#  ['01111239', '-8', '971', 'ABQ', 'ORD'],
#  ['01110815', '-4', '779', 'ABQ', 'SFO'],
#  ['01111635', '-5', '589', 'ABQ', 'LAX'],
#  ['01121255', '-2', '589', 'ABQ', 'LAX'],
#  ['01120545', '-8', '589', 'ABQ', 'LAX'],
#  ...]

# %% [markdown]
# flat map transformation

# %%
# Filter only second column == "WA",
# select first two columns within the RDD,
# and flatten out all values
(aiportRDD.filter(lambda c: c[1] == "WA").map(lambda c: (c[0], c[1])).flatMap(lambda x: x).take(10))
# Out:
# ['Bellingham',
#  'WA',
#  'Moses Lake',
#  'WA',
#  'Pasco',
#  'WA',
#  'Pullman',
#  'WA',
#  'Seattle',
#  'WA']

# %%
# Provide the distinct elements for the
# third column of airports representing
# countries
(aiportRDD.map(lambda c: c[2]).distinct().take(5))
# Out:
# ['Canada', 'USA', 'Country']

# %%
# Provide a sample based on 0.001% the
# flights RDD data specific to the fourth
# column (origin city of flight)
# without replacement (False) using random
# seed of 123
(
departure_flightRDD
.map(lambda c: c[3])
.sample(False, 0.001, 123)
.take(5)
)
# Out:
# ['ABQ', 'AEX', 'AGS', 'ANC', 'ATL']

# %% [markdown]
# Join transformation

# %%
# Flights data
flt = departure_flightRDD.map(lambda c: (c[3], c[0]))
# Airports data
air = aiportRDD.map(lambda c: (c[3], c[1]))
# Execute inner join between RDDs
flt.join(air).take(5)
# Out:
# [('ALB', ('01010600', 'NY')),
#  ('ALB', ('01021808', 'NY')),
#  ('ALB', ('01020600', 'NY')),
#  ('ALB', ('01031808', 'NY')),
#  ('ALB', ('01030600', 'NY'))]

# %% [markdown]
# repartition() transformation

# %%
# The flights RDD originally generated has 2 partitions
departure_flightRDD.getNumPartitions()

flights2 = departure_flightRDD.repartition(8)
# Checking the number of partitions for the flights2 RDD
flights2.getNumPartitions()
# Out:
# 8

# %% [markdown]
# zipWithIndex transformation

# %%
aiportRDD.take(10)
# Out:
# [['City', 'State', 'Country', 'IATA'],
#  ['Abbotsford', 'BC', 'Canada', 'YXX'],
#  ['Aberdeen', 'SD', 'USA', 'ABR'],
#  ['Abilene', 'TX', 'USA', 'ABI'],
#  ['Akron', 'OH', 'USA', 'CAK'],
#  ['Alamosa', 'CO', 'USA', 'ALS'],
#  ['Albany', 'GA', 'USA', 'ABY'],
#  ['Albany', 'NY', 'USA', 'ALB'],
#  ['Albuquerque', 'NM', 'USA', 'ABQ'],
#  ['Alexandria', 'LA', 'USA', 'AEX']]

# %%
# View each row within RDD + the index
# i.e. output is in form ([row], idx)
ac = aiportRDD.map(lambda c: (c[0], c[3]))
ac.zipWithIndex().take(5)
# Out:
# [(('City', 'IATA'), 0),
#  (('Abbotsford', 'YXX'), 1),
#  (('Aberdeen', 'ABR'), 2),
#  (('Abilene', 'ABI'), 3),
#  (('Akron', 'CAK'), 4)]

# %%
# To remove the header from the data
# Using zipWithIndex to skip header row
# - filter out row 0
# - extract only row info
# (ac.zipWithIndex().filter(lambda (row, idx): idx > 0).map(lambda (row, idx): row).take(5))

# %%
(ac.zipWithIndex()
   .filter(lambda row_idx: row_idx[1] > 0)  # Unpacking tuple
   .map(lambda row_idx: row_idx[0])  # Extracting the row
   .take(5)
)
# Out:
# [('Abbotsford', 'YXX'),
#  ('Aberdeen', 'ABR'),
#  ('Abilene', 'ABI'),
#  ('Akron', 'CAK'),
#  ('Alamosa', 'ALS')]

# %% [markdown]
# ## reduceByKey transformation :

# %%
# # Determine delays by originating city
# # - remove header row via zipWithIndex() and map()
# (departure_flightRDD.zipWithIndex().filter(lambda row_idx: row_idx[0] > 0).map(lambda row_idx[1]: row)\
#  .map(lambda c: (c[3], int(c[1]))).reduceByKey(lambda x, y: x + y).take(5))

# %%
(
    departure_flightRDD
    .zipWithIndex()
    .filter(lambda row_idx: row_idx[1] > 0)  # idx is now accessed with row_idx[1]
    .map(lambda row_idx: row_idx[0])  # Extract the row
    .map(lambda c: (c[3], int(c[1])))  # Assuming c[1] is the delay and c[3] is the city
    .reduceByKey(lambda x, y: x + y)
    .take(5)
)
# Out:
# [('ADQ', -254), ('BHM', 44355), ('BQN', 3943), ('BRO', 4967), ('BTM', -138)]

# %%
departure_flightRDD.take(10)
# Out:
# [['date', 'delay', 'distance', 'origin', 'destination'],
#  ['01011245', '6', '602', 'ABE', 'ATL'],
#  ['01020600', '-8', '369', 'ABE', 'DTW'],
#  ['01021245', '-2', '602', 'ABE', 'ATL'],
#  ['01020605', '-4', '602', 'ABE', 'ATL'],
#  ['01031245', '-4', '602', 'ABE', 'ATL'],
#  ['01030605', '0', '602', 'ABE', 'ATL'],
#  ['01041243', '10', '602', 'ABE', 'ATL'],
#  ['01040605', '28', '602', 'ABE', 'ATL'],
#  ['01051245', '88', '602', 'ABE', 'ATL']]

# %% [markdown]
# ## sortByKey transformation

# %%
(
    departure_flightRDD.zipWithIndex()
    .filter(lambda row_idx: row_idx[1] > 0)  # Filter out the header row
    .map(lambda row_idx: row_idx[0])  # Extract the actual row
    .map(lambda c: (c[3], int(c[1])))  # Extract the origin code (c[3]) and delay (c[1])
    .reduceByKey(lambda x, y: x + y)  # Sum the delays by origin code
    .sortByKey()  # Sort by origin code
    .take(50)  # Take top 50 results
)
# Out:
# [('ABE', 5113),
#  ('ABI', 5128),
#  ('ABQ', 64422),
#  ('ABY', 1554),
#  ('ACT', 392),
#  ('ACV', 8429),
#  ('ADQ', -254),
#  ('AEX', 10193),
#  ('AGS', 5003),
#  ('ALB', 22362),
#  ('ALO', 2866),
#  ('AMA', 21979),
#  ('ANC', 4948),
#  ('ATL', 1151087),
#  ('ATW', 8151),
#  ('AUS', 108638),
#  ('AVL', 5727),
#  ('AVP', 2946),
#  ('AZO', 233),
#  ('BDL', 54662),
#  ('BET', -645),
#  ('BFL', 4022),
#  ('BGR', 2852),
#  ('BHM', 44355),
#  ('BIL', 2616),
#  ('BIS', 3825),
#  ('BMI', 7817),
#  ('BNA', 212243),
#  ('BOI', 18004),
#  ('BOS', 238602),
#  ('BPT', 1936),
#  ('BQK', 3952),
#  ('BQN', 3943),
#  ('BRO', 4967),
#  ('BRW', 880),
#  ('BTM', -138),
#  ('BTR', 21989),
#  ('BTV', 14755),
#  ('BUF', 54309),
#  ('BUR', 42241),
#  ('BWI', 362845),
#  ('BZN', 7226),
#  ('CAE', 25686),
#  ('CAK', 14749),
#  ('CDC', 51),
#  ('CDV', -1024),
#  ('CEC', 2832),
#  ('CHA', 7586),
#  ('CHO', 2421),
#  ('CHS', 30789)]

# %% [markdown]
# ## Union transformation

# %%
# Create `a` RDD of Washington airports
a = (
    aiportRDD.zipWithIndex()
    .filter(lambda row_idx: row_idx[1] > 0)  # Filtering out the header row
    .map(lambda row_idx: row_idx[0])  # Extracting the actual row
    .filter(lambda c: c[1] == "WA")  # Filter for Washington (WA) airports
)

# Create `b` RDD of British Columbia airports
b = (
    aiportRDD.zipWithIndex()
    .filter(lambda row_idx: row_idx[1] > 0)  # Filtering out the header row
    .map(lambda row_idx: row_idx[0])  # Extracting the actual row
    .filter(lambda c: c[1] == "BC")  # Filter for British Columbia (BC) airports
)

# Union WA and BC airports
a.union(b).collect()
# Out:
# [['Bellingham', 'WA', 'USA', 'BLI'],
#  ['Moses Lake', 'WA', 'USA', 'MWH'],
#  ['Pasco', 'WA', 'USA', 'PSC'],
#  ['Pullman', 'WA', 'USA', 'PUW'],
#  ['Seattle', 'WA', 'USA', 'SEA'],
#  ['Spokane', 'WA', 'USA', 'GEG'],
#  ['Walla Walla', 'WA', 'USA', 'ALW'],
#  ['Wenatchee', 'WA', 'USA', 'EAT'],
#  ['Yakima', 'WA', 'USA', 'YKM'],
#  ['Abbotsford', 'BC', 'Canada', 'YXX'],
#  ['Anahim Lake', 'BC', 'Canada', 'YAA'],
#  ['Campbell River', 'BC', 'Canada', 'YBL'],
#  ['Castlegar', 'BC', 'Canada', 'YCG'],
#  ['Cranbrook', 'BC', 'Canada', 'YXC'],
#  ['Fort Nelson', 'BC', 'Canada', 'YYE'],
#  ['Fort Saint John', 'BC', 'Canada', 'YXJ'],
#  ['Kamloops', 'BC', 'Canada', 'YKA'],
#  ['Kelowna', 'BC', 'Canada', 'YLW'],
#  ['Nanaimo', 'BC', 'Canada', 'YCD'],
#  ['Penticton', 'BC', 'Canada', 'YYF'],
#  ['Port Hardy', 'BC', 'Canada', 'YZT'],
#  ['Powell River', 'BC', 'Canada', 'YPW'],
#  ['Prince George', 'BC', 'Canada', 'YXS'],
#  ['Prince Rupert', 'BC', 'Canada', 'YPR'],
#  ['Quesnel', 'BC', 'Canada', 'YQZ'],
#  ['"Sandspit, Queen Charlotte Islands"', 'BC', 'Canada', 'YZP'],
#  ['Smithers', 'BC', 'Canada', 'YYD'],
#  ['Terrace', 'BC', 'Canada', 'YXT'],
#  ['Vancouver', 'BC', 'Canada', 'YVR'],
#  ['Victoria', 'BC', 'Canada', 'YYJ'],
#  ['Williams Lake', 'BC', 'Canada', 'YWL']]

# %% [markdown]
# ## mapPartitionsWithIndex transformation

# %%
# # The mapPartitionsWithIndex(f) is similar to map but runs the
# f function separately on each partition and provides an index of the
# partition.

# %%
# Define the partitionElementCount function
def partitionElementCount(idx, iterator):
    count = 0
    for _ in iterator:
        count += 1
    return [(idx, count)]  # Return a list of tuples

# Use mapPartitionsWithIndex to determine the number of elements in each partition
departure_flightRDD.mapPartitionsWithIndex(partitionElementCount).collect()
# Out:
# [(0, 174294),
#  (1, 174020),
#  (2, 173849),
#  (3, 174006),
#  (4, 173864),
#  (5, 174308),
#  (6, 173620),
#  (7, 173618)]

# %% [markdown]
# # RDD Actions

# %% [markdown]
# ## Collect() action

# %%
# Return all airports elements
# filtered by WA state
aiportRDD.filter(lambda c: c[1] == "WA").collect()
# Out:
# [['Bellingham', 'WA', 'USA', 'BLI'],
#  ['Moses Lake', 'WA', 'USA', 'MWH'],
#  ['Pasco', 'WA', 'USA', 'PSC'],
#  ['Pullman', 'WA', 'USA', 'PUW'],
#  ['Seattle', 'WA', 'USA', 'SEA'],
#  ['Spokane', 'WA', 'USA', 'GEG'],
#  ['Walla Walla', 'WA', 'USA', 'ALW'],
#  ['Wenatchee', 'WA', 'USA', 'EAT'],
#  ['Yakima', 'WA', 'USA', 'YKM']]

# %% [markdown]
# ## Reduce action

# %%
# The reduce(f) action aggregates the elements of an RDD by f. The
# f function should be commutative and associative so that it can be
# computed correctly in parallel.

# %%
# Calculate the total delays of flights
# between SEA (origin) and SFO (dest),
# convert delays column to int
# and summarize
departure_flightRDD.filter(lambda c: c[3] == 'SEA' and c[4] == 'SFO')\
.map(lambda c: int(c[1]))\
.reduce(lambda x, y: x + y)
# Out:
# 22293

# %% [markdown]
# ## count() action

# %%
departure_flightRDD.zipWithIndex().filter(lambda row_idx: row_idx[1] > 0).map(lambda row_idx: row_idx[0]).count()
# Out:
# 1391578

# %% [markdown]
# ## saveAsTextFile() action

# %%
# Saves airports as a text file
# Note, each partition has their own file
# saveAsTextFile
aiportRDD.saveAsTextFile("airports")

# %%
# Determine delays by originating city
# - remove header row via zipWithIndex() and map()
departure_flightRDD.zipWithIndex().filter(lambda row_idx: row_idx[1] > 0).map(lambda row_idx: row_idx[0])\
.map(lambda c: (c[3], int(c[1]))).reduceByKey(lambda x, y: x + y).take(5)
# Out:
# [('ADQ', -254), ('BHM', 44355), ('BQN', 3943), ('BRO', 4967), ('BTM', -138)]
